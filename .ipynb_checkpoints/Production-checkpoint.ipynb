# %%
import os
import sys

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

# %%
ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

CompParams = {
  "number_workers":16,   #For S2 data, only use 10 rather than 20  
  "debug"       : True,
  "entire_tile" : False,     #
  "nodes"       : 1,
  "node_memory" : "32G",
  'chunk_size': {'x': 2048, 'y': 2048}
}

  
ProdParams = {
    'sensor': 'HLS_SR',       # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR', 'HLSS30_SR' or 'MOD_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2025,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    'months': [5,6,7],            # A list of integers represening one or multiple monthes     
    'tile_names': ['tile42_421'], # A list of (sub-)tile names (defined using CCRS' tile griding system) 
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution':30,            # Exporting spatial resolution    
    'out_folder': 'E:/HLS_mosaics_2025/HLS_mosaic_tile42_421_2025_30m',  # the folder name for exporting
    'out_datatype': 'int16',     # 'int8' or 'int16'
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    #'start_dates': ['2025-06-15'],
    #'end_dates': ['2025-09-15'],
    #'regions': {'ottawa': ottawa_region}  #, {'vancouver': vancouver_region}    
}

# %%
main(ProdParams, CompParams)
# Out:
# <MosaicProduction> User defined input parameters:
# sensor: HLS_SR
# unit: 2
# year: 2025
# nbYears: -1
# months: [6, 7, 9, 10]
# tile_names: ['tile55_411']
# prod_names: ['mosaic']
# resolution: 30
# out_folder: C:/Work_Data/HLS_mosaic_tile55_411_2025_30m
# out_datatype: int16
# projection: EPSG:3979
# IncludeAngles: False
# SsrData: {'NAME': 'HLS_SR', 'SSR_CODE': 102, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07'], 'SIX_BANDS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07'], 'NoA_BANDS': ['B04', 'B05', 'B06', 'B07'], 'LEAF_BANDS': ['B03', 'B04', 'B05', 'B06', 'B07'], 'ANGLE_BANDS': ['VZA', 'VAA', 'SZA', 'SAA'], 'CLOUD': 'CLOUD_COVERAGE', 'BLU': 'B02', 'GRN': 'B03', 'RED': 'B04', 'NIR': 'B05', 'SW1': 'B06', 'SW2': 'B07'}
# out_location: drive
# cloud_cover: 80
# export_style: separate
# CloudScore: False
# monthly: True
# start_dates: ['2025-06-01', '2025-07-01', '2025-09-01', '2025-10-01']
# end_dates: ['2025-06-30', '2025-07-31', '2025-09-30', '2025-10-31']
# current_time: 0
# scene_ID:
# regions: {'tile55_411': {'type': 'Polygon', 'coordinates': [[[-80.7932, 51.014900000000004], [-82.1071, 46.665499999999994], [-76.1005, 45.6742], [-74.28739999999999, 49.9119], [-80.7932, 51.014900000000004]]]}}
# current_region: tile55_411
# Criteria: {'timeframe': '2025-06-01/2025-06-30', 'filters': {'eo:cloud_cover': {'lt': 80}}, 'region': {'type': 'Polygon', 'coordinates': [[[-80.7932, 51.014900000000004], [-82.1071, 46.665499999999994], [-76.1005, 45.6742], [-74.28739999999999, 49.9119], [-80.7932, 51.014900000000004]]]}, 'collection': ['HLSS30_2.0', 'HLSL30_2.0'], 'bands': {'S2': ['B02', 'B03', 'B04', 'B08', 'B11', 'B12', 'Fmask'], 'LS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'Fmask'], 'angle': ['SZA', 'SAA', 'VZA', 'VAA']}, 'catalog': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD'}
# standardized: True
# number_workers: 16
# debug: True
# entire_tile: False
# nodes: 1
# node_memory: 32G
# chunk_size: {'x': 2048, 'y': 2048}
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-80.7932, 51.014900000000004], [-82.1071, 46.665499999999994], [-76.1005, 45.6742], [-74.28739999999999, 49.9119], [-80.7932, 51.014900000000004]]]}
#
# <period_mosaic> A total of 493 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T18UUB.2025153T161921.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.jpg
# Asset key: B10, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B10.tif
# Asset key: VAA, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.VAA.tif
# Asset key: B04, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B04.tif
# Asset key: Fmask, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.Fmask.tif
# Asset key: B02, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B02.tif
# Asset key: B11, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B11.tif
# Asset key: B06, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B06.tif
# Asset key: B8A, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B8A.tif
# Asset key: B07, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B07.tif
# Asset key: B01, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B01.tif
# Asset key: SZA, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.SZA.tif
# Asset key: B12, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B12.tif
# Asset key: B05, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B05.tif
# Asset key: B03, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B03.tif
# Asset key: B08, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B08.tif
# Asset key: B09, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B09.tif
# Asset key: SAA, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.SAA.tif
# Asset key: VZA, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.VZA.tif
# Asset key: s3_B10, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B10.tif
# Asset key: s3_VAA, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.VAA.tif
# Asset key: s3_B04, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B04.tif
# Asset key: s3_Fmask, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.Fmask.tif
# Asset key: s3_B02, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B02.tif
# Asset key: s3_B11, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B11.tif
# Asset key: s3_B06, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B06.tif
# Asset key: s3_B8A, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B8A.tif
# Asset key: s3_B07, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B07.tif
# Asset key: s3_B01, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B01.tif
# Asset key: s3_SZA, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.SZA.tif
# Asset key: s3_B12, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B12.tif
# Asset key: s3_B05, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B05.tif
# Asset key: s3_B03, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B03.tif
# Asset key: s3_B08, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B08.tif
# Asset key: s3_B09, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.B09.tif
# Asset key: s3_SAA, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.SAA.tif
# Asset key: s3_VZA, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025153T161921.v2.0/HLS.S30.T18UUB.2025153T161921.v2.0.VZA.tif
# Asset key: metadata, title: CMR XML metadata for G3580420386-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3580420386-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# ID: HLS.S30.T18UUB.2025153T161921.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-77.8160726, 50.429713], [-77.2243903, 50.4425357], [-76.7199083, 51.4385655], [-77.8762918, 51.4158836], [-77.8160726, 50.429713]]]}
# Bounding Box: [-77.8762918, 50.429713, -76.7199083, 51.4385655]
# Datetime: 2025-06-02 16:29:28.086000+00:00
# cloud cover: 6
# Properties:
#   <datetime>: 2025-06-02T16:29:28.086Z
#   <eo:cloud_cover>: 6
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2025-06-02T16:29:28.086Z
#   <end_datetime>: 2025-06-02T16:29:28.086Z
#
# <period_mosaic> based mosaic image =  <xarray.Dataset> Size: 10GB
# Dimensions:      (y: 16691, x: 16341)
# Coordinates:
#   * y            (y) float64 134kB 3.405e+05 3.405e+05 ... -1.602e+05 -1.602e+05
#   * x            (x) float64 131kB 9.815e+05 9.815e+05 ... 1.472e+06 1.472e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-06-02T16:29:28.086000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#
# <period_mosaic> The number of unique granule tiles = 41
#
# <<<<<< The unique granule tiles =  ['T18UUA', 'T17UQQ', 'T17UNP', 'T18UUV', 'T17UPS', 'T17UQR', 'T17UNQ', 'T17TQL', 'T18UUB', 'T17UQS', 'T17UNS', 'T17TPN', 'T17TMN', 'T17TMM', 'T18TUR', 'T18UUU', 'T17UMS', 'T17UPR', 'T17UNR', 'T17UPQ', 'T17UQP', 'T17TNN', 'T17TPM', 'T18UVA', 'T18TUS', 'T17UMR', 'T17UMQ', 'T17TNM', 'T18UWA', 'T18UVV', 'T18TVT', 'T18TUT', 'T17TQN', 'T17UPP', 'T17UMP', 'T18UVU', 'T17TQM', 'T18UWV', 'T18UWU', 'T18TVS', 'T18TVR']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 340.46 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.02 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
# ERROR:asyncio:Exception in callback BaseIOStream.write.<locals>.<lambda>() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\iostream.py:536
# handle: <Handle BaseIOStream.write.<locals>.<lambda>() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\iostream.py:536>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\iostream.py", line 536, in <lambda>
#     future.add_done_callback(lambda f: f.exception())
#                                        ~~~~~~~~~~~^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 106, in _needs_document_lock_wrapper
#     await p
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\views\ws.py", line 284, in send_message
#     await message.send(self)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\protocol\message.py", line 325, in send
#     sent += await self.write_buffers(conn, locked=False)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\protocol\message.py", line 269, in write_buffers
#     await conn.write_message(header, locked=locked)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\views\ws.py", line 300, in write_message
#     await super().write_message(message, binary)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\websocket.py", line 1113, in wrapper
#     await fut
# asyncio.exceptions.CancelledError
# <<<<<< The total elapsed time for mosaic generation = 105.73 minutes >>>>>>
# File 'C:\Work_Data\HLS_mosaic_tile55_411_2025_30m\log_ec733163-7a32-4a48-9f36-391025ceaa1f.out' does not exist.
# Directory 'C:\Work_Data\HLS_mosaic_tile55_411_2025_30m\dask_spill_ec733163-7a32-4a48-9f36-391025ceaa1f' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-80.7932, 51.014900000000004], [-82.1071, 46.665499999999994], [-76.1005, 45.6742], [-74.28739999999999, 49.9119], [-80.7932, 51.014900000000004]]]}
#
# <period_mosaic> A total of 570 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T18UUA.2025182T155819.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.jpg
# Asset key: SZA, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.SZA.tif
# Asset key: B08, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B08.tif
# Asset key: B11, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B11.tif
# Asset key: B10, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B10.tif
# Asset key: B12, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B12.tif
# Asset key: B02, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B02.tif
# Asset key: B04, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B04.tif
# Asset key: B8A, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B8A.tif
# Asset key: B09, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B09.tif
# Asset key: B03, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B03.tif
# Asset key: VZA, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.VZA.tif
# Asset key: B01, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B01.tif
# Asset key: VAA, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.VAA.tif
# Asset key: B06, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B06.tif
# Asset key: B07, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B07.tif
# Asset key: Fmask, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.Fmask.tif
# Asset key: B05, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B05.tif
# Asset key: SAA, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.SAA.tif
# Asset key: s3_SZA, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.SZA.tif
# Asset key: s3_B08, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B08.tif
# Asset key: s3_B11, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B11.tif
# Asset key: s3_B10, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B10.tif
# Asset key: s3_B12, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B12.tif
# Asset key: s3_B02, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B02.tif
# Asset key: s3_B04, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B04.tif
# Asset key: s3_B8A, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B8A.tif
# Asset key: s3_B09, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B09.tif
# Asset key: s3_B03, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B03.tif
# Asset key: s3_VZA, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.VZA.tif
# Asset key: s3_B01, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B01.tif
# Asset key: s3_VAA, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.VAA.tif
# Asset key: s3_B06, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B06.tif
# Asset key: s3_B07, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B07.tif
# Asset key: s3_Fmask, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.Fmask.tif
# Asset key: s3_B05, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.B05.tif
# Asset key: s3_SAA, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUA.2025182T155819.v2.0/HLS.S30.T18UUA.2025182T155819.v2.0.SAA.tif
# Asset key: metadata, title: CMR XML metadata for G3590398635-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3590398635-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# ID: HLS.S30.T18UUA.2025182T155819.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-76.8451095, 49.5500438], [-76.247217, 49.558034], [-76.2730756, 50.5453332], [-76.4558998, 50.5421114], [-76.8451095, 49.5500438]]]}
# Bounding Box: [-76.8451095, 49.5500438, -76.247217, 50.5453332]
# Datetime: 2025-07-01 16:09:31.177000+00:00
# cloud cover: 41
# Properties:
#   <datetime>: 2025-07-01T16:09:31.177Z
#   <eo:cloud_cover>: 41
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2025-07-01T16:09:31.177Z
#   <end_datetime>: 2025-07-01T16:09:31.177Z
#
# <period_mosaic> based mosaic image =  <xarray.Dataset> Size: 10GB
# Dimensions:      (y: 16691, x: 16341)
# Coordinates:
#   * y            (y) float64 134kB 3.405e+05 3.405e+05 ... -1.602e+05 -1.602e+05
#   * x            (x) float64 131kB 9.815e+05 9.815e+05 ... 1.472e+06 1.472e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-07-01T16:09:31.177000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#
# <period_mosaic> The number of unique granule tiles = 41
#
# <<<<<< The unique granule tiles =  ['T17TQM', 'T17TPM', 'T18UUA', 'T17UQQ', 'T18TUS', 'T17UNQ', 'T17UNP', 'T17TNN', 'T17TNM', 'T18UUV', 'T18UUU', 'T18TVT', 'T17TQN', 'T17TQL', 'T17TMN', 'T17TMM', 'T17UQP', 'T18TUT', 'T17UPQ', 'T17TPN', 'T17UMQ', 'T17UNS', 'T17UQR', 'T17UMP', 'T18UVU', 'T17UPP', 'T17UPS', 'T18TUR', 'T18UVV', 'T17UMS', 'T17UNR', 'T17UMR', 'T18UVA', 'T17UPR', 'T18UUB', 'T17UQS', 'T18TVR', 'T18TVS', 'T18UWA', 'T18UWV', 'T18UWU']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 352.52 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.02 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation = 122.78 minutes >>>>>>
# File 'C:\Work_Data\HLS_mosaic_tile55_411_2025_30m\log_95bd0640-9ff4-498e-9211-7400445f9707.out' does not exist.
# Directory 'C:\Work_Data\HLS_mosaic_tile55_411_2025_30m\dask_spill_95bd0640-9ff4-498e-9211-7400445f9707' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-80.7932, 51.014900000000004], [-82.1071, 46.665499999999994], [-76.1005, 45.6742], [-74.28739999999999, 49.9119], [-80.7932, 51.014900000000004]]]}
#
# <period_mosaic> A total of 550 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T18UUB.2025245T160829.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.jpg
# Asset key: B03, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B03.tif
# Asset key: B05, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B05.tif
# Asset key: B08, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B08.tif
# Asset key: SZA, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.SZA.tif
# Asset key: B10, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B10.tif
# Asset key: B06, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B06.tif
# Asset key: B11, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B11.tif
# Asset key: B12, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B12.tif
# Asset key: B02, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B02.tif
# Asset key: VAA, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.VAA.tif
# Asset key: B8A, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B8A.tif
# Asset key: SAA, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.SAA.tif
# Asset key: Fmask, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.Fmask.tif
# Asset key: B01, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B01.tif
# Asset key: B09, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B09.tif
# Asset key: VZA, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.VZA.tif
# Asset key: B07, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B07.tif
# Asset key: B04, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B04.tif
# Asset key: s3_B03, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B03.tif
# Asset key: s3_B05, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B05.tif
# Asset key: s3_B08, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B08.tif
# Asset key: s3_SZA, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.SZA.tif
# Asset key: s3_B10, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B10.tif
# Asset key: s3_B06, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B06.tif
# Asset key: s3_B11, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B11.tif
# Asset key: s3_B12, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B12.tif
# Asset key: s3_B02, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B02.tif
# Asset key: s3_VAA, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.VAA.tif
# Asset key: s3_B8A, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B8A.tif
# Asset key: s3_SAA, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.SAA.tif
# Asset key: s3_Fmask, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.Fmask.tif
# Asset key: s3_B01, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B01.tif
# Asset key: s3_B09, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B09.tif
# Asset key: s3_VZA, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.VZA.tif
# Asset key: s3_B07, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B07.tif
# Asset key: s3_B04, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18UUB.2025245T160829.v2.0/HLS.S30.T18UUB.2025245T160829.v2.0.B04.tif
# Asset key: metadata, title: CMR XML metadata for G3687764976-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3687764976-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# ID: HLS.S30.T18UUB.2025245T160829.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-77.8160726, 50.429713], [-76.2706991, 50.4568612], [-76.2979079, 51.4439979], [-77.8762918, 51.4158836], [-77.8160726, 50.429713]]]}
# Bounding Box: [-77.8762918, 50.429713, -76.2706991, 51.4439979]
# Datetime: 2025-09-02 16:19:10.914000+00:00
# cloud cover: 10
# Properties:
#   <datetime>: 2025-09-02T16:19:10.914Z
#   <eo:cloud_cover>: 10
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2025-09-02T16:19:10.914Z
#   <end_datetime>: 2025-09-02T16:19:10.914Z
#
# <period_mosaic> based mosaic image =  <xarray.Dataset> Size: 10GB
# Dimensions:      (y: 16691, x: 16341)
# Coordinates:
#   * y            (y) float64 134kB 3.405e+05 3.405e+05 ... -1.602e+05 -1.602e+05
#   * x            (x) float64 131kB 9.815e+05 9.815e+05 ... 1.472e+06 1.472e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-09-02T16:19:10.914000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#
# <period_mosaic> The number of unique granule tiles = 41
#
# <<<<<< The unique granule tiles =  ['T17TPM', 'T18TUR', 'T18UUA', 'T17UPS', 'T17TPN', 'T17TQM', 'T18UWA', 'T17TQN', 'T18TUS', 'T17TNM', 'T17TQL', 'T18UUB', 'T17UQR', 'T17TNN', 'T17UQS', 'T17UNQ', 'T18TVT', 'T17UNP', 'T17TMM', 'T17UQP', 'T18UVA', 'T18UUU', 'T18TUT', 'T17UNS', 'T17TMN', 'T18UUV', 'T17UQQ', 'T17UPQ', 'T17UPR', 'T18UVU', 'T18UVV', 'T17UNR', 'T17UMQ', 'T17UMP', 'T17UPP', 'T18TVR', 'T18TVS', 'T17UMS', 'T17UMR', 'T18UWV', 'T18UWU']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 348.11 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.02 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation = 114.28 minutes >>>>>>
# File 'C:\Work_Data\HLS_mosaic_tile55_411_2025_30m\log_d7297cba-ec93-4502-8198-840d2ea3e86b.out' does not exist.
# Directory 'C:\Work_Data\HLS_mosaic_tile55_411_2025_30m\dask_spill_d7297cba-ec93-4502-8198-840d2ea3e86b' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-80.7932, 51.014900000000004], [-82.1071, 46.665499999999994], [-76.1005, 45.6742], [-74.28739999999999, 49.9119], [-80.7932, 51.014900000000004]]]}
#
# <period_mosaic> A total of 631 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T17UQS.2025275T161019.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.jpg
# Asset key: VZA, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.VZA.tif
# Asset key: B04, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B04.tif
# Asset key: B02, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B02.tif
# Asset key: B01, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B01.tif
# Asset key: B08, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B08.tif
# Asset key: B06, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B06.tif
# Asset key: Fmask, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.Fmask.tif
# Asset key: B07, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B07.tif
# Asset key: SAA, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.SAA.tif
# Asset key: B8A, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B8A.tif
# Asset key: B10, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B10.tif
# Asset key: B09, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B09.tif
# Asset key: VAA, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.VAA.tif
# Asset key: B05, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B05.tif
# Asset key: B11, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B11.tif
# Asset key: B12, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B12.tif
# Asset key: SZA, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.SZA.tif
# Asset key: B03, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B03.tif
# Asset key: s3_VZA, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.VZA.tif
# Asset key: s3_B04, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B04.tif
# Asset key: s3_B02, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B02.tif
# Asset key: s3_B01, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B01.tif
# Asset key: s3_B08, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B08.tif
# Asset key: s3_B06, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B06.tif
# Asset key: s3_Fmask, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.Fmask.tif
# Asset key: s3_B07, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B07.tif
# Asset key: s3_SAA, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.SAA.tif
# Asset key: s3_B8A, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B8A.tif
# Asset key: s3_B10, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B10.tif
# Asset key: s3_B09, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B09.tif
# Asset key: s3_VAA, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.VAA.tif
# Asset key: s3_B05, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B05.tif
# Asset key: s3_B11, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B11.tif
# Asset key: s3_B12, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B12.tif
# Asset key: s3_SZA, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.SZA.tif
# Asset key: s3_B03, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17UQS.2025275T161019.v2.0/HLS.S30.T17UQS.2025275T161019.v2.0.B03.tif
# Asset key: metadata, title: CMR XML metadata for G3789202368-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3789202368-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# ID: HLS.S30.T17UQS.2025275T161019.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-76.6423781, 50.3821223], [-76.5494103, 51.366602], [-78.1242827, 51.4158977], [-78.1844899, 50.4297266], [-76.6423781, 50.3821223]]]}
# Bounding Box: [-78.1844899, 50.3821223, -76.5494103, 51.4158977]
# Datetime: 2025-10-02 16:19:12.659000+00:00
# cloud cover: 79
# Properties:
#   <datetime>: 2025-10-02T16:19:12.659Z
#   <eo:cloud_cover>: 79
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2025-10-02T16:19:12.659Z
#   <end_datetime>: 2025-10-02T16:19:12.659Z
#
# <period_mosaic> based mosaic image =  <xarray.Dataset> Size: 10GB
# Dimensions:      (y: 16691, x: 16341)
# Coordinates:
#   * y            (y) float64 134kB 3.405e+05 3.405e+05 ... -1.602e+05 -1.602e+05
#   * x            (x) float64 131kB 9.815e+05 9.815e+05 ... 1.472e+06 1.472e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-10-02T16:19:12.659000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#
# <period_mosaic> The number of unique granule tiles = 41
#
# <<<<<< The unique granule tiles =  ['T17UQQ', 'T18UUA', 'T18UUV', 'T17UPS', 'T17UQP', 'T17UQS', 'T17UQR', 'T17UPR', 'T17UPQ', 'T17UNP', 'T17TNN', 'T18TUS', 'T17TQM', 'T17TQL', 'T17UNQ', 'T18UUB', 'T17TPM', 'T17TNM', 'T18UVA', 'T18UUU', 'T18TUT', 'T18TUR', 'T17TMN', 'T17UNS', 'T18UWA', 'T18UVV', 'T17UPP', 'T18TVT', 'T17TQN', 'T17TPN', 'T17UMP', 'T17TMM', 'T18UVU', 'T17UNR', 'T17UMR', 'T17UMS', 'T17UMQ', 'T18TVS', 'T18UWV', 'T18TVR', 'T18UWU']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 356.96 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.02 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation = 125.84 minutes >>>>>>
# File 'C:\Work_Data\HLS_mosaic_tile55_411_2025_30m\log_af6911ca-946f-4e45-84c1-bcf8503a7e4a.out' does not exist.
# Directory 'C:\Work_Data\HLS_mosaic_tile55_411_2025_30m\dask_spill_af6911ca-946f-4e45-84c1-bcf8503a7e4a' and its contents have been deleted.
