# %%
import os
import sys

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

# %%
ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

CompParams = {
  "number_workers":10,   #For S2 data, only use 10 rather than 20  
  "debug"       : True,
  "entire_tile" : False,     #
  "nodes"       : 1,
  "node_memory" : "50G",
  'chunk_size': {'x': 4096, 'y': 4096}
}

  
ProdParams = {
    'sensor': 'HLS_SR',       # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR', 'HLSS30_SR' or 'MOD_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2025,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    'months': [5,6,7,8,9,10],            # A list of integers represening one or multiple monthes     
    'tile_names': ['tile54_411', 'tile54_412'], # A list of (sub-)tile names (defined using CCRS' tile griding system) 
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution': 30,            # Exporting spatial resolution    
    'out_folder': 'E:/HLS_mosaics_2025/HLS_mosaic_tile54_2025_30m',  # the folder name for exporting
    'out_datatype': 'int16',     # 'int8' or 'int16'
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    #'start_dates': ['2025-06-15'],
    #'end_dates': ['2025-09-15'],
    #'regions': {'ottawa': ottawa_region}  #, {'vancouver': vancouver_region}    
}

# %%
main(ProdParams, CompParams)
# Out:
# <form_spatial_regions> Raw polygon = {'type': 'Polygon', 'coordinates': [[[-106.5964, 51.1826], [-105.5276, 47.195], [-99.6401, 47.6739], [-100.1193, 51.718], [-106.5964, 51.1826]]]}
# <form_spatial_regions> Raw polygon = {'type': 'Polygon', 'coordinates': [[[-100.1193, 51.718], [-99.6401, 47.6739], [-93.6721, 47.7788], [-93.5344, 51.8354], [-100.1193, 51.718]]]}
# <MosaicProduction> User defined input parameters:
# sensor: HLS_SR
# unit: 2
# year: 2025
# nbYears: -1
# months: [5, 6, 7, 8, 9, 10]
# tile_names: ['tile53_411', 'tile53_412']
# prod_names: ['mosaic']
# resolution: 30
# out_folder: E:/HLS_mosaics_2025/HLS_mosaic_tile53_2025_30m
# out_datatype: int16
# projection: EPSG:3979
# IncludeAngles: False
# SsrData: {'NAME': 'HLS_SR', 'SSR_CODE': 102, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07'], 'SIX_BANDS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07'], 'NoA_BANDS': ['B04', 'B05', 'B06', 'B07'], 'LEAF_BANDS': ['B03', 'B04', 'B05', 'B06', 'B07'], 'ANGLE_BANDS': ['VZA', 'VAA', 'SZA', 'SAA'], 'CLOUD': 'CLOUD_COVERAGE', 'BLU': 'B02', 'GRN': 'B03', 'RED': 'B04', 'NIR': 'B05', 'SW1': 'B06', 'SW2': 'B07'}
# out_location: drive
# cloud_cover: 80
# export_style: separate
# CloudScore: False
# monthly: True
# start_dates: ['2025-05-01', '2025-06-01', '2025-07-01', '2025-08-01', '2025-09-01', '2025-10-01']
# end_dates: ['2025-05-31', '2025-06-30', '2025-07-31', '2025-08-31', '2025-09-30', '2025-10-31']
# current_time: 0
# scene_ID:
# regions: {'tile53_411': {'type': 'Polygon', 'coordinates': [[[-106.7964, 51.382600000000004], [-105.72760000000001, 46.995], [-99.4401, 47.4739], [-99.91929999999999, 51.918000000000006], [-106.7964, 51.382600000000004]]]}, 'tile53_412': {'type': 'Polygon', 'coordinates': [[[-100.3193, 51.918000000000006], [-99.8401, 47.4739], [-93.4721, 47.578799999999994], [-93.3344, 52.0354], [-100.3193, 51.918000000000006]]]}}
# current_region: tile53_411
# Criteria: {'timeframe': '2025-05-01/2025-05-31', 'filters': {'eo:cloud_cover': {'lt': 80}}, 'region': {'type': 'Polygon', 'coordinates': [[[-106.7964, 51.382600000000004], [-105.72760000000001, 46.995], [-99.4401, 47.4739], [-99.91929999999999, 51.918000000000006], [-106.7964, 51.382600000000004]]]}, 'collection': ['HLSS30_2.0', 'HLSL30_2.0'], 'bands': {'S2': ['B02', 'B03', 'B04', 'B08', 'B11', 'B12', 'Fmask'], 'LS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'Fmask'], 'angle': ['SZA', 'SAA', 'VZA', 'VAA']}, 'catalog': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD'}
# standardized: True
# number_workers: 10
# debug: True
# entire_tile: False
# nodes: 1
# node_memory: 50G
# chunk_size: {'x': 4096, 'y': 4096}
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-106.7964, 51.382600000000004], [-105.72760000000001, 46.995], [-99.4401, 47.4739], [-99.91929999999999, 51.918000000000006], [-106.7964, 51.382600000000004]]]}
#
# <one_mosaic> A total of 683 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T13UET.2025121T180919.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.jpg
# Asset key: B07, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B07.tif
# Asset key: B03, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B03.tif
# Asset key: SAA, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.SAA.tif
# Asset key: B8A, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B8A.tif
# Asset key: VAA, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.VAA.tif
# Asset key: B04, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B04.tif
# Asset key: B08, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B08.tif
# Asset key: B06, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B06.tif
# Asset key: Fmask, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.Fmask.tif
# Asset key: B02, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B02.tif
# Asset key: B10, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B10.tif
# Asset key: SZA, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.SZA.tif
# Asset key: B05, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B05.tif
# Asset key: B12, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B12.tif
# Asset key: B01, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B01.tif
# Asset key: B11, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B11.tif
# Asset key: VZA, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.VZA.tif
# Asset key: B09, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B09.tif
# Asset key: s3_B07, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B07.tif
# Asset key: s3_B03, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B03.tif
# Asset key: s3_SAA, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.SAA.tif
# Asset key: s3_B8A, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B8A.tif
# Asset key: s3_VAA, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.VAA.tif
# Asset key: s3_B04, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B04.tif
# Asset key: s3_B08, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B08.tif
# Asset key: s3_B06, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B06.tif
# Asset key: s3_Fmask, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.Fmask.tif
# Asset key: s3_B02, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B02.tif
# Asset key: s3_B10, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B10.tif
# Asset key: s3_SZA, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.SZA.tif
# Asset key: s3_B05, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B05.tif
# Asset key: s3_B12, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B12.tif
# Asset key: s3_B01, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B01.tif
# Asset key: s3_B11, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B11.tif
# Asset key: s3_VZA, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.VZA.tif
# Asset key: s3_B09, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13UET.2025121T180919.v2.0/HLS.S30.T13UET.2025121T180919.v2.0.B09.tif
# Asset key: metadata, title: CMR XML metadata for G3519188077-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3519188077-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: HLS.S30.T13UET.2025121T180919.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-104.4539081, 51.3619691], [-103.9371618, 52.3456932], [-105.0002936, 52.3504732], [-105.0002873, 51.3632417], [-104.4539081, 51.3619691]]]}
# Bounding Box: [-105.0002936, 51.3619691, -103.9371618, 52.3504732]
# Datetime: 2025-05-01 18:19:39.556000+00:00
# cloud cover: 62
# Properties:
#   <datetime>: 2025-05-01T18:19:39.556Z
#   <eo:cloud_cover>: 62
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2025-05-01T18:19:39.556Z
#   <end_datetime>: 2025-05-01T18:19:39.556Z
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 11GB
# Dimensions:      (y: 16588, x: 16140)
# Coordinates:
#   * y            (y) float64 133kB 3.391e+05 3.391e+05 ... -1.584e+05 -1.585e+05
#   * x            (x) float64 129kB -8.188e+05 -8.188e+05 ... -3.346e+05
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-05-01T18:19:39.556000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     sensor       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 42
#
# <<<<<< The unique granule tiles =  ['T13UET', 'T13UES', 'T13UGT', 'T13UGS', 'T13TGN', 'T14ULC', 'T13UFP', 'T14TLT', 'T13UDS', 'T13UER', 'T13UCS', 'T14ULB', 'T14ULA', 'T14UMV', 'T14ULV', 'T13UGQ', 'T13UFQ', 'T14ULU', 'T13UGP', 'T13TFN', 'T13UDT', 'T14UMC', 'T13UGR', 'T14UMU', 'T13UFR', 'T13UDP', 'T14UMB', 'T14UMA', 'T13UFS', 'T13UDR', 'T13UEQ', 'T13UEP', 'T13TEN', 'T14TMT', 'T13UDQ', 'T12UYC', 'T13UFT', 'T13UCT', 'T12UYB', 'T13UCR', 'T13UCQ', 'T13TDN']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 223.57 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.00 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
# ERROR:asyncio:Exception in callback BaseIOStream.write.<locals>.<lambda>() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\iostream.py:536
# handle: <Handle BaseIOStream.write.<locals>.<lambda>() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\iostream.py:536>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\iostream.py", line 536, in <lambda>
#     future.add_done_callback(lambda f: f.exception())
#                                        ~~~~~~~~~~~^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 106, in _needs_document_lock_wrapper
#     await p
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\views\ws.py", line 284, in send_message
#     await message.send(self)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\protocol\message.py", line 325, in send
#     sent += await self.write_buffers(conn, locked=False)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\protocol\message.py", line 269, in write_buffers
#     await conn.write_message(header, locked=locked)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\views\ws.py", line 300, in write_message
#     await super().write_message(message, binary)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\websocket.py", line 1113, in wrapper
#     await fut
# asyncio.exceptions.CancelledError
# <<<<<< The total elapsed time for mosaic generation = 122.31 minutes >>>>>>
# File 'E:\HLS_mosaics_2025\HLS_mosaic_tile53_2025_30m\log_00a2d5ee-2845-46c5-a497-7d1f38f69430.out' does not exist.
# Directory 'E:\HLS_mosaics_2025\HLS_mosaic_tile53_2025_30m\dask_spill_00a2d5ee-2845-46c5-a497-7d1f38f69430' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-106.7964, 51.382600000000004], [-105.72760000000001, 46.995], [-99.4401, 47.4739], [-99.91929999999999, 51.918000000000006], [-106.7964, 51.382600000000004]]]}
#
# <one_mosaic> A total of 606 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T14UMC.2025152T173909.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.jpg
# Asset key: B09, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B09.tif
# Asset key: B02, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B02.tif
# Asset key: B05, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B05.tif
# Asset key: VZA, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.VZA.tif
# Asset key: B07, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B07.tif
# Asset key: SAA, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.SAA.tif
# Asset key: B08, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B08.tif
# Asset key: B06, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B06.tif
# Asset key: B12, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B12.tif
# Asset key: SZA, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.SZA.tif
# Asset key: B04, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B04.tif
# Asset key: B01, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B01.tif
# Asset key: B11, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B11.tif
# Asset key: B8A, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B8A.tif
# Asset key: VAA, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.VAA.tif
# Asset key: B10, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B10.tif
# Asset key: Fmask, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.Fmask.tif
# Asset key: B03, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B03.tif
# Asset key: s3_B09, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B09.tif
# Asset key: s3_B02, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B02.tif
# Asset key: s3_B05, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B05.tif
# Asset key: s3_VZA, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.VZA.tif
# Asset key: s3_B07, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B07.tif
# Asset key: s3_SAA, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.SAA.tif
# Asset key: s3_B08, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B08.tif
# Asset key: s3_B06, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B06.tif
# Asset key: s3_B12, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B12.tif
# Asset key: s3_SZA, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.SZA.tif
# Asset key: s3_B04, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B04.tif
# Asset key: s3_B01, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B01.tif
# Asset key: s3_B11, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B11.tif
# Asset key: s3_B8A, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B8A.tif
# Asset key: s3_VAA, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.VAA.tif
# Asset key: s3_B10, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B10.tif
# Asset key: s3_Fmask, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.Fmask.tif
# Asset key: s3_B03, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025152T173909.v2.0/HLS.S30.T14UMC.2025152T173909.v2.0.B03.tif
# Asset key: metadata, title: CMR XML metadata for G3558969994-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3558969994-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: HLS.S30.T14UMC.2025152T173909.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-100.4366949, 51.3544324], [-98.8598112, 51.3631578], [-98.8567092, 52.3503863], [-100.4684711, 52.3413478], [-100.4366949, 51.3544324]]]}
# Bounding Box: [-100.4684711, 51.3544324, -98.8567092, 52.3503863]
# Datetime: 2025-06-01 17:49:34.922000+00:00
# cloud cover: 36
# Properties:
#   <datetime>: 2025-06-01T17:49:34.922Z
#   <eo:cloud_cover>: 36
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2025-06-01T17:49:34.922Z
#   <end_datetime>: 2025-06-01T17:49:34.922Z
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 11GB
# Dimensions:      (y: 16588, x: 16140)
# Coordinates:
#   * y            (y) float64 133kB 3.391e+05 3.391e+05 ... -1.584e+05 -1.585e+05
#   * x            (x) float64 129kB -8.188e+05 -8.188e+05 ... -3.346e+05
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-06-01T17:49:34.922000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     sensor       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 42
#
# <<<<<< The unique granule tiles =  ['T13UDP', 'T13UET', 'T13UES', 'T13UGT', 'T13UER', 'T13UDT', 'T14ULC', 'T13UFQ', 'T14UMV', 'T13UFP', 'T13TFN', 'T13UGS', 'T13UEQ', 'T13TDN', 'T14UMC', 'T14TLT', 'T13TGN', 'T13TEN', 'T13UDR', 'T14UMB', 'T14ULB', 'T14UMA', 'T14ULA', 'T13UGR', 'T14ULV', 'T14ULU', 'T13UGP', 'T13UFS', 'T13UDQ', 'T13UCQ', 'T13UCS', 'T13UGQ', 'T13UFT', 'T13UFR', 'T13UEP', 'T13UCR', 'T13UDS', 'T13UCT', 'T12UYC', 'T14UMU', 'T14TMT', 'T12UYB']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 224.58 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.00 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation = 113.77 minutes >>>>>>
# File 'E:\HLS_mosaics_2025\HLS_mosaic_tile53_2025_30m\log_a34c76e6-8b23-4e97-85f7-27c4baf9fa13.out' does not exist.
# Directory 'E:\HLS_mosaics_2025\HLS_mosaic_tile53_2025_30m\dask_spill_a34c76e6-8b23-4e97-85f7-27c4baf9fa13' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-106.7964, 51.382600000000004], [-105.72760000000001, 46.995], [-99.4401, 47.4739], [-99.91929999999999, 51.918000000000006], [-106.7964, 51.382600000000004]]]}
#
# <one_mosaic> A total of 678 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T14UMC.2025182T173909.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.jpg
# Asset key: B8A, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.B8A.tif
# Asset key: B05, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.B05.tif
# Asset key: B02, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.B02.tif
# Asset key: VAA, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.VAA.tif
# Asset key: B10, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.B10.tif
# Asset key: SAA, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.SAA.tif
# Asset key: B01, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.B01.tif
# Asset key: B12, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.B12.tif
# Asset key: B08, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.B08.tif
# Asset key: SZA, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.SZA.tif
# Asset key: B09, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.B09.tif
# Asset key: B11, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.B11.tif
# Asset key: VZA, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.VZA.tif
# Asset key: B04, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.B04.tif
# Asset key: B03, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.B03.tif
# Asset key: Fmask, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.Fmask.tif
# Asset key: B07, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.B07.tif
# Asset key: B06, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.B06.tif
# Asset key: s3_B8A, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.B8A.tif
# Asset key: s3_B05, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.B05.tif
# Asset key: s3_B02, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.B02.tif
# Asset key: s3_VAA, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.VAA.tif
# Asset key: s3_B10, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.B10.tif
# Asset key: s3_SAA, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.SAA.tif
# Asset key: s3_B01, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T14UMC.2025182T173909.v2.0/HLS.S30.T14UMC.2025182T173909.v2.0.B01.tif
# ...
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =  72.04 minutes >>>>>>
# File 'E:\HLS_mosaics_2025\HLS_mosaic_tile53_2025_30m\log_9f614254-b808-43bc-9f69-e6fa33c05e02.out' does not exist.
# Directory 'E:\HLS_mosaics_2025\HLS_mosaic_tile53_2025_30m\dask_spill_9f614254-b808-43bc-9f69-e6fa33c05e02' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-100.3193, 51.918000000000006], [-99.8401, 47.4739], [-93.4721, 47.578799999999994], [-93.3344, 52.0354], [-100.3193, 51.918000000000006]]]}
#
# <one_mosaic> A total of 528 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T15UVT.2025274T173141.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.jpg
# Asset key: B10, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B10.tif
# Asset key: B02, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B02.tif
# Asset key: B11, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B11.tif
# Asset key: B05, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B05.tif
# Asset key: B09, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B09.tif
# Asset key: B12, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B12.tif
# Asset key: B03, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B03.tif
# Asset key: SAA, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.SAA.tif
# Asset key: VZA, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.VZA.tif
# Asset key: VAA, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.VAA.tif
# Asset key: B06, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B06.tif
# Asset key: Fmask, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.Fmask.tif
# Asset key: B04, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B04.tif
# Asset key: B08, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B08.tif
# Asset key: B01, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B01.tif
# Asset key: SZA, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.SZA.tif
# Asset key: B8A, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B8A.tif
# Asset key: B07, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B07.tif
# Asset key: s3_B10, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B10.tif
# Asset key: s3_B02, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B02.tif
# Asset key: s3_B11, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B11.tif
# Asset key: s3_B05, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B05.tif
# Asset key: s3_B09, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B09.tif
# Asset key: s3_B12, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B12.tif
# Asset key: s3_B03, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B03.tif
# Asset key: s3_SAA, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.SAA.tif
# Asset key: s3_VZA, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.VZA.tif
# Asset key: s3_VAA, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.VAA.tif
# Asset key: s3_B06, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B06.tif
# Asset key: s3_Fmask, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.Fmask.tif
# Asset key: s3_B04, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B04.tif
# Asset key: s3_B08, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B08.tif
# Asset key: s3_B01, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B01.tif
# Asset key: s3_SZA, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.SZA.tif
# Asset key: s3_B8A, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B8A.tif
# Asset key: s3_B07, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15UVT.2025274T173141.v2.0/HLS.S30.T15UVT.2025274T173141.v2.0.B07.tif
# Asset key: metadata, title: CMR XML metadata for G3786613696-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3786613696-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: HLS.S30.T15UVT.2025274T173141.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-94.4366949, 51.3544324], [-94.3841822, 51.3561438], [-93.8643907, 52.3473116], [-94.4684711, 52.3413478], [-94.4366949, 51.3544324]]]}
# Bounding Box: [-94.4684711, 51.3544324, -93.8643907, 52.3473116]
# Datetime: 2025-10-01 17:39:33.529000+00:00
# cloud cover: 62
# Properties:
#   <datetime>: 2025-10-01T17:39:33.529Z
#   <eo:cloud_cover>: 62
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2025-10-01T17:39:33.529Z
#   <end_datetime>: 2025-10-01T17:39:33.529Z
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 11GB
# Dimensions:      (y: 16504, x: 16080)
# Coordinates:
#   * y            (y) float64 132kB 3.38e+05 3.38e+05 ... -1.571e+05 -1.571e+05
#   * x            (x) float64 129kB -3.668e+05 -3.667e+05 ... 1.156e+05 1.156e+05
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-10-01T17:39:33.529000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     sensor       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 37
#
# <<<<<< The unique granule tiles =  ['T14TQT', 'T14TNT', 'T14UQU', 'T15UUP', 'T15UUQ', 'T15UVP', 'T14TPT', 'T14UPB', 'T14UQV', 'T15TVN', 'T14UPA', 'T14UMA', 'T14UPU', 'T15TUN', 'T14UPC', 'T15UUR', 'T14TMT', 'T14UPV', 'T15UVS', 'T14UMB', 'T14UNV', 'T14UNU', 'T14UMU', 'T15UVQ', 'T15UVT', 'T15UUT', 'T14UQC', 'T14UMV', 'T14UQA', 'T15UVR', 'T14UNC', 'T15UUS', 'T14UQB', 'T14UNB', 'T14UNA', 'T14ULC', 'T14UMC']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 164.05 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.98 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.98 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.98 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.98 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.98 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.98 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.98 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 0.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.98 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.98 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =  67.19 minutes >>>>>>
# File 'E:\HLS_mosaics_2025\HLS_mosaic_tile53_2025_30m\log_70ac8192-c4ba-46bc-8ac9-ff7fb8f6a54e.out' does not exist.
# Directory 'E:\HLS_mosaics_2025\HLS_mosaic_tile53_2025_30m\dask_spill_70ac8192-c4ba-46bc-8ac9-ff7fb8f6a54e' and its contents have been deleted.
