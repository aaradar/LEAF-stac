# %%
import os
import sys

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

# %%
ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

CompParams = {
  "debug"       : True,
  "entire_tile" : False,     #
  "nodes"       : 1,
  "node_memory" : "14G",
  "number_workers" : 4
}

  
ProdParams = {
    'sensor': 'HLS_SR',       # A sensor type string (e.g., 'S2_SR' or 'HLSS30_SR' or 'MOD_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2024,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    'months': [8],            # A list of integers represening one or multiple monthes     
    'tile_names': ['tile55_922'], # A list of (sub-)tile names (defined using CCRS' tile griding system) 
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution': 200,            # Exporting spatial resolution    
    'out_folder': 'C:/Work_Data/HLS_mosaic_tile55_922_2024_200m_new_mask',  # the folder name for exporting
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    #'start_dates': ['2024-06-15'],
    #'end_dates': ['2024-09-15'],
    #'regions': {'ottawa': ottawa_region, 'vancouver': vancouver_region}    
}

# %%
main(ProdParams, CompParams)
# Out:
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-76.12, 45.184], [-75.383, 45.171], [-75.39, 45.564], [-76.105, 45.568], [-76.12, 45.184]]]}
#
# <period_mosaic> A total of 13 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T18TVR.2022213T155911.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.jpg
# Asset key: VAA, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.VAA.tif
# Asset key: B04, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B04.tif
# Asset key: B08, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B08.tif
# Asset key: B02, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B02.tif
# Asset key: B11, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B11.tif
# Asset key: B10, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B10.tif
# Asset key: VZA, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.VZA.tif
# Asset key: Fmask, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.Fmask.tif
# Asset key: B06, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B06.tif
# Asset key: B05, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B05.tif
# Asset key: B07, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B07.tif
# Asset key: SAA, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.SAA.tif
# Asset key: B12, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B12.tif
# Asset key: B03, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B03.tif
# Asset key: SZA, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.SZA.tif
# Asset key: B8A, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B8A.tif
# Asset key: B01, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B01.tif
# Asset key: B09, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B09.tif
# Asset key: s3_VAA, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.VAA.tif
# Asset key: s3_B04, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B04.tif
# Asset key: s3_B08, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B08.tif
# Asset key: s3_B02, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B02.tif
# Asset key: s3_B11, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B11.tif
# Asset key: s3_B10, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B10.tif
# Asset key: s3_VZA, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.VZA.tif
# Asset key: s3_Fmask, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.Fmask.tif
# Asset key: s3_B06, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B06.tif
# Asset key: s3_B05, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B05.tif
# Asset key: s3_B07, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B07.tif
# Asset key: s3_SAA, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.SAA.tif
# Asset key: s3_B12, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B12.tif
# Asset key: s3_B03, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B03.tif
# Asset key: s3_SZA, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.SZA.tif
# Asset key: s3_B8A, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B8A.tif
# Asset key: s3_B01, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B01.tif
# Asset key: s3_B09, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2022213T155911.v2.0/HLS.S30.T18TVR.2022213T155911.v2.0.B09.tif
# Asset key: metadata, title: CMR XML metadata for G2383166485-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G2383166485-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# ID: HLS.S30.T18TVR.2022213T155911.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-76.2705836, 45.0581917], [-74.8760255, 45.0651927], [-74.8738328, 46.0535047], [-76.2930489, 46.0462596], [-76.2705836, 45.0581917]]]}
# Bounding Box: [-76.2930489, 45.0581917, -74.8738328, 46.0535047]
# Datetime: 2022-08-01 16:10:46.071000+00:00
# cloud cover: 67
# Properties:
#   <datetime>: 2022-08-01T16:10:46.071Z
#   <eo:cloud_cover>: 67
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2022-08-01T16:10:46.071Z
#   <end_datetime>: 2022-08-01T16:10:46.071Z
#
# <period_mosaic> based mosaic image =  <xarray.Dataset> Size: 14MB
# Dimensions:      (y: 583, x: 683)
# Coordinates:
#   * y            (y) float64 5kB -1.472e+05 -1.472e+05 ... -2.052e+05 -2.054e+05
#   * x            (x) float64 5kB 1.475e+06 1.475e+06 ... 1.543e+06 1.543e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2022-08-01T16:10:46.071000
# Data variables:
#     blue         (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     green        (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     red          (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     nir08        (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     swir16       (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     swir22       (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     Fmask        (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     date         (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     score        (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#
# <period_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['T18TVR']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
#
# <<<<<<<<<< The total elapsed time for generating the mosaic =   2.42 minutes>>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\dask\array\chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# File 'C:\Work_Data\HLS_mosaic_Ottawa_2022_100m_new_mask\log_80e5fe08-1952-49f6-b059-402e8b2f5bba.out' does not exist.
# Directory 'C:\Work_Data\HLS_mosaic_Ottawa_2022_100m_new_mask\dask_spill_80e5fe08-1952-49f6-b059-402e8b2f5bba' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-123.32, 49.37], [-122.44, 49.35], [-122.96, 48.75], [-123.27, 48.96], [-123.32, 49.37]]]}
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# File ~\STAC_python\source\eoMosaic.py:216, in search_STAC_Catalog(MosaicParams, MaxImgs)
#     215 try:
# --> 216   stac_items += items
#     217 except:
#
# File ~\AppData\Local\anaconda3\envs\stac\Lib\site-packages\pystac_client\item_search.py:746, in ItemSearch.items(self)
#     740 """Iterator that yields :class:`pystac.Item` instances for each item matching
#     741 the given search parameters.
#     742
#     743 Yields:
#     744     Item : each Item matching the search criteria
#     745 """
# --> 746 for item in self.items_as_dicts():
#     747     # already signed in items_as_dicts
#     748     yield Item.from_dict(item, root=self.client, preserve_dict=False)
#
# File ~\AppData\Local\anaconda3\envs\stac\Lib\site-packages\pystac_client\item_search.py:757, in ItemSearch.items_as_dicts(self)
#     751 """Iterator that yields :class:`dict` instances for each item matching
#     752 the given search parameters.
#     753
#     754 Yields:
#     755     Item : each Item matching the search criteria
#     756 """
# --> 757 for page in self.pages_as_dicts():
#     758     for item in page.get("features", []):
#     759         # already signed in pages_as_dicts
#
# File ~\AppData\Local\anaconda3\envs\stac\Lib\site-packages\pystac_client\item_search.py:789, in ItemSearch.pages_as_dicts(self)
#     788 num_items = 0
# --> 789 for page in self._stac_io.get_pages(
#     790     self.url, self.method, self.get_parameters()
#     791 ):
#     792     call_modifier(self.modifier, page)
#
# File ~\AppData\Local\anaconda3\envs\stac\Lib\site-packages\pystac_client\stac_api_io.py:308, in StacApiIO.get_pages(self, url, method, parameters)
#     302 """Iterator that yields dictionaries for each page at a STAC paging
#     303 endpoint, e.g., /collections, /search
#     304
#     305 Return:
#     306     Dict[str, Any] : JSON content from a single page
#     307 """
# --> 308 page = self.read_json(url, method=method, parameters=parameters)
#     309 if not (page.get("features") or page.get("collections")):
#
# File ~\AppData\Local\anaconda3\envs\stac\Lib\site-packages\pystac\stac_io.py:206, in StacIO.read_json(self, source, *args, **kwargs)
#     190 """Read a dict from the given source.
#     191
#     192 See :func:`StacIO.read_text <pystac.StacIO.read_text>` for usage of
#    (...)
#     204     given source.
#     205 """
# --> 206 txt = self.read_text(source, *args, **kwargs)
#     207 return self.json_loads(txt)
#
# File ~\AppData\Local\anaconda3\envs\stac\Lib\site-packages\pystac_client\stac_api_io.py:171, in StacApiIO.read_text(self, source, *args, **kwargs)
#     170 if _is_url(href):
# --> 171     return self.request(href, *args, **kwargs)
#     172 else:
#
# File ~\AppData\Local\anaconda3\envs\stac\Lib\site-packages\pystac_client\stac_api_io.py:223, in StacApiIO.request(self, href, method, headers, parameters)
#     222 if resp.status_code != 200:
# --> 223     raise APIError.from_response(resp)
#     224 try:
#
# APIError: {"errors":["Oops! Something has gone wrong. We have been alerted and are working to resolve the problem. Please try your request again later."]}
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 main(ProdParams, CompParams)
#
# File ~\STAC_python\Production.py:123, in main(inProdParams, inCompParams)
#     120   leaf.LEAF_production(prod_params, comp_params)
#     122 else:
# --> 123   eoMz.MosaicProduction(prod_params, comp_params)
#
# File ~\STAC_python\source\eoMosaic.py:1597, in MosaicProduction(ProdParams, CompParams)
#    1589   #out_params = compact_params(mosaic, SsrData, ClassImg)
#    1590
#    1591   # Export the 64-bits image to either GD or GCS
#    (...)
#    1594 else:
#    1595   # Produce and export vegetation parameetr maps for a time period and a region
#    1596   print('\n<MosaicProduction> Generate and export separate mosaic images......')
# -> 1597   one_mosaic(usedParams, CompParams)
#
# File ~\STAC_python\source\eoMosaic.py:1335, in one_mosaic(ProdParams, CompParams, Output)
#    1326 mosaic_start = time.time()   #Record the start time of the whole process
#    1328 #==========================================================================================================
#    1329 # Search all the STAC items based on a spatial region and a time window
#    1330 # Note: (1) The 2nd parameter (MaxImgs) for "search_STAC_Catalog" function cannot be too large. Otherwise,
#    (...)
#    1333 #           data from AWS is used.
#    1334 #==========================================================================================================
# -> 1335 stac_items = search_STAC_Catalog(ProdParams, 100)
#    1336 print(f"\n<period_mosaic> A total of {len(stac_items):d} items were found.\n")
#    1338 #When in debugging mode, display metadata assets
#
# File ~\STAC_python\source\eoMosaic.py:218, in search_STAC_Catalog(MosaicParams, MaxImgs)
#     216       stac_items += items
#     217     except:
# --> 218        raise ValueError("There is no list of STAC items found for your query. If you are using a custom region or time, please adjust and expand them accordingly.")
#     219 else:
#     220   stac_catalog = catalog.search(collections = Criteria['collection'],
#     221                                 intersects  = Region,
#     222                                 datetime    = str(Criteria['timeframe']),
#     223                                 query       = Criteria['filters'],
#     224                                 limit       = MaxImgs)
#
# ValueError: There is no list of STAC items found for your query. If you are using a custom region or time, please adjust and expand them accordingly.
