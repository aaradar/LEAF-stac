# %%
import os
import sys

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

# %%
ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

CompParams = {
  "number_workers" : 10   #For S2 data, only use 10 rather than 20
  "debug"       : True,
  "entire_tile" : False,     #
  "nodes"       : 1,
  "node_memory" : "300G",
  'chunk_size': {'x': 4000, 'y': 4000}
}

  
ProdParams = {
    'sensor': 'S2_SR',       # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR', 'HLSS30_SR' or 'MOD_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2025,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    'months': [9],            # A list of integers represening one or multiple monthes     
    'tile_names': ['tile55_922'], # A list of (sub-)tile names (defined using CCRS' tile griding system) 
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution':20,            # Exporting spatial resolution    
    'out_folder': 'C:/Work_Data/S2_mosaic_tile55_922_2025_20m',  # the folder name for exporting
    'out_datatype': 'int16',     # 'int8' or 'int16'
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    #'start_dates': ['2025-06-15'],
    #'end_dates': ['2025-09-15'],
    #'regions': {'ottawa': ottawa_region}  #, {'vancouver': vancouver_region}    
}

# %%
main(ProdParams, CompParams)
# Out:
#  <get_query_conditions> inParams = {'sensor': 'S2_SR', 'unit': 2, 'year': 2025, 'nbYears': -1, 'months': [9], 'tile_names': ['tile55_922'], 'prod_names': ['mosaic'], 'resolution': 20, 'out_folder': 'C:/Work_Data/S2_mosaic_tile55_922_2025_20m', 'out_datatype': 'int16', 'projection': 'EPSG:3979', 'IncludeAngles': False, 'SsrData': {'NAME': 'S2_SR', 'SSR_CODE': 21, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], '10M_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'SIX_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'NoA_BANDS': ['red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'LEAF_BANDS': ['green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'GEE_NAME': 'COPERNICUS/S2_SR_HARMONIZED', 'CLOUD': 'CLOUDY_PIXEL_PERCENTAGE', 'SZA': 'view:sun_elevation', 'SAA': 'view:sun_azimuth', 'VZA': 'view:sun_elevation', 'VAA': 'view:sun_azimuth', 'BLU': 'blue', 'GRN': 'green', 'RED': 'red', 'NIR': 'nir08', 'SW1': 'swir16', 'SW2': 'swir22'}, 'out_location': 'drive', 'cloud_cover': 80, 'export_style': 'separate', 'monthly': True, 'start_dates': ['2025-09-01'], 'end_dates': ['2025-09-30'], 'current_time': 0, 'scene_ID': '', 'regions': {'tile55_922': {'type': 'Polygon', 'coordinates': [[[-77.6221, 47.5314], [-78.6303, 44.9569], [-75.0742, 44.2113], [-73.8758, 46.7329], [-77.6221, 47.5314]]]}}, 'current_region': 'tile55_922'}
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-77.6221, 47.5314], [-78.6303, 44.9569], [-75.0742, 44.2113], [-73.8758, 46.7329], [-77.6221, 47.5314]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.09 minutes
#
# <period_mosaic> A total of 208 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/9/S2B_17TPL_20250929_0_L2A/AOT.tif
# Asset key: blue, title: Blue - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/9/S2B_17TPL_20250929_0_L2A/B02.tif
# Asset key: cloud, title: Cloud Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/9/29/0/qi/CLD_20m.jp2
# Asset key: coastal, title: Coastal - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/9/S2B_17TPL_20250929_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/9/S2B_17TPL_20250929_0_L2A/granule_metadata.xml
# Asset key: green, title: Green - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/9/S2B_17TPL_20250929_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/9/S2B_17TPL_20250929_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/9/S2B_17TPL_20250929_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/9/S2B_17TPL_20250929_0_L2A/B09.tif
# Asset key: product_metadata, title: None, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/9/29/0/product_metadata.xml
# Asset key: red, title: Red - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/9/S2B_17TPL_20250929_0_L2A/B04.tif
# Asset key: rededge1, title: Red Edge 1 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/9/S2B_17TPL_20250929_0_L2A/B05.tif
# Asset key: rededge2, title: Red Edge 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/9/S2B_17TPL_20250929_0_L2A/B06.tif
# Asset key: rededge3, title: Red Edge 3 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/9/S2B_17TPL_20250929_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/9/S2B_17TPL_20250929_0_L2A/SCL.tif
# Asset key: snow, title: Snow Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/9/29/0/qi/SNW_20m.jp2
# Asset key: swir16, title: SWIR 1.6μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/9/S2B_17TPL_20250929_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2.2μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/9/S2B_17TPL_20250929_0_L2A/B12.tif
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/9/S2B_17TPL_20250929_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/9/S2B_17TPL_20250929_0_L2A/TCI.tif
# Asset key: wvp, title: Water Vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/9/S2B_17TPL_20250929_0_L2A/WVP.tif
# Asset key: thumbnail, title: Thumbnail of preview image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/9/S2B_17TPL_20250929_0_L2A/preview.jpg
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/9/29/0/R20m/AOT.jp2
# Asset key: blue-jp2, title: Blue - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/9/29/0/R10m/B02.jp2
# Asset key: coastal-jp2, title: Coastal - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/9/29/0/R60m/B01.jp2
# Asset key: green-jp2, title: Green - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/9/29/0/R10m/B03.jp2
# Asset key: nir-jp2, title: NIR 1 - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/9/29/0/R10m/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/9/29/0/R20m/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/9/29/0/R60m/B09.jp2
# Asset key: red-jp2, title: Red - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/9/29/0/R10m/B04.jp2
# Asset key: rededge1-jp2, title: Red Edge 1 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/9/29/0/R20m/B05.jp2
# Asset key: rededge2-jp2, title: Red Edge 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/9/29/0/R20m/B06.jp2
# Asset key: rededge3-jp2, title: Red Edge 3 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/9/29/0/R20m/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/9/29/0/R20m/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1.6μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/9/29/0/R20m/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2.2μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/9/29/0/R20m/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/9/29/0/R10m/TCI.jp2
# Asset key: wvp-jp2, title: Water Vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/9/29/0/R20m/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# ID: S2B_17TPL_20250929_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-78.33777624295573, 45.03422901836111], [-78.31579245111705, 45.51797449235688], [-78.48078281488912, 45.03747525820727], [-78.33777624295573, 45.03422901836111]]]}
# Bounding Box: [-78.480783, 45.034229, -78.315792, 45.517974]
# Datetime: 2025-09-29 16:10:50.560000+00:00
# cloud cover: 0
# Properties:
#   <created>: 2025-09-29T22:02:04.522Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 0
#   <proj:centroid>: {'lat': 45.19656, 'lon': -78.37812}
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: PL
#   <grid:code>: MGRS-17TPL
#   <view:azimuth>: 109.8562241407683
#   <view:incidence_angle>: 11.541872085823861
#   <view:sun_azimuth>: 161.724330143026
#   <view:sun_elevation>: 40.2152129880652
#   <s2:tile_id>: S2B_OPER_MSI_L2A_TL_2BPS_20250929T211149_A044739_T17TPL_N05.11
#   <s2:degraded_msi_data_percentage>: 0
#   <s2:nodata_pixel_percentage>: 97.379315
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:cloud_shadow_percentage>: 0
#   <s2:vegetation_percentage>: 86.33827
#   <s2:not_vegetated_percentage>: 2.691175
#   <s2:water_percentage>: 10.925105
#   <s2:unclassified_percentage>: 0.00595
#   <s2:medium_proba_clouds_percentage>: 0
#   <s2:high_proba_clouds_percentage>: 0
#   <s2:thin_cirrus_percentage>: 0
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.11
#   <s2:product_uri>: S2B_MSIL2A_20250929T155949_N0511_R097_T17TPL_20250929T211149.SAFE
#   <s2:generation_time>: 2025-09-29T21:11:49.000000Z
#   <s2:datatake_id>: GS2B_20250929T155949_044739_N05.11
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_2BPS_20250929T211149_S20250929T160136_N05.11
#   <s2:reflectance_conversion_factor>: 0.995188591119387
#   <datetime>: 2025-09-29T16:10:50.560000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/PL/2025/9/S2B_17TPL_20250929_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/455a5aa949f4bed41218e2108707e936
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '2025.03.06'}
#   <updated>: 2025-09-29T22:02:04.522Z
#   <proj:code>: EPSG:32617
#   <sza>: 49.7847870119348
#   <saa>: 161.724330143026
#   <vza>: 11.5778728260141
#   <vaa>: 111.675890928405
#
# <period_mosaic> based mosaic image =  <xarray.Dataset> Size: 11GB
# Dimensions:      (y: 15001, x: 15002)
# Coordinates:
#   * y            (y) float64 120kB 1.493e+04 1.491e+04 ... -2.85e+05 -2.851e+05
#   * x            (x) float64 120kB 1.3e+06 1.3e+06 1.3e+06 ... 1.6e+06 1.6e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-09-29T16:10:50.560000
# Data variables:
#     blue         (y, x) float32 900MB dask.array<chunksize=(4000, 4000), meta=np.ndarray>
#     green        (y, x) float32 900MB dask.array<chunksize=(4000, 4000), meta=np.ndarray>
#     red          (y, x) float32 900MB dask.array<chunksize=(4000, 4000), meta=np.ndarray>
#     rededge1     (y, x) float32 900MB dask.array<chunksize=(4000, 4000), meta=np.ndarray>
#     rededge2     (y, x) float32 900MB dask.array<chunksize=(4000, 4000), meta=np.ndarray>
#     rededge3     (y, x) float32 900MB dask.array<chunksize=(4000, 4000), meta=np.ndarray>
#     nir08        (y, x) float32 900MB dask.array<chunksize=(4000, 4000), meta=np.ndarray>
#     swir16       (y, x) float32 900MB dask.array<chunksize=(4000, 4000), meta=np.ndarray>
#     swir22       (y, x) float32 900MB dask.array<chunksize=(4000, 4000), meta=np.ndarray>
#     scl          (y, x) float32 900MB dask.array<chunksize=(4000, 4000), meta=np.ndarray>
#     date         (y, x) float32 900MB dask.array<chunksize=(4000, 4000), meta=np.ndarray>
#     score        (y, x) float32 900MB dask.array<chunksize=(4000, 4000), meta=np.ndarray>
#
# <period_mosaic> The number of unique granule tiles = 19
#
# <<<<<< The unique granule tiles =  ['18TVT', '18TVR', '18TWT', '18TWS', '18TUR', '18TVS', '18TUQ', '17TPK', '18TWR', '17TQL', '17TQK', '18TWQ', '17TQN', '18TVQ', '18TVP', '17TQM', '18TUS', '18TUT', '17TPL']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 103.32 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< The total elapsed time for generating the mosaic =  46.52 minutes>>>>>>>>>
# File 'C:\Work_Data\S2_mosaic_tile55_922_2025_20m\log_9a6ebe71-9741-4c52-ad55-cc0a8283b8f1.out' does not exist.
# Directory 'C:\Work_Data\S2_mosaic_tile55_922_2025_20m\dask_spill_9a6ebe71-9741-4c52-ad55-cc0a8283b8f1' and its contents have been deleted.
