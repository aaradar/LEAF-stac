# %%
import os
import sys

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

# %%
ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

CompParams = {
  "number_workers" : 8,   #For S2 data, only use 10 rather than 20
  "worker_threads": 1,
  "debug"       : True,
  "entire_tile" : False,     #
  "nodes"       : 1,
  "node_memory" : "64G",
  'chunk_size': {'x': 4096, 'y': 4096}
}

  
ProdParams = {
    'sensor': 'HLS_SR',       # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR', 'HLSS30_SR' or 'MOD_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2025,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    'months': [7],            # A list of integers represening one or multiple monthes     
    'tile_names': ['tile55_922'], # A list of (sub-)tile names (defined using CCRS' tile griding system) 
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution':30,            # Exporting spatial resolution    
    'out_folder': 'C:/Work_Data/HLS_mosaic_tile55_922_2025_20m',  # the folder name for exporting
    'out_datatype': 'int16',     # 'int8' or 'int16'
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    #'start_dates': ['2025-06-15'],
    #'end_dates': ['2025-09-15'],
    #'regions': {'ottawa': ottawa_region}  #, {'vancouver': vancouver_region}    
}

# %%
main(ProdParams, CompParams)
# Out:
#  <get_query_conditions> inParams = {'sensor': 'S2_SR', 'unit': 2, 'year': 2025, 'nbYears': -1, 'months': [5], 'tile_names': ['tile55_922'], 'prod_names': ['mosaic'], 'resolution': 20, 'out_folder': 'C:/Work_Data/S2_mosaic_tile55_922_2025_20m', 'out_datatype': 'int16', 'projection': 'EPSG:3979', 'IncludeAngles': False, 'SsrData': {'NAME': 'S2_SR', 'SSR_CODE': 21, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], '10M_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'SIX_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'NoA_BANDS': ['red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'LEAF_BANDS': ['green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'GEE_NAME': 'COPERNICUS/S2_SR_HARMONIZED', 'CLOUD': 'CLOUDY_PIXEL_PERCENTAGE', 'SZA': 'view:sun_elevation', 'SAA': 'view:sun_azimuth', 'VZA': 'view:sun_elevation', 'VAA': 'view:sun_azimuth', 'BLU': 'blue', 'GRN': 'green', 'RED': 'red', 'NIR': 'nir08', 'SW1': 'swir16', 'SW2': 'swir22'}, 'out_location': 'drive', 'cloud_cover': 80, 'export_style': 'separate', 'monthly': True, 'start_dates': ['2025-05-01'], 'end_dates': ['2025-05-31'], 'current_time': 0, 'scene_ID': '', 'regions': {'tile55_922': {'type': 'Polygon', 'coordinates': [[[-77.6221, 47.5314], [-78.6303, 44.9569], [-75.0742, 44.2113], [-73.8758, 46.7329], [-77.6221, 47.5314]]]}}, 'current_region': 'tile55_922'}
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-77.6221, 47.5314], [-78.6303, 44.9569], [-75.0742, 44.2113], [-73.8758, 46.7329], [-77.6221, 47.5314]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.07 minutes
#
# <period_mosaic> A total of 101 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/5/S2C_17TPL_20250527_0_L2A/AOT.tif
# Asset key: blue, title: Blue - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/5/S2C_17TPL_20250527_0_L2A/B02.tif
# Asset key: cloud, title: Cloud Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/5/27/0/qi/CLD_20m.jp2
# Asset key: coastal, title: Coastal - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/5/S2C_17TPL_20250527_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/5/S2C_17TPL_20250527_0_L2A/granule_metadata.xml
# Asset key: green, title: Green - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/5/S2C_17TPL_20250527_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/5/S2C_17TPL_20250527_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/5/S2C_17TPL_20250527_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/5/S2C_17TPL_20250527_0_L2A/B09.tif
# Asset key: product_metadata, title: None, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/5/27/0/product_metadata.xml
# Asset key: red, title: Red - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/5/S2C_17TPL_20250527_0_L2A/B04.tif
# Asset key: rededge1, title: Red Edge 1 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/5/S2C_17TPL_20250527_0_L2A/B05.tif
# Asset key: rededge2, title: Red Edge 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/5/S2C_17TPL_20250527_0_L2A/B06.tif
# Asset key: rededge3, title: Red Edge 3 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/5/S2C_17TPL_20250527_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/5/S2C_17TPL_20250527_0_L2A/SCL.tif
# Asset key: snow, title: Snow Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/5/27/0/qi/SNW_20m.jp2
# Asset key: swir16, title: SWIR 1.6μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/5/S2C_17TPL_20250527_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2.2μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/5/S2C_17TPL_20250527_0_L2A/B12.tif
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/5/S2C_17TPL_20250527_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/5/S2C_17TPL_20250527_0_L2A/TCI.tif
# Asset key: wvp, title: Water Vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/5/S2C_17TPL_20250527_0_L2A/WVP.tif
# Asset key: thumbnail, title: Thumbnail of preview image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PL/2025/5/S2C_17TPL_20250527_0_L2A/preview.jpg
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/5/27/0/R20m/AOT.jp2
# Asset key: blue-jp2, title: Blue - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/5/27/0/R10m/B02.jp2
# Asset key: coastal-jp2, title: Coastal - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/5/27/0/R60m/B01.jp2
# Asset key: green-jp2, title: Green - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/5/27/0/R10m/B03.jp2
# Asset key: nir-jp2, title: NIR 1 - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/5/27/0/R10m/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/5/27/0/R20m/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/5/27/0/R60m/B09.jp2
# Asset key: red-jp2, title: Red - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/5/27/0/R10m/B04.jp2
# Asset key: rededge1-jp2, title: Red Edge 1 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/5/27/0/R20m/B05.jp2
# Asset key: rededge2-jp2, title: Red Edge 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/5/27/0/R20m/B06.jp2
# Asset key: rededge3-jp2, title: Red Edge 3 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/5/27/0/R20m/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/5/27/0/R20m/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1.6μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/5/27/0/R20m/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2.2μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/5/27/0/R20m/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/5/27/0/R10m/TCI.jp2
# Asset key: wvp-jp2, title: Water Vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/PL/2025/5/27/0/R20m/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# ID: S2C_17TPL_20250527_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-78.33777624233485, 45.03422901834663], [-78.31485147591292, 45.53771678014865], [-78.48598345466779, 45.03758993110655], [-78.33777624233485, 45.03422901834663]]]}
# Bounding Box: [-78.485983, 45.034229, -78.314851, 45.537717]
# Datetime: 2025-05-27 16:11:09.978000+00:00
# cloud cover: 28.651902
# Properties:
#   <created>: 2025-05-28T00:36:56.978Z
#   <platform>: sentinel-2c
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 28.651902
#   <proj:centroid>: {'lat': 45.20318, 'lon': -78.37954}
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: PL
#   <grid:code>: MGRS-17TPL
#   <view:azimuth>: 109.22312888668269
#   <view:incidence_angle>: 11.563291484942024
#   <view:sun_azimuth>: 147.018767786472
#   <view:sun_elevation>: 62.7200369956537
#   <s2:tile_id>: S2C_OPER_MSI_L2A_TL_2CPS_20250527T231418_A003785_T17TPL_N05.11
#   <s2:degraded_msi_data_percentage>: 0
#   <s2:nodata_pixel_percentage>: 97.177583
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:cloud_shadow_percentage>: 9.273522
#   <s2:vegetation_percentage>: 51.200217
#   <s2:not_vegetated_percentage>: 0.48667
#   <s2:water_percentage>: 8.535054
#   <s2:unclassified_percentage>: 1.408755
#   <s2:medium_proba_clouds_percentage>: 9.161142
#   <s2:high_proba_clouds_percentage>: 13.64767
#   <s2:thin_cirrus_percentage>: 5.84309
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.11
#   <s2:product_uri>: S2C_MSIL2A_20250527T155841_N0511_R097_T17TPL_20250527T231418.SAFE
#   <s2:generation_time>: 2025-05-27T23:14:18.000000Z
#   <s2:datatake_id>: GS2C_20250527T155841_003785_N05.11
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2C_OPER_MSI_L2A_DS_2CPS_20250527T231418_S20250527T160259_N05.11
#   <s2:reflectance_conversion_factor>: 0.975397392718893
#   <datetime>: 2025-05-27T16:11:09.978000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/PL/2025/5/S2C_17TPL_20250527_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/9c21063e2993002e85bc86180643e69c
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '2025.03.06'}
#   <updated>: 2025-05-28T00:36:56.978Z
#   <proj:code>: EPSG:32617
#   <sza>: 27.2799630043463
#   <saa>: 147.018767786472
#   <vza>: 11.5974215381882
#   <vaa>: 111.069189169068
#
# <period_mosaic> based mosaic image =  <xarray.Dataset> Size: 11GB
# Dimensions:      (y: 15001, x: 15002)
# Coordinates:
#   * y            (y) float64 120kB 1.493e+04 1.491e+04 ... -2.85e+05 -2.851e+05
#   * x            (x) float64 120kB 1.3e+06 1.3e+06 1.3e+06 ... 1.6e+06 1.6e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-05-27T16:11:09.978000
# Data variables:
#     blue         (y, x) float32 900MB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     green        (y, x) float32 900MB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     red          (y, x) float32 900MB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     rededge1     (y, x) float32 900MB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     rededge2     (y, x) float32 900MB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     rededge3     (y, x) float32 900MB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     nir08        (y, x) float32 900MB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir16       (y, x) float32 900MB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir22       (y, x) float32 900MB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     scl          (y, x) float32 900MB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     date         (y, x) float32 900MB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     score        (y, x) float32 900MB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#
# <period_mosaic> The number of unique granule tiles = 19
#
# <<<<<< The unique granule tiles =  ['17TPL', '18TUR', '17TQL', '18TUT', '18TVT', '18TUQ', '17TPK', '17TQM', '18TUS', '17TQN', '18TVR', '17TQK', '18TWQ', '18TVS', '18TWR', '18TVQ', '18TWS', '18TWT', '18TVP']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 96.70 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.68 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 858.48 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =  51.75 minutes >>>>>>
# File 'C:\Work_Data\S2_mosaic_tile55_922_2025_20m\log_07409fe1-581a-4ae9-9908-787099d27109.out' does not exist.
# Directory 'C:\Work_Data\S2_mosaic_tile55_922_2025_20m\dask_spill_07409fe1-581a-4ae9-9908-787099d27109' and its contents have been deleted.
