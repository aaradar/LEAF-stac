# %%
import os
import sys
import geopandas as gpd

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from leaf_wrapper import LeafWrapper
from Production import main

kml = cwd + "/AfforestationSItesFixed.kml"

# %%
# Load polygons from KML (NOTE: some start dates are a problem since the sentinel-2 only has data from around 2016-present, 
# so some of the data will crash the program when main is called
wrapper = LeafWrapper(kml).load()
regions_dict = wrapper.to_region_dict()  # keys = TARGET_FID

#Access region with TARGET_FID = 2
print(regions_dict[4])

# Select region with TARGET_FID = 4
region_data = regions_dict[4]
region_data2 = regions_dict[5]

ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

test_region = {
    'type': 'Polygon',
    'coordinates': region_data["coordinates"]
}

test_region2 = {
    'type': 'Polygon',
    'coordinates': region_data2["coordinates"]
}

CompParams = {
  "number_workers":20,     
  "debug"       : True,
  "entire_tile" : False, 
  "nodes"       : 1,
  "node_memory" : "25G",
  'chunk_size': {'x': 4096, 'y': 4096}
}


  
ProdParams = {
    'sensor': 'S2_SR',       # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR' or 'HLSS30_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2025,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    #'months': [8],    # A list of integers represening one or multiple monthes     
    #'tile_names': ['tile46_411','tile46_412','tile46_421','tile46_422'],  # A list of (sub-)tile names
    #'tile_names': ['tile46_412'],
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution': 100,            # Exporting spatial resolution  
    'out_folder': 'E:/S2_mosaics_2025/S2_kml_test_100m',
    #'out_folder': 'E:/S2_mosaics_2025/S2_mosaic_tile46_412_2025_100m',  # the folder name for exporting
    'out_datatype': 'int16',     # 'int8' or 'int16'
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    'start_dates': ['2025-06-15'],
    'end_dates': ['2025-09-15'],
    #'regions': {'ottawa': ottawa_region, 'vancouver': vancouver_region},  
    #'start_dates': [region_data["start_date"]],
    #'end_dates': [region_data["end_date"]],
    'regions': {'region_test': test_region, 'region_test2': test_region2}
    
}


print(ProdParams)
# Out:
# {'coordinates': [[[-80.4414758461818, 44.4468399119331], [-80.4399721805282, 44.4471867620164], [-80.4395657798354, 44.4447820571645], [-80.44099741403, 44.4444232095963], [-80.4414758461818, 44.4468399119331]]], 'start_date': '2009-07-01', 'end_date': '2010-07-01'}
# {'sensor': 'S2_SR', 'unit': 2, 'year': 2025, 'nbYears': -1, 'months': [8], 'prod_names': ['mosaic'], 'resolution': 100, 'out_folder': 'E:/S2_mosaics_2025/S2_vancouver_and_ottawa_2025_100m', 'out_datatype': 'int16', 'projection': 'EPSG:3979', 'IncludeAngles': False, 'start_dates': ['2025-06-15'], 'end_dates': ['2025-09-15'], 'regions': {'region_test': {'type': 'Polygon', 'coordinates': [[[-80.4414758461818, 44.4468399119331], [-80.4399721805282, 44.4471867620164], [-80.4395657798354, 44.4447820571645], [-80.44099741403, 44.4444232095963], [-80.4414758461818, 44.4468399119331]]]}, 'vancouver': {'type': 'Polygon', 'coordinates': [[[-123.32, 49.37], [-122.44, 49.35], [-122.96, 48.75], [-123.27, 48.96], [-123.32, 49.37]]]}}}

# %%
main(ProdParams, CompParams)
# Out:
# <MosaicProduction> User defined input parameters:
# sensor: S2_SR
# unit: 2
# year: 2025
# nbYears: -1
# months: [8]
# prod_names: ['mosaic']
# resolution: 100
# out_folder: E:/S2_mosaics_2025/S2_vancouver_and_ottawa_2025_100m
# out_datatype: int16
# projection: EPSG:3979
# IncludeAngles: False
# start_dates: ['2025-06-15']
# end_dates: ['2025-09-15']
# regions: {'region_test': {'type': 'Polygon', 'coordinates': [[[-80.4414758461818, 44.4468399119331], [-80.4399721805282, 44.4471867620164], [-80.4395657798354, 44.4447820571645], [-80.44099741403, 44.4444232095963], [-80.4414758461818, 44.4468399119331]]]}, 'vancouver': {'type': 'Polygon', 'coordinates': [[[-123.32, 49.37], [-122.44, 49.35], [-122.96, 48.75], [-123.27, 48.96], [-123.32, 49.37]]]}}
# SsrData: {'NAME': 'S2_SR', 'SSR_CODE': 21, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], '10M_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'SIX_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'NoA_BANDS': ['red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'LEAF_BANDS': ['green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'GEE_NAME': 'COPERNICUS/S2_SR_HARMONIZED', 'CLOUD': 'CLOUDY_PIXEL_PERCENTAGE', 'SZA': 'view:sun_elevation', 'SAA': 'view:sun_azimuth', 'VZA': 'view:sun_elevation', 'VAA': 'view:sun_azimuth', 'BLU': 'blue', 'GRN': 'green', 'RED': 'red', 'NIR': 'nir08', 'SW1': 'swir16', 'SW2': 'swir22'}
# out_location: drive
# tile_names: []
# cloud_cover: 80
# export_style: separate
# monthly: False
# current_time: 0
# scene_ID:
# current_region: region_test
# Criteria: {'timeframe': '2025-06-15/2025-09-15', 'filters': {'eo:cloud_cover': {'lt': 80}}, 'region': {'type': 'Polygon', 'coordinates': [[[-80.4414758461818, 44.4468399119331], [-80.4399721805282, 44.4471867620164], [-80.4395657798354, 44.4447820571645], [-80.44099741403, 44.4444232095963], [-80.4414758461818, 44.4468399119331]]]}, 'catalog': 'https://earth-search.aws.element84.com/v1', 'collection': ['sentinel-2-l2a'], 'bands': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl']}
# standardized: True
# number_workers: 20
# debug: True
# entire_tile: False
# nodes: 1
# node_memory: 25G
# chunk_size: {'x': 4096, 'y': 4096}
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-80.4414758461818, 44.4468399119331], [-80.4399721805282, 44.4471867620164], [-80.4395657798354, 44.4447820571645], [-80.44099741403, 44.4444232095963], [-80.4414758461818, 44.4468399119331]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.03 minutes
#
# <one_mosaic> A total of 33 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/AOT.tif
# Asset key: blue, title: Blue - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B02.tif
# Asset key: cloud, title: Cloud Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/qi/CLD_20m.jp2
# Asset key: coastal, title: Coastal - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/granule_metadata.xml
# Asset key: green, title: Green - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B09.tif
# Asset key: product_metadata, title: None, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/product_metadata.xml
# Asset key: red, title: Red - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B04.tif
# Asset key: rededge1, title: Red Edge 1 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B05.tif
# Asset key: rededge2, title: Red Edge 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B06.tif
# Asset key: rededge3, title: Red Edge 3 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/SCL.tif
# Asset key: snow, title: Snow Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/qi/SNW_20m.jp2
# Asset key: swir16, title: SWIR 1.6μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2.2μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B12.tif
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/TCI.tif
# Asset key: wvp, title: Water Vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/WVP.tif
# Asset key: thumbnail, title: Thumbnail of preview image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/preview.jpg
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R20m/AOT.jp2
# Asset key: blue-jp2, title: Blue - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R10m/B02.jp2
# Asset key: coastal-jp2, title: Coastal - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R60m/B01.jp2
# Asset key: green-jp2, title: Green - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R10m/B03.jp2
# Asset key: nir-jp2, title: NIR 1 - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R10m/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R20m/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R60m/B09.jp2
# Asset key: red-jp2, title: Red - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R10m/B04.jp2
# Asset key: rededge1-jp2, title: Red Edge 1 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R20m/B05.jp2
# Asset key: rededge2-jp2, title: Red Edge 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R20m/B06.jp2
# Asset key: rededge3-jp2, title: Red Edge 3 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R20m/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R20m/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1.6μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R20m/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2.2μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R20m/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R10m/TCI.jp2
# Asset key: wvp-jp2, title: Water Vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R20m/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2C_17TNK_20250821_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-81.00024171761814, 45.153828248771845], [-81.00023764893123, 44.16627582537803], [-80.01584714999262, 44.16221649073625], [-79.61713183890808, 45.14545548657298], [-81.00024171761814, 45.153828248771845]]]}
# Bounding Box: [-81.000242, 44.162216, -79.617132, 45.153828]
# Datetime: 2025-08-21 16:31:16.711000+00:00
# cloud cover: 18.512073
# Properties:
#   <created>: 2025-08-21T22:46:25.125Z
#   <platform>: sentinel-2c
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 18.512073
#   <proj:centroid>: {'lat': 44.68464, 'lon': -80.40298}
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:azimuth>: 286.14725199948623
#   <view:incidence_angle>: 8.106150437477405
#   <view:sun_azimuth>: 156.811872764238
#   <view:sun_elevation>: 55.2955297467904
#   <s2:tile_id>: S2C_OPER_MSI_L2A_TL_2CPS_20250821T210914_A005015_T17TNK_N05.11
#   <s2:degraded_msi_data_percentage>: 0.0171
#   <s2:nodata_pixel_percentage>: 14.533134
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:cloud_shadow_percentage>: 6.665886
#   <s2:vegetation_percentage>: 32.629919
#   <s2:not_vegetated_percentage>: 2.734978
#   <s2:water_percentage>: 39.121401
#   <s2:unclassified_percentage>: 0.268523
#   <s2:medium_proba_clouds_percentage>: 5.186015
#   <s2:high_proba_clouds_percentage>: 4.769121
#   <s2:thin_cirrus_percentage>: 8.556937
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.11
#   <s2:product_uri>: S2C_MSIL2A_20250821T161921_N0511_R040_T17TNK_20250821T210914.SAFE
#   <s2:generation_time>: 2025-08-21T21:09:14.000000Z
#   <s2:datatake_id>: GS2C_20250821T161921_005015_N05.11
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2C_OPER_MSI_L2A_DS_2CPS_20250821T210914_S20250821T162900_N05.11
#   <s2:reflectance_conversion_factor>: 0.976079260018279
#   <datetime>: 2025-08-21T16:31:16.711000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/8e84e299d1da0ecaeed3e21e8b4c974c
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '2025.03.06'}
#   <updated>: 2025-08-21T22:46:25.125Z
#   <proj:code>: EPSG:32617
#   <sza>: 34.7044702532096
#   <saa>: 156.811872764238
#   <vza>: 8.17286668600843
#   <vaa>: 286.221140482994
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 644B
# Dimensions:      (y: 4, x: 3)
# Coordinates:
#   * y            (y) float64 32B -3.762e+05 -3.764e+05 -3.764e+05 -3.766e+05
#   * x            (x) float64 24B 1.172e+06 1.172e+06 1.172e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-08-21T16:31:16.711000
# Data variables:
#     blue         (y, x) float32 48B dask.array<chunksize=(4, 3), meta=np.ndarray>
#     green        (y, x) float32 48B dask.array<chunksize=(4, 3), meta=np.ndarray>
#     red          (y, x) float32 48B dask.array<chunksize=(4, 3), meta=np.ndarray>
#     rededge1     (y, x) float32 48B dask.array<chunksize=(4, 3), meta=np.ndarray>
#     rededge2     (y, x) float32 48B dask.array<chunksize=(4, 3), meta=np.ndarray>
#     rededge3     (y, x) float32 48B dask.array<chunksize=(4, 3), meta=np.ndarray>
#     nir08        (y, x) float32 48B dask.array<chunksize=(4, 3), meta=np.ndarray>
#     swir16       (y, x) float32 48B dask.array<chunksize=(4, 3), meta=np.ndarray>
#     swir22       (y, x) float32 48B dask.array<chunksize=(4, 3), meta=np.ndarray>
#     scl          (y, x) float32 48B dask.array<chunksize=(4, 3), meta=np.ndarray>
#     date         (y, x) float32 48B dask.array<chunksize=(4, 3), meta=np.ndarray>
#     score        (y, x) float32 48B dask.array<chunksize=(4, 3), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:60584/status >>>>>>>>>
