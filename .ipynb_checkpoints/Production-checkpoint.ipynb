# %%
import os
import sys

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

# %%
ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

CompParams = {
  "debug"       : True,
  "entire_tile" : False,     #
  "nodes"       : 1,
  "node_memory" : "120G",
  "number_workers" : 10
}

  
ProdParams = {
    'sensor': 'S2_SR',       # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR', 'HLSS30_SR' or 'MOD_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2024,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    'months': [8],            # A list of integers represening one or multiple monthes     
    'tile_names': ['tile55_421'], # A list of (sub-)tile names (defined using CCRS' tile griding system) 
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution': 60,            # Exporting spatial resolution    
    'out_folder': 'C:/Work_Data/S2_mosaic_tile55_421_2024_60m',  # the folder name for exporting
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    #'start_dates': ['2024-06-15'],
    #'end_dates': ['2024-09-15'],
    #'regions': {'ottawa': ottawa_region}  #, 'vancouver': vancouver_region}    
}

# %%
main(ProdParams, CompParams)
# Out:
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-81.9071, 46.8655], [-83.004, 42.9647], [-77.8264, 42.0702], [-76.3005, 45.8742], [-81.9071, 46.8655]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.10 minutes
#
# <period_mosaic> A total of 269 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PK/2024/8/S2B_17TPK_20240831_0_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PK/2024/8/S2B_17TPK_20240831_0_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PK/2024/8/S2B_17TPK_20240831_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PK/2024/8/S2B_17TPK_20240831_0_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PK/2024/8/S2B_17TPK_20240831_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PK/2024/8/S2B_17TPK_20240831_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PK/2024/8/S2B_17TPK_20240831_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PK/2024/8/S2B_17TPK_20240831_0_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PK/2024/8/S2B_17TPK_20240831_0_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PK/2024/8/S2B_17TPK_20240831_0_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PK/2024/8/S2B_17TPK_20240831_0_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PK/2024/8/S2B_17TPK_20240831_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PK/2024/8/S2B_17TPK_20240831_0_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PK/2024/8/S2B_17TPK_20240831_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PK/2024/8/S2B_17TPK_20240831_0_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PK/2024/8/S2B_17TPK_20240831_0_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PK/2024/8/S2B_17TPK_20240831_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PK/2024/8/S2B_17TPK_20240831_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/PK/2024/8/S2B_17TPK_20240831_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/PK/2024/8/31/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/PK/2024/8/31/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/PK/2024/8/31/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/PK/2024/8/31/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/PK/2024/8/31/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/PK/2024/8/31/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/PK/2024/8/31/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/PK/2024/8/31/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/PK/2024/8/31/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/PK/2024/8/31/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/PK/2024/8/31/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/PK/2024/8/31/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/PK/2024/8/31/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/PK/2024/8/31/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/PK/2024/8/31/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/PK/2024/8/31/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# ID: S2B_17TPK_20240831_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-79.7279465151616, 45.14674371395526], [-79.73431893317562, 44.85809969944198], [-79.6163687832882, 45.14544624306206], [-79.7279465151616, 45.14674371395526]]]}
# Bounding Box: [-79.73431893317562, 44.85809969944198, -79.6163687832882, 45.14674371395526]
# Datetime: 2024-08-31 16:30:50.698000+00:00
# cloud cover: 4.14746
# Properties:
#   <created>: 2024-08-31T21:39:33.769Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 4.14746
#   <proj:epsg>: 32617
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: PK
#   <grid:code>: MGRS-17TPK
#   <view:sun_azimuth>: 161.45302798082
#   <view:sun_elevation>: 52.3360189752392
#   <s2:degraded_msi_data_percentage>: 0
#   <s2:nodata_pixel_percentage>: 98.795086
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:cloud_shadow_percentage>: 3.657046
#   <s2:vegetation_percentage>: 74.702752
#   <s2:not_vegetated_percentage>: 0.872613
#   <s2:water_percentage>: 15.533839
#   <s2:unclassified_percentage>: 0.739064
#   <s2:medium_proba_clouds_percentage>: 1.997731
#   <s2:high_proba_clouds_percentage>: 2.149454
#   <s2:thin_cirrus_percentage>: 0.000275
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.11
#   <s2:product_uri>: S2B_MSIL2A_20240831T161829_N0511_R040_T17TPK_20240831T202059.SAFE
#   <s2:generation_time>: 2024-08-31T20:20:59.000000Z
#   <s2:datatake_id>: GS2B_20240831T161829_039105_N05.11
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_2BPS_20240831T202059_S20240831T162456_N05.11
#   <s2:granule_id>: S2B_OPER_MSI_L2A_TL_2BPS_20240831T202059_A039105_T17TPK_N05.11
#   <s2:reflectance_conversion_factor>: 0.980359915503397
#   <datetime>: 2024-08-31T16:30:50.698000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/PK/2024/8/S2B_17TPK_20240831_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/687e120e762c17f765909240669b6958
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '0.1.1'}
#   <updated>: 2024-08-31T21:39:33.769Z
#   <sza>: 37.6639810247608
#   <saa>: 161.45302798082
#   <vza>: 11.6050820631839
#   <vaa>: 294.729559831971
#
# <period_mosaic> based mosaic image =  <xarray.Dataset> Size: 3GB
# Dimensions:      (y: 7501, x: 7501)
# Coordinates:
#   * y            (y) float64 60kB -1.351e+05 -1.352e+05 ... -5.85e+05 -5.851e+05
#   * x            (x) float64 60kB 1e+06 1e+06 1e+06 ... 1.45e+06 1.45e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2024-08-31T16:30:50.698000
# Data variables:
#     blue         (y, x) float32 225MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     green        (y, x) float32 225MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     red          (y, x) float32 225MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     rededge1     (y, x) float32 225MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     rededge2     (y, x) float32 225MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     rededge3     (y, x) float32 225MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     nir08        (y, x) float32 225MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     swir16       (y, x) float32 225MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     swir22       (y, x) float32 225MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     scl          (y, x) float32 225MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     date         (y, x) float32 225MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     score        (y, x) float32 225MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#
# <period_mosaic> The number of unique granule tiles = 34
#
# <<<<<< The unique granule tiles =  ['17TPK', '17TMM', '17TPM', '17TLL', '17TMK', '17TPL', '17TLH', '17TNM', '17TML', '17TPH', '17TPG', '17TLK', '17TQH', '17TMN', '17TMJ', '17TNH', '17TLJ', '17TPJ', '17TQM', '17TMH', '17TQJ', '18TUP', '18TUS', '17TQL', '18TUR', '18TTM', '17TQG', '18TUQ', '17TNJ', '17TNK', '17TNL', '18TUN', '17TQK', '17TNG']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 main(ProdParams, CompParams)
#
# File ~\STAC_python\Production.py:123, in main(inProdParams, inCompParams)
#     120   leaf.LEAF_production(prod_params, comp_params)
#     122 else:
# --> 123   eoMz.MosaicProduction(prod_params, comp_params)
#
# File ~\STAC_python\source\eoMosaic.py:1598, in MosaicProduction(ProdParams, CompParams)
#    1590   #out_params = compact_params(mosaic, SsrData, ClassImg)
#    1591
#    1592   # Export the 64-bits image to either GD or GCS
#    (...)
#    1595 else:
#    1596   # Produce and export vegetation parameetr maps for a time period and a region
#    1597   print('\n<MosaicProduction> Generate and export separate mosaic images......')
# -> 1598   one_mosaic(usedParams, CompParams)
#
# File ~\STAC_python\source\eoMosaic.py:1367, in one_mosaic(ProdParams, CompParams, Output)
#    1364   submited_granules_mosaics, client, cluster, unique_name = create_mosaic_at_once_distributed(base_img, unique_granules, stac_items, ProdParams)
#    1366 persisted_granules_mosaics = dask.persist(*submited_granules_mosaics, optimize_graph=True)
# -> 1367 for future, granules_mosaic in as_completed(persisted_granules_mosaics, with_results=True):
#    1368   base_img = merge_granule_mosaics(granules_mosaic, base_img, eoIM.pix_score)
#    1369   client.cancel(future)
#
# File ~\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\client.py:5902, in as_completed.__next__(self)
#    5900     with self.thread_condition:
#    5901         self.thread_condition.wait(timeout=0.100)
# -> 5902 return self._get_and_raise()
#
# File ~\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\client.py:5891, in as_completed._get_and_raise(self)
#    5889     if self.raise_errors and future.status == "error":
#    5890         typ, exc, tb = result
# -> 5891         raise exc.with_traceback(tb)
#    5892 return res
#
# File ~\STAC_python\source\eoMosaic.py:1011, in get_granule_mosaic()
#    1004 filtered_items    = get_unique_STAC_items(one_granule_items, MosaicParams)   # Remain only one item from those that share the same timestamp
#    1006 if 'scl' in Bands:   # For Sentinel-2 images from AWS data catalog
#    1007   #When in debugging mode, display metadata assets
#    1008   # if MosaicParams["debug"]:
#    1009   #   display_meta_assets(filtered_items['S2'], False)
# -> 1011   xrDS_S2 = load_STAC_items(filtered_items['S2'], Bands, chunk_size, ProjStr, Scale)
#    1012   xrDS_LS = None
#    1013 else:  #For both Snetinel-2 and Landsat data from LP DAAC of NASA
#
# File ~\STAC_python\source\eoMosaic.py:831, in load_STAC_items()
#     829 #print("<load_STAC_items> item time tag: datetime: {}; CC: {}".format(properties['datetime'], properties['eo:cloud_cover']))
#     830 time_str = properties['datetime']
# --> 831 dt = datetime.strptime(time_str, "%Y-%m-%dT%H:%M:%S.%fZ")
#     832 iso_str = dt.strftime("%Y-%m-%dT%H:%M:%S.%fZ")
#     833 item_CC[iso_str] = properties['eo:cloud_cover']
#
# File ~\AppData\Local\anaconda3\envs\stac\Lib\_strptime.py:554, in _strptime_datetime()
#     551 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     552     """Return a class cls instance based on the input string and the
#     553     format string."""
# --> 554     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     555     tzname, gmtoff = tt[-2:]
#     556     args = tt[:6] + (fraction,)
#
# File ~\AppData\Local\anaconda3\envs\stac\Lib\_strptime.py:333, in _strptime()
#     331 found = format_regex.match(data_string)
#     332 if not found:
# --> 333     raise ValueError("time data %r does not match format %r" %
#     334                      (data_string, format))
#     335 if len(data_string) != found.end():
#     336     raise ValueError("unconverted data remains: %s" %
#     337                       data_string[found.end():])
#
# ValueError: time data '2024-08-21T16:30:47Z' does not match format '%Y-%m-%dT%H:%M:%S.%fZ'
