# %%
import os
import sys

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

# %%
ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

CompParams = {
  "number_workers":10,     
  "debug"       : True,
  "entire_tile" : False, 
  "nodes"       : 1,
  "node_memory" : "50G",
  'chunk_size': {'x': 4096, 'y': 4096}
}

  
ProdParams = {
    'sensor': 'HLS_SR',       # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR' or 'HLSS30_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2025,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    'months': [5,6,7,8,9,10],    # A list of integers represening one or multiple monthes     
    'tile_names': ['tile45_411','tile45_412','tile45_421','tile45_422'],  # A list of (sub-)tile names
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution': 30,            # Exporting spatial resolution    
    'out_folder': 'E:/HLS_mosaics_2025/HLS_mosaic_tile45_2025_30m',  # the folder name for exporting
    'out_datatype': 'int16',     # 'int8' or 'int16'
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    #'start_dates': ['2025-06-15'],
    #'end_dates': ['2025-09-15'],
    #'regions': {'ottawa': ottawa_region}  #, {'vancouver': vancouver_region}    
}

# %%
main(ProdParams, CompParams)
# Out:
# <form_spatial_regions> Raw polygon = {'type': 'Polygon', 'coordinates': [[[-93.1511, 60.0848], [-93.3649, 55.9426], [-86.0644, 55.5994], [-84.9136, 59.6947], [-93.1511, 60.0848]]]}
# <form_spatial_regions> Raw polygon = {'type': 'Polygon', 'coordinates': [[[-84.9136, 59.6947], [-86.0644, 55.5994], [-78.9924, 54.7951], [-77.0021, 58.7838], [-84.9136, 59.6947]]]}
# <form_spatial_regions> Raw polygon = {'type': 'Polygon', 'coordinates': [[[-93.3649, 55.9426], [-93.5344, 51.8354], [-86.9807, 51.5308], [-86.0644, 55.5994], [-93.3649, 55.9426]]]}
# <form_spatial_regions> Raw polygon = {'type': 'Polygon', 'coordinates': [[[-86.0644, 55.5994], [-86.9807, 51.5308], [-80.5932, 50.8149], [-78.9924, 54.7951], [-86.0644, 55.5994]]]}
# <MosaicProduction> User defined input parameters:
# sensor: HLS_SR
# unit: 2
# year: 2025
# nbYears: -1
# months: [5, 6, 7, 8, 9, 10]
# tile_names: ['tile44_411', 'tile44_412', 'tile44_421', 'tile44_422']
# prod_names: ['mosaic']
# resolution: 30
# out_folder: E:/HLS_mosaics_2025/HLS_mosaic_tile44_2025_30m
# out_datatype: int16
# projection: EPSG:3979
# IncludeAngles: False
# SsrData: {'NAME': 'HLS_SR', 'SSR_CODE': 102, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07'], 'SIX_BANDS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07'], 'NoA_BANDS': ['B04', 'B05', 'B06', 'B07'], 'LEAF_BANDS': ['B03', 'B04', 'B05', 'B06', 'B07'], 'ANGLE_BANDS': ['VZA', 'VAA', 'SZA', 'SAA'], 'CLOUD': 'CLOUD_COVERAGE', 'BLU': 'B02', 'GRN': 'B03', 'RED': 'B04', 'NIR': 'B05', 'SW1': 'B06', 'SW2': 'B07'}
# out_location: drive
# cloud_cover: 80
# export_style: separate
# CloudScore: False
# monthly: True
# start_dates: ['2025-05-01', '2025-06-01', '2025-07-01', '2025-08-01', '2025-09-01', '2025-10-01']
# end_dates: ['2025-05-31', '2025-06-30', '2025-07-31', '2025-08-31', '2025-09-30', '2025-10-31']
# current_time: 0
# scene_ID:
# regions: {'tile44_411': {'type': 'Polygon', 'coordinates': [[[-93.3511, 60.284800000000004], [-93.56490000000001, 55.742599999999996], [-85.8644, 55.3994], [-84.7136, 59.8947], [-93.3511, 60.284800000000004]]]}, 'tile44_412': {'type': 'Polygon', 'coordinates': [[[-85.1136, 59.8947], [-86.26440000000001, 55.3994], [-78.7924, 54.595099999999995], [-76.8021, 58.9838], [-85.1136, 59.8947]]]}, 'tile44_421': {'type': 'Polygon', 'coordinates': [[[-93.56490000000001, 56.1426], [-93.73440000000001, 51.6354], [-86.7807, 51.330799999999996], [-85.8644, 55.799400000000006], [-93.56490000000001, 56.1426]]]}, 'tile44_422': {'type': 'Polygon', 'coordinates': [[[-86.26440000000001, 55.799400000000006], [-87.1807, 51.330799999999996], [-80.3932, 50.6149], [-78.7924, 54.9951], [-86.26440000000001, 55.799400000000006]]]}}
# current_region: tile44_411
# Criteria: {'timeframe': '2025-05-01/2025-05-31', 'filters': {'eo:cloud_cover': {'lt': 80}}, 'region': {'type': 'Polygon', 'coordinates': [[[-93.3511, 60.284800000000004], [-93.56490000000001, 55.742599999999996], [-85.8644, 55.3994], [-84.7136, 59.8947], [-93.3511, 60.284800000000004]]]}, 'collection': ['HLSS30_2.0', 'HLSL30_2.0'], 'bands': {'S2': ['B02', 'B03', 'B04', 'B08', 'B11', 'B12', 'Fmask'], 'LS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'Fmask'], 'angle': ['SZA', 'SAA', 'VZA', 'VAA']}, 'catalog': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD'}
# standardized: True
# number_workers: 10
# debug: True
# entire_tile: False
# nodes: 1
# node_memory: 50G
# chunk_size: {'x': 4096, 'y': 4096}
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-93.3511, 60.284800000000004], [-93.56490000000001, 55.742599999999996], [-85.8644, 55.3994], [-84.7136, 59.8947], [-93.3511, 60.284800000000004]]]}
# <search_STAC_Catalog> Number of items found in collection HLSS30_2.0: 212
# <search_STAC_Catalog> Number of items found in collection HLSL30_2.0: 141
#
# <one_mosaic> A total of 353 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T16VEH.2025122T164901.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.jpg
# Asset key: B06, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B06.tif
# Asset key: B05, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B05.tif
# Asset key: B07, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B07.tif
# Asset key: B09, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B09.tif
# Asset key: Fmask, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.Fmask.tif
# Asset key: B08, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B08.tif
# Asset key: B02, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B02.tif
# Asset key: VAA, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.VAA.tif
# Asset key: SAA, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.SAA.tif
# Asset key: SZA, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.SZA.tif
# Asset key: B04, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B04.tif
# Asset key: B03, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B03.tif
# Asset key: B10, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B10.tif
# Asset key: B8A, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B8A.tif
# Asset key: VZA, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.VZA.tif
# Asset key: B11, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B11.tif
# Asset key: B12, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B12.tif
# Asset key: B01, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B01.tif
# Asset key: s3_B06, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B06.tif
# Asset key: s3_B05, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B05.tif
# Asset key: s3_B07, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B07.tif
# Asset key: s3_B09, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B09.tif
# Asset key: s3_Fmask, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.Fmask.tif
# Asset key: s3_B08, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B08.tif
# Asset key: s3_B02, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B02.tif
# Asset key: s3_VAA, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.VAA.tif
# Asset key: s3_SAA, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.SAA.tif
# Asset key: s3_SZA, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.SZA.tif
# Asset key: s3_B04, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B04.tif
# Asset key: s3_B03, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B03.tif
# Asset key: s3_B10, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B10.tif
# Asset key: s3_B8A, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B8A.tif
# Asset key: s3_VZA, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.VZA.tif
# Asset key: s3_B11, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B11.tif
# Asset key: s3_B12, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B12.tif
# Asset key: s3_B01, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025122T164901.v2.0/HLS.S30.T16VEH.2025122T164901.v2.0.B01.tif
# Asset key: metadata, title: CMR XML metadata for G3520351367-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3520351367-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: HLS.S30.T16VEH.2025122T164901.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-85.2467141, 55.8448305], [-85.2008941, 56.8308491], [-86.2164625, 56.8413537], [-86.7108486, 55.8575206], [-86.7108526, 55.8569815], [-85.2467141, 55.8448305]]]}
# Bounding Box: [-86.7108526, 55.8448305, -85.2008941, 56.8413537]
# Datetime: 2025-05-02 16:58:19.975000+00:00
# cloud cover: 0
# Properties:
#   <datetime>: 2025-05-02T16:58:19.975Z
#   <eo:cloud_cover>: 0
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2025-05-02T16:58:19.975Z
#   <end_datetime>: 2025-05-02T16:58:19.975Z
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 11GB
# Dimensions:      (y: 16508, x: 15903)
# Coordinates:
#   * y            (y) float64 132kB 1.238e+06 1.238e+06 ... 7.429e+05 7.428e+05
#   * x            (x) float64 127kB 8.828e+04 8.83e+04 ... 5.653e+05 5.653e+05
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-05-02T16:58:19.975000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     sensor       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 21
#
# <<<<<< The unique granule tiles =  ['T16UDG', 'T15UWB', 'T15VXD', 'T16VCH', 'T15VXC', 'T16UEG', 'T16UCG', 'T15VWD', 'T15VWC', 'T15UXB', 'T16VEH', 'T15VVD', 'T15UVB', 'T15VVE', 'T15VVC', 'T15VWE', 'T15VVG', 'T16VDH', 'T15VVF', 'T16VCJ', 'T16VDJ']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 96.38 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 0.98 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =  50.90 minutes >>>>>>
# File 'E:\HLS_mosaics_2025\HLS_mosaic_tile44_2025_30m\log_c1dc2634-853f-4b74-9b73-3819243beeb5.out' does not exist.
# Directory 'E:\HLS_mosaics_2025\HLS_mosaic_tile44_2025_30m\dask_spill_c1dc2634-853f-4b74-9b73-3819243beeb5' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-93.3511, 60.284800000000004], [-93.56490000000001, 55.742599999999996], [-85.8644, 55.3994], [-84.7136, 59.8947], [-93.3511, 60.284800000000004]]]}
# <search_STAC_Catalog> Number of items found in collection HLSS30_2.0: 202
# <search_STAC_Catalog> Number of items found in collection HLSL30_2.0: 129
#
# <one_mosaic> A total of 331 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T16VEH.2025152T164911.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.jpg
# Asset key: VAA, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.VAA.tif
# Asset key: B04, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B04.tif
# Asset key: B01, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B01.tif
# Asset key: SZA, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.SZA.tif
# Asset key: B8A, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B8A.tif
# Asset key: B12, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B12.tif
# Asset key: B08, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B08.tif
# Asset key: B03, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B03.tif
# Asset key: B05, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B05.tif
# Asset key: B07, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B07.tif
# Asset key: Fmask, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.Fmask.tif
# Asset key: B11, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B11.tif
# Asset key: B10, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B10.tif
# Asset key: SAA, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.SAA.tif
# Asset key: B06, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B06.tif
# Asset key: VZA, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.VZA.tif
# Asset key: B09, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B09.tif
# Asset key: B02, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B02.tif
# Asset key: s3_VAA, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.VAA.tif
# Asset key: s3_B04, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B04.tif
# Asset key: s3_B01, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B01.tif
# Asset key: s3_SZA, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.SZA.tif
# Asset key: s3_B8A, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B8A.tif
# Asset key: s3_B12, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B12.tif
# Asset key: s3_B08, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B08.tif
# Asset key: s3_B03, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B03.tif
# Asset key: s3_B05, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B05.tif
# Asset key: s3_B07, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B07.tif
# Asset key: s3_Fmask, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.Fmask.tif
# Asset key: s3_B11, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B11.tif
# Asset key: s3_B10, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B10.tif
# Asset key: s3_SAA, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.SAA.tif
# Asset key: s3_B06, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B06.tif
# Asset key: s3_VZA, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.VZA.tif
# Asset key: s3_B09, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B09.tif
# Asset key: s3_B02, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T16VEH.2025152T164911.v2.0/HLS.S30.T16VEH.2025152T164911.v2.0.B02.tif
# Asset key: metadata, title: CMR XML metadata for G3558681344-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3558681344-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: HLS.S30.T16VEH.2025152T164911.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-85.2467141, 55.8448305], [-85.2008941, 56.8308491], [-86.2056449, 56.8412853], [-86.700301, 55.8580345], [-86.7003093, 55.8569563], [-85.2467141, 55.8448305]]]}
# Bounding Box: [-86.7003093, 55.8448305, -85.2008941, 56.8412853]
# Datetime: 2025-06-01 16:58:19.057000+00:00
# cloud cover: 17
# Properties:
#   <datetime>: 2025-06-01T16:58:19.057Z
#   <eo:cloud_cover>: 17
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2025-06-01T16:58:19.057Z
#   <end_datetime>: 2025-06-01T16:58:19.057Z
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 11GB
# Dimensions:      (y: 16508, x: 15903)
# Coordinates:
#   * y            (y) float64 132kB 1.238e+06 1.238e+06 ... 7.429e+05 7.428e+05
#   * x            (x) float64 127kB 8.828e+04 8.83e+04 ... 5.653e+05 5.653e+05
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-06-01T16:58:19.057000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     sensor       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 21
#
# <<<<<< The unique granule tiles =  ['T16UCG', 'T15VWE', 'T15VVE', 'T16VCH', 'T15VXC', 'T16VDJ', 'T15VXD', 'T16VEH', 'T15VWC', 'T15VWD', 'T15VVG', 'T16VDH', 'T15UWB', 'T15UXB', 'T16UEG', 'T15VVF', 'T16VCJ', 'T16UDG', 'T15VVD', 'T15UVB', 'T15VVC']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 93.06 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 0.98 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =  47.43 minutes >>>>>>
# File 'E:\HLS_mosaics_2025\HLS_mosaic_tile44_2025_30m\log_e00390f3-421b-440e-b1e3-03c1aedbf4ef.out' does not exist.
# Directory 'E:\HLS_mosaics_2025\HLS_mosaic_tile44_2025_30m\dask_spill_e00390f3-421b-440e-b1e3-03c1aedbf4ef' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-93.3511, 60.284800000000004], [-93.56490000000001, 55.742599999999996], [-85.8644, 55.3994], [-84.7136, 59.8947], [-93.3511, 60.284800000000004]]]}
# <search_STAC_Catalog> Number of items found in collection HLSS30_2.0: 192
# <search_STAC_Catalog> Number of items found in collection HLSL30_2.0: 137
#
# <one_mosaic> A total of 329 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T15VWE.2025182T173909.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.jpg
# Asset key: B8A, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B8A.tif
# Asset key: B08, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B08.tif
# Asset key: B12, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B12.tif
# Asset key: B06, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B06.tif
# Asset key: SZA, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.SZA.tif
# Asset key: B05, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B05.tif
# Asset key: B02, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B02.tif
# Asset key: B01, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B01.tif
# Asset key: VAA, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.VAA.tif
# Asset key: SAA, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.SAA.tif
# Asset key: B09, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B09.tif
# Asset key: Fmask, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.Fmask.tif
# Asset key: B07, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B07.tif
# Asset key: VZA, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.VZA.tif
# Asset key: B04, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B04.tif
# Asset key: B11, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B11.tif
# Asset key: B10, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B10.tif
# Asset key: B03, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B03.tif
# Asset key: s3_B8A, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B8A.tif
# Asset key: s3_B08, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B08.tif
# Asset key: s3_B12, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B12.tif
# Asset key: s3_B06, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B06.tif
# Asset key: s3_SZA, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.SZA.tif
# Asset key: s3_B05, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B05.tif
# Asset key: s3_B02, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B02.tif
# Asset key: s3_B01, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B01.tif
# Asset key: s3_VAA, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.VAA.tif
# Asset key: s3_SAA, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.SAA.tif
# Asset key: s3_B09, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B09.tif
# Asset key: s3_Fmask, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.Fmask.tif
# Asset key: s3_B07, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B07.tif
# Asset key: s3_VZA, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.VZA.tif
# Asset key: s3_B04, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B04.tif
# Asset key: s3_B11, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B11.tif
# Asset key: s3_B10, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B10.tif
# Asset key: s3_B03, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T15VWE.2025182T173909.v2.0/HLS.S30.T15VWE.2025182T173909.v2.0.B03.tif
# Asset key: metadata, title: CMR XML metadata for G3589654009-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3589654009-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: HLS.S30.T15VWE.2025182T173909.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-93.0003371, 57.8640986], [-92.9983145, 57.8651765], [-92.4463521, 58.6394653], [-93.0003445, 58.6406562], [-93.0003371, 57.8640986]]]}
# Bounding Box: [-93.0003445, 57.8640986, -92.4463521, 58.6406562]
# Datetime: 2025-07-01 17:47:32.741000+00:00
# cloud cover: 73
# Properties:
#   <datetime>: 2025-07-01T17:47:32.741Z
#   <eo:cloud_cover>: 73
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2025-07-01T17:47:32.741Z
#   <end_datetime>: 2025-07-01T17:47:32.741Z
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 11GB
# Dimensions:      (y: 16508, x: 15903)
# Coordinates:
#   * y            (y) float64 132kB 1.238e+06 1.238e+06 ... 7.429e+05 7.428e+05
#   * x            (x) float64 127kB 8.828e+04 8.83e+04 ... 5.653e+05 5.653e+05
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-07-01T17:47:32.741000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     sensor       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 21
#
# <<<<<< The unique granule tiles =  ['T15VXD', 'T15VWE', 'T15VVE', 'T16VEH', 'T15VWD', 'T15UVB', 'T16VDJ', 'T16UDG', 'T16UEG', 'T15VWC', 'T15VVD', 'T15VVG', 'T15VVF', 'T16VDH', 'T16VCJ', 'T15UWB', 'T16VCH', 'T15VVC', 'T15VXC', 'T16UCG', 'T15UXB']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 92.78 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.96 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
# ...
# File 'E:\HLS_mosaics_2025\HLS_mosaic_tile44_2025_30m\log_ae5b242a-fbd7-4ff8-9a11-fc263dee9188.out' does not exist.
# Directory 'E:\HLS_mosaics_2025\HLS_mosaic_tile44_2025_30m\dask_spill_ae5b242a-fbd7-4ff8-9a11-fc263dee9188' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-86.26440000000001, 55.799400000000006], [-87.1807, 51.330799999999996], [-80.3932, 50.6149], [-78.7924, 54.9951], [-86.26440000000001, 55.799400000000006]]]}
# <search_STAC_Catalog> Number of items found in collection HLSS30_2.0: 366
# <search_STAC_Catalog> Number of items found in collection HLSL30_2.0: 123
#
# <one_mosaic> A total of 489 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T17ULB.2025274T164019.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.jpg
# Asset key: VAA, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.VAA.tif
# Asset key: Fmask, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.Fmask.tif
# Asset key: B12, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B12.tif
# Asset key: B01, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B01.tif
# Asset key: B11, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B11.tif
# Asset key: B07, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B07.tif
# Asset key: B02, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B02.tif
# Asset key: B03, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B03.tif
# Asset key: B04, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B04.tif
# Asset key: SZA, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.SZA.tif
# Asset key: B8A, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B8A.tif
# Asset key: VZA, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.VZA.tif
# Asset key: B10, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B10.tif
# Asset key: B08, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B08.tif
# Asset key: SAA, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.SAA.tif
# Asset key: B05, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B05.tif
# Asset key: B09, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B09.tif
# Asset key: B06, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B06.tif
# Asset key: s3_VAA, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.VAA.tif
# Asset key: s3_Fmask, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.Fmask.tif
# Asset key: s3_B12, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B12.tif
# Asset key: s3_B01, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B01.tif
# Asset key: s3_B11, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B11.tif
# Asset key: s3_B07, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B07.tif
# Asset key: s3_B02, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B02.tif
# Asset key: s3_B03, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B03.tif
# Asset key: s3_B04, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B04.tif
# Asset key: s3_SZA, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.SZA.tif
# Asset key: s3_B8A, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B8A.tif
# Asset key: s3_VZA, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.VZA.tif
# Asset key: s3_B10, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B10.tif
# Asset key: s3_B08, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B08.tif
# Asset key: s3_SAA, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.SAA.tif
# Asset key: s3_B05, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B05.tif
# Asset key: s3_B09, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B09.tif
# Asset key: s3_B06, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T17ULB.2025274T164019.v2.0/HLS.S30.T17ULB.2025274T164019.v2.0.B06.tif
# Asset key: metadata, title: CMR XML metadata for G3787282976-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3787282976-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: HLS.S30.T17ULB.2025274T164019.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-84.1207799, 54.9190265], [-82.4083987, 54.9509423], [-82.4439778, 55.9372734], [-84.1477455, 55.9055023], [-84.1922347, 55.8158913], [-84.1207799, 54.9190265]]]}
# Bounding Box: [-84.1922347, 54.9190265, -82.4083987, 55.9372734]
# Datetime: 2025-10-01 16:48:08.476000+00:00
# cloud cover: 33
# Properties:
#   <datetime>: 2025-10-01T16:48:08.476Z
#   <eo:cloud_cover>: 33
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2025-10-01T16:48:08.476Z
#   <end_datetime>: 2025-10-01T16:48:08.476Z
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 11GB
# Dimensions:      (y: 16598, x: 16130)
# Coordinates:
#   * y            (y) float64 133kB 7.892e+05 7.892e+05 ... 2.913e+05 2.913e+05
#   * x            (x) float64 129kB 5.348e+05 5.348e+05 ... 1.019e+06 1.019e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-10-01T16:48:08.476000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     sensor       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 41
#
# <<<<<< The unique granule tiles =  ['T16UFG', 'T17UMS', 'T17UMT', 'T17UNV', 'T17ULB', 'T17UMA', 'T17UNU', 'T17ULT', 'T16UGC', 'T17UMB', 'T17UNA', 'T16UEB', 'T17UNS', 'T17UMV', 'T17UMU', 'T16UED', 'T16UEC', 'T17ULS', 'T16UGB', 'T17ULU', 'T16UGD', 'T17UNB', 'T16UFF', 'T17ULV', 'T16UGE', 'T16UDB', 'T16UFE', 'T16UFC', 'T17UNT', 'T16UFB', 'T16UFD', 'T16UEE', 'T17ULA', 'T17UPA', 'T17UPU', 'T17UPV', 'T16UEG', 'T16UDC', 'T16UEF', 'T16UDD', 'T17UPB']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 211.21 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.00 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.99 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =  88.35 minutes >>>>>>
# File 'E:\HLS_mosaics_2025\HLS_mosaic_tile44_2025_30m\log_bf922a4e-ca05-402c-8162-7faa31e1755e.out' does not exist.
# Directory 'E:\HLS_mosaics_2025\HLS_mosaic_tile44_2025_30m\dask_spill_bf922a4e-ca05-402c-8162-7faa31e1755e' and its contents have been deleted.
