# %%
import os
import sys

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

# %%
ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

CompParams = {
  "debug"       : True,
  "entire_tile" : False,     #
  "nodes"       : 1,
  "node_memory" : "120G",
  "number_workers" : 10
}

  
ProdParams = {
    'sensor': 'S2_SR',       # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR', 'HLSS30_SR' or 'MOD_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2024,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    'months': [8],            # A list of integers represening one or multiple monthes     
    'tile_names': ['tile42_921'], # A list of (sub-)tile names (defined using CCRS' tile griding system) 
    'prod_names': ['LAI', 'fCOVER', 'fAPAR', 'Albedo'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution': 100,            # Exporting spatial resolution    
    'out_folder': 'C:/Work_Data/LEAF_tile42_921_2024_100m',  # the folder name for exporting
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    #'start_dates': ['2024-06-15'],
    #'end_dates': ['2024-09-15'],
    #'regions': {'ottawa': ottawa_region}  #, 'vancouver': vancouver_region}    
}

# %%
main(ProdParams, CompParams)
# Out:
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-122.1409, 53.9559], [-120.3386, 51.4542], [-116.2217, 52.4298], [-117.7869, 55.0058], [-122.1409, 53.9559]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.09 minutes
#
# <period_mosaic> A total of 245 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/11/U/NT/2024/8/S2B_11UNT_20240829_0_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/11/U/NT/2024/8/S2B_11UNT_20240829_0_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/11/U/NT/2024/8/S2B_11UNT_20240829_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/11/U/NT/2024/8/S2B_11UNT_20240829_0_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/11/U/NT/2024/8/S2B_11UNT_20240829_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/11/U/NT/2024/8/S2B_11UNT_20240829_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/11/U/NT/2024/8/S2B_11UNT_20240829_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/11/U/NT/2024/8/S2B_11UNT_20240829_0_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/11/U/NT/2024/8/S2B_11UNT_20240829_0_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/11/U/NT/2024/8/S2B_11UNT_20240829_0_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/11/U/NT/2024/8/S2B_11UNT_20240829_0_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/11/U/NT/2024/8/S2B_11UNT_20240829_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/11/U/NT/2024/8/S2B_11UNT_20240829_0_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/11/U/NT/2024/8/S2B_11UNT_20240829_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/11/U/NT/2024/8/S2B_11UNT_20240829_0_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/11/U/NT/2024/8/S2B_11UNT_20240829_0_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/11/U/NT/2024/8/S2B_11UNT_20240829_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/11/U/NT/2024/8/S2B_11UNT_20240829_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/11/U/NT/2024/8/S2B_11UNT_20240829_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/11/U/NT/2024/8/29/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/11/U/NT/2024/8/29/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/11/U/NT/2024/8/29/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/11/U/NT/2024/8/29/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/11/U/NT/2024/8/29/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/11/U/NT/2024/8/29/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/11/U/NT/2024/8/29/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/11/U/NT/2024/8/29/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/11/U/NT/2024/8/29/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/11/U/NT/2024/8/29/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/11/U/NT/2024/8/29/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/11/U/NT/2024/8/29/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/11/U/NT/2024/8/29/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/11/U/NT/2024/8/29/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/11/U/NT/2024/8/29/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/11/U/NT/2024/8/29/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# ID: S2B_11UNT_20240829_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-117.00027894760612, 52.3504641665289], [-117.00027334568982, 51.43656960575973], [-116.93993754734564, 51.561941574671955], [-116.84436452257863, 51.750236203032856], [-116.5219308049674, 52.34949713347982], [-117.00027894760612, 52.3504641665289]]]}
# Bounding Box: [-117.00027894760612, 51.43656960575973, -116.5219308049674, 52.3504641665289]
# Datetime: 2024-08-29 19:09:56.930000+00:00
# cloud cover: 33.237851
# Properties:
#   <created>: 2024-08-30T00:52:32.172Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 33.237851
#   <proj:epsg>: 32611
#   <mgrs:utm_zone>: 11
#   <mgrs:latitude_band>: U
#   <mgrs:grid_square>: NT
#   <grid:code>: MGRS-11UNT
#   <view:sun_azimuth>: 167.218613024983
#   <view:sun_elevation>: 46.5004415358947
#   <s2:degraded_msi_data_percentage>: 0
#   <s2:nodata_pixel_percentage>: 86.230373
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:cloud_shadow_percentage>: 6.04976
#   <s2:vegetation_percentage>: 20.872729
#   <s2:not_vegetated_percentage>: 18.512493
#   <s2:water_percentage>: 0.762714
#   <s2:unclassified_percentage>: 4.724661
#   <s2:medium_proba_clouds_percentage>: 11.668888
#   <s2:high_proba_clouds_percentage>: 21.562649
#   <s2:thin_cirrus_percentage>: 0.006313
#   <s2:snow_ice_percentage>: 4.524453
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.11
#   <s2:product_uri>: S2B_MSIL2A_20240829T185919_N0511_R013_T11UNT_20240829T230848.SAFE
#   <s2:generation_time>: 2024-08-29T23:08:48.000000Z
#   <s2:datatake_id>: GS2B_20240829T185919_039078_N05.11
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_2BPS_20240829T230848_S20240829T190749_N05.11
#   <s2:granule_id>: S2B_OPER_MSI_L2A_TL_2BPS_20240829T230848_A039078_T11UNT_N05.11
#   <s2:reflectance_conversion_factor>: 0.979523560756685
#   <datetime>: 2024-08-29T19:09:56.930000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/11/U/NT/2024/8/S2B_11UNT_20240829_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/c83e37a550648be892f01871345b0437
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '0.1.1'}
#   <updated>: 2024-08-30T00:52:32.172Z
#   <sza>: 43.4995584641053
#   <saa>: 167.218613024983
#   <vza>: 11.0138372754096
#   <vaa>: 295.645190849256
#
# <period_mosaic> based mosaic image =  <xarray.Dataset> Size: 432MB
# Dimensions:      (y: 3001, x: 3001)
# Coordinates:
#   * y            (y) float64 24kB 9.15e+05 9.148e+05 ... 6.15e+05 6.15e+05
#   * x            (x) float64 24kB -1.7e+06 -1.7e+06 ... -1.4e+06 -1.4e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2024-08-29T19:09:56.930000
# Data variables:
#     blue         (y, x) float32 36MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     green        (y, x) float32 36MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     red          (y, x) float32 36MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     rededge1     (y, x) float32 36MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     rededge2     (y, x) float32 36MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     rededge3     (y, x) float32 36MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     nir08        (y, x) float32 36MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     swir16       (y, x) float32 36MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     swir22       (y, x) float32 36MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     scl          (y, x) float32 36MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     date         (y, x) float32 36MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     score        (y, x) float32 36MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#
# <period_mosaic> The number of unique granule tiles = 22
#
# <<<<<< The unique granule tiles =  ['11UMV', '10UFE', '11ULU', '10UFD', '10UFF', '10UGC', '11ULT', '10UGE', '11ULV', '11UMA', '11ULA', '11UNT', '10UGD', '10UFC', '11UNU', '11UMU', '11UMT', '10UEE', '10UED', '10UEF', '11UNV', '11UMB']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\client.py:3361: UserWarning: Sending large graph of size 28.53 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< The total elapsed time for generating the mosaic =   3.84 minutes>>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\dask\array\chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# File 'C:\Work_Data\LEAF_tile42_921_2024_100m\log_cfbd7f89-cc51-4891-b6dd-c6b2e3292024.out' does not exist.
# Directory 'C:\Work_Data\LEAF_tile42_921_2024_100m\dask_spill_cfbd7f89-cc51-4891-b6dd-c6b2e3292024' and its contents have been deleted.
