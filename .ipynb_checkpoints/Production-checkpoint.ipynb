# %%
import os
import sys
import geopandas as gpd

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from leaf_wrapper import LeafWrapper
from Production import main

kml = cwd + "/AfforestationSItesFixed.kml"

# %%
# Load polygons from KML (NOTE: some start dates are a problem since the sentinel-2 only has data from around 2016-present, 
# so some of the data will crash the program when main is called
wrapper = LeafWrapper(kml).load()
regions_dict = wrapper.to_region_dict()  # keys = TARGET_FID

#Access region with TARGET_FID = 2
print(regions_dict[11])

# Select region with TARGET_FID = 4
region_data = regions_dict[11]
region_data2 = regions_dict[5]

ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

test_region = {
    'type': 'Polygon',
    'coordinates': region_data["coordinates"]
}

test_region2 = {
    'type': 'Polygon',
    'coordinates': region_data2["coordinates"]
}

CompParams = {
  "number_workers":20,     
  "debug"       : True,
  "entire_tile" : False, 
  "nodes"       : 1,
  "node_memory" : "25G",
  'chunk_size': {'x': 4096, 'y': 4096}
}


  
ProdParams = {
    'sensor': 'S2_SR',       # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR' or 'HLSS30_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2025,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    #'months': [8],    # A list of integers represening one or multiple monthes     
    #'tile_names': ['tile46_411','tile46_412','tile46_421','tile46_422'],  # A list of (sub-)tile names
    #'tile_names': ['tile46_412'],
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution': 20,            # Exporting spatial resolution  
    'out_folder': 'E:/S2_mosaics_2025/S2_kml_test_4_5__100m',
    #'out_folder': 'E:/S2_mosaics_2025/S2_mosaic_tile46_412_2025_100m',  # the folder name for exporting
    'out_datatype': 'int16',     # 'int8' or 'int16'
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    'start_dates': ['2025-06-15'],
    'end_dates': ['2025-09-15'],
    'regions': {'ottawa': ottawa_region, 'vancouver': vancouver_region},  
    #'start_dates': [region_data["start_date"]],
    #'end_dates': [region_data["end_date"]],
    #'regions': {'region_test': test_region} #, 'region_test2': test_region2}
    
}


print(ProdParams)
# Out:
# {'coordinates': [[[-80.7569341568744, 44.5691909520517], [-80.7566607230147, 44.5688567557109], [-80.7566991088114, 44.5687362710262], [-80.7567649133657, 44.568529725759], [-80.7568032999563, 44.5684092411317], [-80.7567377479886, 44.5682175196673], [-80.7566447764069, 44.5681118586657], [-80.7566679097094, 44.5678802617108], [-80.7565825659824, 44.5678301569264], [-80.7564490685852, 44.5677722125913], [-80.7561415439444, 44.5677040390138], [-80.7560507175409, 44.5676711462586], [-80.7560848200089, 44.5674051246706], [-80.7563179690184, 44.5673887713006], [-80.7567842630557, 44.5673560601777], [-80.7573895391806, 44.5673640778983], [-80.757721140384, 44.5674361663936], [-80.7581063814418, 44.5674988819651], [-80.7584477597977, 44.5676992929832], [-80.7586708980731, 44.5679528735229], [-80.7587178619607, 44.5681234619126], [-80.7587331207467, 44.5682345741272], [-80.758717628055, 44.5685217278542], [-80.7589035810664, 44.5687330462537], [-80.7588990544134, 44.5689857758354], [-80.7569341568744, 44.5691909520517]]], 'start_date': '2009-07-01', 'end_date': '2010-07-01'}
# {'sensor': 'S2_SR', 'unit': 2, 'year': 2025, 'nbYears': -1, 'tile_names': ['tile46_412'], 'prod_names': ['mosaic'], 'resolution': 20, 'out_folder': 'E:/S2_mosaics_2025/S2_kml_test_4_5__100m', 'out_datatype': 'int16', 'projection': 'EPSG:3979', 'IncludeAngles': False, 'start_dates': ['2025-06-15'], 'end_dates': ['2025-09-15']}

# %%
main(ProdParams, CompParams)
# Out:
# <form_spatial_regions> Raw polygon = {'type': 'Polygon', 'coordinates': [[[-56.8731, 53.4275], [-60.4286, 49.9916], [-55.3111, 47.7608], [-51.5381, 50.9785], [-56.8731, 53.4275]]]}
# <MosaicProduction> User defined input parameters:
# sensor: S2_SR
# unit: 2
# year: 2025
# nbYears: -1
# tile_names: ['tile46_412']
# prod_names: ['mosaic']
# resolution: 20
# out_folder: E:/S2_mosaics_2025/S2_kml_test_4_5__100m
# out_datatype: int16
# projection: EPSG:3979
# IncludeAngles: False
# start_dates: ['2025-06-15']
# end_dates: ['2025-09-15']
# SsrData: {'NAME': 'S2_SR', 'SSR_CODE': 21, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], '10M_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'SIX_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'NoA_BANDS': ['red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'LEAF_BANDS': ['green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'GEE_NAME': 'COPERNICUS/S2_SR_HARMONIZED', 'CLOUD': 'CLOUDY_PIXEL_PERCENTAGE', 'SZA': 'view:sun_elevation', 'SAA': 'view:sun_azimuth', 'VZA': 'view:sun_elevation', 'VAA': 'view:sun_azimuth', 'BLU': 'blue', 'GRN': 'green', 'RED': 'red', 'NIR': 'nir08', 'SW1': 'swir16', 'SW2': 'swir22'}
# out_location: drive
# months: []
# cloud_cover: 80
# export_style: separate
# monthly: False
# current_time: 0
# scene_ID:
# regions: {'tile46_412': {'type': 'Polygon', 'coordinates': [[[-57.073100000000004, 53.627500000000005], [-60.628600000000006, 49.791599999999995], [-55.1111, 47.5608], [-51.3381, 51.1785], [-57.073100000000004, 53.627500000000005]]]}}
# current_region: tile46_412
# Criteria: {'timeframe': '2025-06-15/2025-09-15', 'filters': {'eo:cloud_cover': {'lt': 80}}, 'region': {'type': 'Polygon', 'coordinates': [[[-57.073100000000004, 53.627500000000005], [-60.628600000000006, 49.791599999999995], [-55.1111, 47.5608], [-51.3381, 51.1785], [-57.073100000000004, 53.627500000000005]]]}, 'catalog': 'https://earth-search.aws.element84.com/v1', 'collection': ['sentinel-2-l2a'], 'bands': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl']}
# standardized: True
# number_workers: 20
# debug: True
# entire_tile: False
# nodes: 1
# node_memory: 25G
# chunk_size: {'x': 4096, 'y': 4096}
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-57.073100000000004, 53.627500000000005], [-60.628600000000006, 49.791599999999995], [-55.1111, 47.5608], [-51.3381, 51.1785], [-57.073100000000004, 53.627500000000005]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.87 minutes
#
# <one_mosaic> A total of 1444 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/21/U/XP/2025/9/S2C_21UXP_20250913_0_L2A/AOT.tif
# Asset key: blue, title: Blue - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/21/U/XP/2025/9/S2C_21UXP_20250913_0_L2A/B02.tif
# Asset key: cloud, title: Cloud Probabilities, href: s3://sentinel-s2-l2a/tiles/21/U/XP/2025/9/13/0/qi/CLD_20m.jp2
# Asset key: coastal, title: Coastal - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/21/U/XP/2025/9/S2C_21UXP_20250913_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/21/U/XP/2025/9/S2C_21UXP_20250913_0_L2A/granule_metadata.xml
# Asset key: green, title: Green - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/21/U/XP/2025/9/S2C_21UXP_20250913_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/21/U/XP/2025/9/S2C_21UXP_20250913_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/21/U/XP/2025/9/S2C_21UXP_20250913_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/21/U/XP/2025/9/S2C_21UXP_20250913_0_L2A/B09.tif
# Asset key: product_metadata, title: None, href: s3://sentinel-s2-l2a/tiles/21/U/XP/2025/9/13/0/product_metadata.xml
# Asset key: red, title: Red - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/21/U/XP/2025/9/S2C_21UXP_20250913_0_L2A/B04.tif
# Asset key: rededge1, title: Red Edge 1 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/21/U/XP/2025/9/S2C_21UXP_20250913_0_L2A/B05.tif
# Asset key: rededge2, title: Red Edge 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/21/U/XP/2025/9/S2C_21UXP_20250913_0_L2A/B06.tif
# Asset key: rededge3, title: Red Edge 3 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/21/U/XP/2025/9/S2C_21UXP_20250913_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/21/U/XP/2025/9/S2C_21UXP_20250913_0_L2A/SCL.tif
# Asset key: snow, title: Snow Probabilities, href: s3://sentinel-s2-l2a/tiles/21/U/XP/2025/9/13/0/qi/SNW_20m.jp2
# Asset key: swir16, title: SWIR 1.6μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/21/U/XP/2025/9/S2C_21UXP_20250913_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2.2μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/21/U/XP/2025/9/S2C_21UXP_20250913_0_L2A/B12.tif
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/21/U/XP/2025/9/S2C_21UXP_20250913_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/21/U/XP/2025/9/S2C_21UXP_20250913_0_L2A/TCI.tif
# Asset key: wvp, title: Water Vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/21/U/XP/2025/9/S2C_21UXP_20250913_0_L2A/WVP.tif
# Asset key: thumbnail, title: Thumbnail of preview image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/21/U/XP/2025/9/S2C_21UXP_20250913_0_L2A/preview.jpg
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/21/U/XP/2025/9/13/0/R20m/AOT.jp2
# Asset key: blue-jp2, title: Blue - 10m, href: s3://sentinel-s2-l2a/tiles/21/U/XP/2025/9/13/0/R10m/B02.jp2
# Asset key: coastal-jp2, title: Coastal - 60m, href: s3://sentinel-s2-l2a/tiles/21/U/XP/2025/9/13/0/R60m/B01.jp2
# Asset key: green-jp2, title: Green - 10m, href: s3://sentinel-s2-l2a/tiles/21/U/XP/2025/9/13/0/R10m/B03.jp2
# Asset key: nir-jp2, title: NIR 1 - 10m, href: s3://sentinel-s2-l2a/tiles/21/U/XP/2025/9/13/0/R10m/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 - 20m, href: s3://sentinel-s2-l2a/tiles/21/U/XP/2025/9/13/0/R20m/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 - 60m, href: s3://sentinel-s2-l2a/tiles/21/U/XP/2025/9/13/0/R60m/B09.jp2
# Asset key: red-jp2, title: Red - 10m, href: s3://sentinel-s2-l2a/tiles/21/U/XP/2025/9/13/0/R10m/B04.jp2
# Asset key: rededge1-jp2, title: Red Edge 1 - 20m, href: s3://sentinel-s2-l2a/tiles/21/U/XP/2025/9/13/0/R20m/B05.jp2
# Asset key: rededge2-jp2, title: Red Edge 2 - 20m, href: s3://sentinel-s2-l2a/tiles/21/U/XP/2025/9/13/0/R20m/B06.jp2
# Asset key: rededge3-jp2, title: Red Edge 3 - 20m, href: s3://sentinel-s2-l2a/tiles/21/U/XP/2025/9/13/0/R20m/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/21/U/XP/2025/9/13/0/R20m/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1.6μm - 20m, href: s3://sentinel-s2-l2a/tiles/21/U/XP/2025/9/13/0/R20m/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2.2μm - 20m, href: s3://sentinel-s2-l2a/tiles/21/U/XP/2025/9/13/0/R20m/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/21/U/XP/2025/9/13/0/R10m/TCI.jp2
# Asset key: wvp-jp2, title: Water Vapour (WVP), href: s3://sentinel-s2-l2a/tiles/21/U/XP/2025/9/13/0/R20m/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2C_21UXP_20250913_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-55.63970739769837, 48.74497495719576], [-55.6558213979569, 48.13799160345603], [-55.377632515175165, 48.7415826227901], [-55.63970739769837, 48.74497495719576]]]}
# Bounding Box: [-55.655821, 48.137992, -55.377633, 48.744975]
# Datetime: 2025-09-13 14:59:23.550000+00:00
# cloud cover: 60.689586
# Properties:
#   <created>: 2025-09-13T22:31:23.967Z
#   <platform>: sentinel-2c
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 60.689586
#   <proj:centroid>: {'lat': 48.54152, 'lon': -55.55772}
#   <mgrs:utm_zone>: 21
#   <mgrs:latitude_band>: U
#   <mgrs:grid_square>: XP
#   <grid:code>: MGRS-21UXP
#   <view:azimuth>: 294.4914844546913
#   <view:incidence_angle>: 11.267991464794546
#   <view:sun_azimuth>: 167.344105676012
#   <view:sun_elevation>: 44.6320360914888
#   <s2:tile_id>: S2C_OPER_MSI_L2A_TL_2CPS_20250913T210612_A005343_T21UXP_N05.11
#   <s2:degraded_msi_data_percentage>: 0
#   <s2:nodata_pixel_percentage>: 94.524038
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:cloud_shadow_percentage>: 0.003029
#   <s2:vegetation_percentage>: 36.721802
#   <s2:not_vegetated_percentage>: 0.893326
#   <s2:water_percentage>: 1.692194
#   <s2:unclassified_percentage>: 6.1e-05
#   <s2:medium_proba_clouds_percentage>: 17.04748
#   <s2:high_proba_clouds_percentage>: 0.017692
#   <s2:thin_cirrus_percentage>: 43.624419
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.11
#   <s2:product_uri>: S2C_MSIL2A_20250913T145741_N0511_R082_T21UXP_20250913T210612.SAFE
#   <s2:generation_time>: 2025-09-13T21:06:12.000000Z
#   <s2:datatake_id>: GS2C_20250913T145741_005343_N05.11
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2C_OPER_MSI_L2A_DS_2CPS_20250913T210612_S20250913T145831_N05.11
#   <s2:reflectance_conversion_factor>: 0.986471801650202
#   <datetime>: 2025-09-13T14:59:23.550000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/21/U/XP/2025/9/S2C_21UXP_20250913_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/3e107e24f8aafb65deb5d20d635ec0e2
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '2025.03.06'}
#   <updated>: 2025-09-13T22:31:23.967Z
#   <proj:code>: EPSG:32621
#   <sza>: 45.3679639085112
#   <saa>: 167.344105676012
#   <vza>: 11.3143952354076
#   <vaa>: 296.386207252657
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 30GB
# Dimensions:      (y: 25115, x: 24924)
# Coordinates:
#   * y            (y) float64 201kB 1.241e+06 1.241e+06 ... 7.386e+05 7.385e+05
#   * x            (x) float64 199kB 2.327e+06 2.327e+06 ... 2.825e+06 2.825e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-09-13T14:59:23.550000
# Data variables:
#     blue         (y, x) float32 3GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     green        (y, x) float32 3GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     red          (y, x) float32 3GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     rededge1     (y, x) float32 3GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     rededge2     (y, x) float32 3GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     rededge3     (y, x) float32 3GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     nir08        (y, x) float32 3GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir16       (y, x) float32 3GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir22       (y, x) float32 3GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     scl          (y, x) float32 3GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     date         (y, x) float32 3GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     score        (y, x) float32 3GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 47
#
# <<<<<< The unique granule tiles =  ['21UVQ', '20UQB', '21UVP', '21UUS', '20UQV', '20UQA', '21UUR', '21UWS', '21UXP', '21UWU', '21UUT', '21UXQ', '21UWT', '21UUQ', '21UYS', '21UWP', '20UPV', '21UVR', '21UWQ', '21UVT', '20UQC', '21UWV', '20UPA', '21TWN', '21UWR', '21UXU', '21UVS', '21UVV', '21TXN', '21UVU', '21UYP', '22UCV', '21UYQ', '21UXT', '22UCA', '21UYR', '21UXR', '21UXS', '21UYT', '21UYU', '22UDB', '22UCD', '22UCC', '22UDA', '22UCB', '21UUU', '22UDC']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\aradar\AppData\Local\anaconda3\envs\leaftoolbox2\Lib\site-packages\distributed\client.py:3164: UserWarning: Sending large graph of size 542.66 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# 2026-01-26 10:27:32,871 - distributed.scheduler - ERROR - Task ('attach_score-1d3af8f93b964d8c9bc8b2be274be68e', 0, 0, 0) has 23.56 GiB worth of input dependencies, but worker tcp://127.0.0.1:58757 has memory_limit set to 23.28 GiB.
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 main(ProdParams, CompParams)
#
# File ~\LEAF Files\LEAF-Stac\Production.py:221, in main(inProdParams, inCompParams)
#     218   leaf.LEAF_production(prod_params, comp_params)
#     220 else:
# --> 221   MosaicProduction(prod_params, comp_params)
#
# File ~\LEAF Files\LEAF-Stac\Production.py:188, in MosaicProduction(ProdParams, CompParams)
#     186 print('\n<MosaicProduction> Generate and export separate mosaic images......')
#     187 #AIMz.one_mosaicC(usedParams, CompParams)
# --> 188 eoMz.one_mosaic(usedParams, CompParams)
#
# File ~\LEAF Files\LEAF-Stac\source\eoMosaic.py:1619, in one_mosaic(AllParams, Output)
#    1616   client.cancel(future)
#    1618 # We do the compute to get a dask array instead of a future
# -> 1619 base_img = base_img.chunk(ChunkDict).compute()
#    1621 #==========================================================================================================
#    1622 # Mask out the pixels with negative date value
#    1623 #==========================================================================================================
#    1624 mosaic = base_img.where(base_img[eoIM.pix_date] > 0)
#
# File ~\AppData\Local\anaconda3\envs\leaftoolbox2\Lib\site-packages\dask\base.py:375, in DaskMethodsMixin.compute(self, **kwargs)
#     351 def compute(self, **kwargs):
#     352     """Compute this dask collection
#     353
#     354     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)    373     dask.compute
#     374     """
# --> 375     (result,) = compute(self, traverse=False, **kwargs)
#     376     return result
#
# File ~\AppData\Local\anaconda3\envs\leaftoolbox2\Lib\site-packages\dask\base.py:661, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     658     postcomputes.append(x.__dask_postcompute__())
#     660 with shorten_traceback():
# --> 661     results = schedule(dsk, keys, **kwargs)
#     663 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~\AppData\Local\anaconda3\envs\leaftoolbox2\Lib\site-packages\distributed\client.py:2234, in Client._gather(self, futures, errors, direct, local_worker)
#    2232         exc = CancelledError(key)
#    2233     else:
# -> 2234         raise exception.with_traceback(traceback)
#    2235     raise exc
#    2236 if errors == "skip":
#
# MemoryError: Task ('attach_score-1d3af8f93b964d8c9bc8b2be274be68e', 0, 0, 0) has 23.56 GiB worth of input dependencies, but worker tcp://127.0.0.1:58757 has memory_limit set to 23.28 GiB.
