# %%
import os
import sys

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

# %%
ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

CompParams = {
  "debug"       : True,
  "entire_tile" : False,     #
  "nodes"       : 1,
  "node_memory" : "120G",
  "number_workers" : 10
}

  
ProdParams = {
    'sensor': 'HLSS30_SR',       # A sensor type string (e.g., 'S2_SR' or 'HLSS30_SR' or 'MOD_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2024,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    'months': [8],            # A list of integers represening one or multiple monthes     
    'tile_names': ['tile55_922'], # A list of (sub-)tile names (defined using CCRS' tile griding system) 
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution': 30,            # Exporting spatial resolution    
    'out_folder': 'C:/Work_Data/HLSS30_mosaic_ott_vanc_2024_10m_new_mask',  # the folder name for exporting
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    #'start_dates': ['2024-06-15'],
    #'end_dates': ['2024-09-15'],
    'regions': {'ottawa': ottawa_region, 'vancouver': vancouver_region}
}

# %%
main(ProdParams, CompParams)
# Out:
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-76.12, 45.184], [-75.383, 45.171], [-75.39, 45.564], [-76.105, 45.568], [-76.12, 45.184]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.01 minutes
#
# <period_mosaic> A total of 7 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2024/8/S2B_18TVR_20240812_0_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2024/8/S2B_18TVR_20240812_0_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2024/8/S2B_18TVR_20240812_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2024/8/S2B_18TVR_20240812_0_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2024/8/S2B_18TVR_20240812_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2024/8/S2B_18TVR_20240812_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2024/8/S2B_18TVR_20240812_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2024/8/S2B_18TVR_20240812_0_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2024/8/S2B_18TVR_20240812_0_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2024/8/S2B_18TVR_20240812_0_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2024/8/S2B_18TVR_20240812_0_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2024/8/S2B_18TVR_20240812_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2024/8/S2B_18TVR_20240812_0_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2024/8/S2B_18TVR_20240812_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2024/8/S2B_18TVR_20240812_0_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2024/8/S2B_18TVR_20240812_0_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2024/8/S2B_18TVR_20240812_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2024/8/S2B_18TVR_20240812_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2024/8/S2B_18TVR_20240812_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/18/T/VR/2024/8/12/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2024/8/12/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2024/8/12/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2024/8/12/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2024/8/12/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2024/8/12/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2024/8/12/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2024/8/12/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2024/8/12/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2024/8/12/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2024/8/12/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/18/T/VR/2024/8/12/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2024/8/12/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2024/8/12/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2024/8/12/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/18/T/VR/2024/8/12/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# ID: S2B_18TVR_20240812_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-75.61952140445247, 46.051886362023595], [-75.96080682363764, 45.061227271532296], [-74.87603818430986, 45.065201721669794], [-74.87384571020863, 46.053495749294726], [-75.61952140445247, 46.051886362023595]]]}
# Bounding Box: [-75.96080682363764, 45.061227271532296, -74.87384571020863, 46.053495749294726]
# Datetime: 2024-08-12 16:00:43.129000+00:00
# cloud cover: 50.202137
# Properties:
#   <created>: 2024-08-12T21:51:17.901Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 50.202137
#   <mgrs:utm_zone>: 18
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: VR
#   <grid:code>: MGRS-18TVR
#   <view:sun_azimuth>: 150.244560024476
#   <view:sun_elevation>: 56.0855584196875
#   <s2:degraded_msi_data_percentage>: 0.0226
#   <s2:nodata_pixel_percentage>: 34.750417
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:cloud_shadow_percentage>: 12.649655
#   <s2:vegetation_percentage>: 30.373898
#   <s2:not_vegetated_percentage>: 2.684441
#   <s2:water_percentage>: 1.854712
#   <s2:unclassified_percentage>: 2.203202
#   <s2:medium_proba_clouds_percentage>: 16.373831
#   <s2:high_proba_clouds_percentage>: 33.756545
#   <s2:thin_cirrus_percentage>: 0.071762
#   <s2:snow_ice_percentage>: 0.000142
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.11
#   <s2:product_uri>: S2B_MSIL2A_20240812T154819_N0511_R054_T18TVR_20240812T200004.SAFE
#   <s2:generation_time>: 2024-08-12T20:00:04.000000Z
#   <s2:datatake_id>: GS2B_20240812T154819_038833_N05.11
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_2BPS_20240812T200004_S20240812T155513_N05.11
#   <s2:granule_id>: S2B_OPER_MSI_L2A_TL_2BPS_20240812T200004_A038833_T18TVR_N05.11
#   <s2:reflectance_conversion_factor>: 0.973044590709704
#   <datetime>: 2024-08-12T16:00:43.129000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/18/T/VR/2024/8/S2B_18TVR_20240812_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/7d580a6c2eb5427f2ab60b2ab0601ffd
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '0.1.1'}
#   <updated>: 2024-08-12T21:51:17.901Z
#   <proj:code>: EPSG:32618
#   <sza>: 33.9144415803125
#   <saa>: 150.244560024476
#   <vza>: 9.07733075478732
#   <vaa>: 106.738624083964
#
# <period_mosaic> based mosaic image =  <xarray.Dataset> Size: 119MB
# Dimensions:      (y: 1457, x: 1706)
# Coordinates:
#   * y            (y) float64 12kB -1.471e+05 -1.472e+05 ... -2.054e+05
#   * x            (x) float64 14kB 1.475e+06 1.475e+06 ... 1.543e+06 1.543e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2024-08-12T16:00:43.129000
# Data variables:
#     blue         (y, x) float32 10MB dask.array<chunksize=(1457, 1706), meta=np.ndarray>
#     green        (y, x) float32 10MB dask.array<chunksize=(1457, 1706), meta=np.ndarray>
#     red          (y, x) float32 10MB dask.array<chunksize=(1457, 1706), meta=np.ndarray>
#     rededge1     (y, x) float32 10MB dask.array<chunksize=(1457, 1706), meta=np.ndarray>
#     rededge2     (y, x) float32 10MB dask.array<chunksize=(1457, 1706), meta=np.ndarray>
#     rededge3     (y, x) float32 10MB dask.array<chunksize=(1457, 1706), meta=np.ndarray>
#     nir08        (y, x) float32 10MB dask.array<chunksize=(1457, 1706), meta=np.ndarray>
#     swir16       (y, x) float32 10MB dask.array<chunksize=(1457, 1706), meta=np.ndarray>
#     swir22       (y, x) float32 10MB dask.array<chunksize=(1457, 1706), meta=np.ndarray>
#     scl          (y, x) float32 10MB dask.array<chunksize=(1457, 1706), meta=np.ndarray>
#     date         (y, x) float32 10MB dask.array<chunksize=(1457, 1706), meta=np.ndarray>
#     score        (y, x) float32 10MB dask.array<chunksize=(1457, 1706), meta=np.ndarray>
#
# <period_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['18TVR']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
#
# <<<<<<<<<< The total elapsed time for generating the mosaic =   2.82 minutes>>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\dask\array\chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# File 'C:\Work_Data\S2_mosaic_ott_vanc_2024_40m_new_mask\log_b170f921-81a1-4c82-a7e2-49a8a34d2523.out' does not exist.
# Directory 'C:\Work_Data\S2_mosaic_ott_vanc_2024_40m_new_mask\dask_spill_b170f921-81a1-4c82-a7e2-49a8a34d2523' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-123.32, 49.37], [-122.44, 49.35], [-122.96, 48.75], [-123.27, 48.96], [-123.32, 49.37]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.02 minutes
#
# <period_mosaic> A total of 23 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/DV/2024/8/S2A_10UDV_20240810_0_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/DV/2024/8/S2A_10UDV_20240810_0_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/DV/2024/8/S2A_10UDV_20240810_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/DV/2024/8/S2A_10UDV_20240810_0_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/DV/2024/8/S2A_10UDV_20240810_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/DV/2024/8/S2A_10UDV_20240810_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/DV/2024/8/S2A_10UDV_20240810_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/DV/2024/8/S2A_10UDV_20240810_0_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/DV/2024/8/S2A_10UDV_20240810_0_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/DV/2024/8/S2A_10UDV_20240810_0_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/DV/2024/8/S2A_10UDV_20240810_0_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/DV/2024/8/S2A_10UDV_20240810_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/DV/2024/8/S2A_10UDV_20240810_0_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/DV/2024/8/S2A_10UDV_20240810_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/DV/2024/8/S2A_10UDV_20240810_0_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/DV/2024/8/S2A_10UDV_20240810_0_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/DV/2024/8/S2A_10UDV_20240810_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/DV/2024/8/S2A_10UDV_20240810_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/DV/2024/8/S2A_10UDV_20240810_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/10/U/DV/2024/8/10/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/10/U/DV/2024/8/10/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/10/U/DV/2024/8/10/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/10/U/DV/2024/8/10/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/10/U/DV/2024/8/10/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/10/U/DV/2024/8/10/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/10/U/DV/2024/8/10/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/10/U/DV/2024/8/10/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/10/U/DV/2024/8/10/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/10/U/DV/2024/8/10/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/10/U/DV/2024/8/10/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/10/U/DV/2024/8/10/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/10/U/DV/2024/8/10/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/10/U/DV/2024/8/10/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/10/U/DV/2024/8/10/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/10/U/DV/2024/8/10/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# ID: S2A_10UDV_20240810_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-123.37409430787012, 48.66443298020229], [-123.20389655793687, 49.028089637481195], [-123.55167837861846, 49.110849183978004], [-123.97200522150557, 49.204130462252415], [-124.37572329144687, 49.288993081483675], [-124.35844044147314, 48.65702992832568], [-123.37409430787012, 48.66443298020229]]]}
# Bounding Box: [-124.37572329144687, 48.65702992832568, -123.20389655793687, 49.288993081483675]
# Datetime: 2024-08-10 19:31:00.746000+00:00
# cloud cover: 0.000534
# Properties:
#   <created>: 2024-08-11T02:10:28.682Z
#   <platform>: sentinel-2a
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 0.000534
#   <mgrs:utm_zone>: 10
#   <mgrs:latitude_band>: U
#   <mgrs:grid_square>: DV
#   <grid:code>: MGRS-10UDV
#   <view:sun_azimuth>: 159.387264207062
#   <view:sun_elevation>: 54.6408711886071
#   <s2:degraded_msi_data_percentage>: 0.0322
#   <s2:nodata_pixel_percentage>: 62.703103
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:cloud_shadow_percentage>: 0
#   <s2:vegetation_percentage>: 69.468474
#   <s2:not_vegetated_percentage>: 4.549598
#   <s2:water_percentage>: 25.193673
#   <s2:unclassified_percentage>: 0.195413
#   <s2:medium_proba_clouds_percentage>: 0.000516
#   <s2:high_proba_clouds_percentage>: 1.8e-05
#   <s2:thin_cirrus_percentage>: 0
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.11
#   <s2:product_uri>: S2A_MSIL2A_20240810T191911_N0511_R099_T10UDV_20240811T005649.SAFE
#   <s2:generation_time>: 2024-08-11T00:56:49.000000Z
#   <s2:datatake_id>: GS2A_20240810T191911_047715_N05.11
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2A_OPER_MSI_L2A_DS_2APS_20240811T005649_S20240810T193052_N05.11
#   <s2:granule_id>: S2A_OPER_MSI_L2A_TL_2APS_20240811T005649_A047715_T10UDV_N05.11
#   <s2:reflectance_conversion_factor>: 0.972475643072822
#   <datetime>: 2024-08-10T19:31:00.746000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/10/U/DV/2024/8/S2A_10UDV_20240810_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/5230169f5a9cd7de9ecb0e647b68a079
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '0.1.1'}
#   <updated>: 2024-08-11T02:10:28.682Z
#   <proj:code>: EPSG:32610
#   <sza>: 35.3591288113929
#   <saa>: 159.387264207062
#   <vza>: 8.43351170719585
#   <vaa>: 288.800658162257
#
# <period_mosaic> based mosaic image =  <xarray.Dataset> Size: 162MB
# Dimensions:      (y: 1840, x: 1831)
# Coordinates:
#   * y            (y) float64 15kB 4.909e+05 4.908e+05 ... 4.173e+05 4.173e+05
#   * x            (x) float64 15kB -2.003e+06 -2.003e+06 ... -1.93e+06 -1.93e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2024-08-10T19:31:00.746000
# Data variables:
#     blue         (y, x) float32 13MB dask.array<chunksize=(1840, 1831), meta=np.ndarray>
#     green        (y, x) float32 13MB dask.array<chunksize=(1840, 1831), meta=np.ndarray>
#     red          (y, x) float32 13MB dask.array<chunksize=(1840, 1831), meta=np.ndarray>
#     rededge1     (y, x) float32 13MB dask.array<chunksize=(1840, 1831), meta=np.ndarray>
#     rededge2     (y, x) float32 13MB dask.array<chunksize=(1840, 1831), meta=np.ndarray>
#     rededge3     (y, x) float32 13MB dask.array<chunksize=(1840, 1831), meta=np.ndarray>
#     nir08        (y, x) float32 13MB dask.array<chunksize=(1840, 1831), meta=np.ndarray>
#     swir16       (y, x) float32 13MB dask.array<chunksize=(1840, 1831), meta=np.ndarray>
#     swir22       (y, x) float32 13MB dask.array<chunksize=(1840, 1831), meta=np.ndarray>
#     scl          (y, x) float32 13MB dask.array<chunksize=(1840, 1831), meta=np.ndarray>
#     date         (y, x) float32 13MB dask.array<chunksize=(1840, 1831), meta=np.ndarray>
#     score        (y, x) float32 13MB dask.array<chunksize=(1840, 1831), meta=np.ndarray>
#
# <period_mosaic> The number of unique granule tiles = 4
#
# <<<<<< The unique granule tiles =  ['10UDV', '10UEV', '10UDU', '10UEU']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
#
# <<<<<<<<<< The total elapsed time for generating the mosaic =   3.07 minutes>>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\dask\array\chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# File 'C:\Work_Data\S2_mosaic_ott_vanc_2024_40m_new_mask\log_1d84c571-7784-49d5-b666-cfba31c2b416.out' does not exist.
# Directory 'C:\Work_Data\S2_mosaic_ott_vanc_2024_40m_new_mask\dask_spill_1d84c571-7784-49d5-b666-cfba31c2b416' and its contents have been deleted.
