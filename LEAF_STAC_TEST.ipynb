# %%
import os
import sys
import geopandas as gpd

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

kml = os.path.join(os.getcwd(), "AfforestationSItesFixed.kml")

print(kml)
# Out:
# C:\Users\aradar\LEAF Files\LEAF-Stac\AfforestationSItesFixed.kml

# %%
ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

CompParams = {
  "number_workers":20,     
  "debug"       : True,
  "entire_tile" : False, 
  "nodes"       : 1,
  "node_memory" : "25G",
  'chunk_size': {'x': 512, 'y': 512}
}


  
ProdParams = {
    'sensor': 'S2_SR',       # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR' or 'HLSS30_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2025,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    #'months': [8],    # A list of integers represening one or multiple monthes     
    #'tile_names': ['tile46_411','tile46_412','tile46_421','tile46_422'],  # A list of (sub-)tile names
    #'tile_names': ['tile46_412'],
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution': 20,            # Exporting spatial resolution  
    'out_folder': 'E:/S2_mosaics_2025/S2_kml_region11_20m',
    #'out_folder': 'E:/S2_mosaics_2025/S2_mosaic_tile46_412_2025_20m',  # the folder name for exporting
    'out_datatype': 'int16',     # 'int8' or 'int16'
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    'start_dates': ['2025-06-15'],
    'end_dates': ['2025-09-15'],
    'regions': {'ottawa': ottawa_region, 'vancouver': vancouver_region},  
    #'start_dates': [region_data["start_date"]],
    #'end_dates': [region_data["end_date"]],
    #'regions': kml 
    
}


print(ProdParams)
# Out:
# {'sensor': 'S2_SR', 'unit': 2, 'year': 2025, 'nbYears': -1, 'prod_names': ['mosaic'], 'resolution': 20, 'out_folder': 'E:/S2_mosaics_2025/S2_kml_region11_20m', 'out_datatype': 'int16', 'projection': 'EPSG:3979', 'IncludeAngles': False, 'start_dates': ['2025-06-15'], 'end_dates': ['2025-09-15'], 'regions': 'C:\\Users\\aradar\\LEAF Files\\LEAF-Stac\\AfforestationSItesFixed.kml'}

# %%
main(ProdParams, CompParams)

print(ProdParams)
# Out:
# <MosaicProduction> Detected KML regions input, loading regions from KML...
# <MosaicProduction> User defined input parameters:
# sensor: S2_SR
# unit: 2
# year: 2025
# nbYears: -1
# prod_names: ['mosaic']
# resolution: 20
# out_folder: E:/S2_mosaics_2025/S2_kml_region11_20m
# out_datatype: int16
# projection: EPSG:3979
# IncludeAngles: False
# start_dates: ['2025-06-15']
# end_dates: ['2025-09-15']
# regions: {'region1': {'type': 'Polygon', 'coordinates': [[[-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.2868313289172, 44.3529866183925], [-80.2871254773415, 44.3529366809224], [-80.2874977225433, 44.3529180592246], [-80.2876405698119, 44.3529059627622], [-80.2879206306362, 44.3528989373857], [-80.2880395541161, 44.3528827993289], [-80.2880782566738, 44.352880279965], [-80.2882027280036, 44.353154957613], [-80.288085927134, 44.3531261618167], [-80.287951530048, 44.3531125098555], [-80.2878832692439, 44.3531281508011], [-80.287738989293, 44.3532215337679], [-80.2877249039523, 44.3532644472593], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3533270111586], [-80.2871598357525, 44.3533320137857], [-80.2866384110016, 44.3533435417762]]]}, 'region2': {'type': 'Polygon', 'coordinates': [[[-80.529638877948, 44.5242213601121], [-80.5236686736853, 44.5252976281762], [-80.5234042910143, 44.5252538220711], [-80.5231938083608, 44.5249653160984], [-80.5230220292666, 44.5247919216231], [-80.5294731056627, 44.5235598453566], [-80.529638877948, 44.5242213601121]]]}, 'region3': {'type': 'Polygon', 'coordinates': [[[-80.3772169808165, 44.3239559238229], [-80.3778062318809, 44.3239281559541], [-80.3783858830901, 44.3257096706257], [-80.3764241776696, 44.3259233842728], [-80.376232840644, 44.3258912372486], [-80.3761778827904, 44.3258276760676], [-80.3757712939805, 44.325759362561], [-80.3752059343744, 44.3257911355417], [-80.3747978938721, 44.3239478686715], [-80.3765005174368, 44.3236001331235], [-80.3766048311268, 44.3237444227003], [-80.3766908273936, 44.3238675253118], [-80.3769060715396, 44.323903689341], [-80.3772169808165, 44.3239559238229]]]}, 'region4': {'type': 'Polygon', 'coordinates': [[[-80.4414758461818, 44.4468399119331], [-80.4399721805282, 44.4471867620164], [-80.4395657798354, 44.4447820571645], [-80.44099741403, 44.4444232095963], [-80.4414758461818, 44.4468399119331]]]}, 'region5': {'type': 'Polygon', 'coordinates': [[[-80.4421816733383, 44.4466135137253], [-80.4416845003799, 44.4468203876096], [-80.4411932481774, 44.444365318568], [-80.4415073722911, 44.4442547096037], [-80.4421816733383, 44.4466135137253]]]}}
# SsrData: {'NAME': 'S2_SR', 'SSR_CODE': 21, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], '10M_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'SIX_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'NoA_BANDS': ['red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'LEAF_BANDS': ['green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'GEE_NAME': 'COPERNICUS/S2_SR_HARMONIZED', 'CLOUD': 'CLOUDY_PIXEL_PERCENTAGE', 'SZA': 'view:sun_elevation', 'SAA': 'view:sun_azimuth', 'VZA': 'view:sun_elevation', 'VAA': 'view:sun_azimuth', 'BLU': 'blue', 'GRN': 'green', 'RED': 'red', 'NIR': 'nir08', 'SW1': 'swir16', 'SW2': 'swir22'}
# out_location: drive
# months: []
# tile_names: []
# cloud_cover: 80
# export_style: separate
# monthly: False
# current_time: 0
# scene_ID:
# current_region: region1
# Criteria: {'timeframe': '2025-06-15/2025-09-15', 'filters': {'eo:cloud_cover': {'lt': 80}}, 'region': {'type': 'Polygon', 'coordinates': [[[-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.2868313289172, 44.3529866183925], [-80.2871254773415, 44.3529366809224], [-80.2874977225433, 44.3529180592246], [-80.2876405698119, 44.3529059627622], [-80.2879206306362, 44.3528989373857], [-80.2880395541161, 44.3528827993289], [-80.2880782566738, 44.352880279965], [-80.2882027280036, 44.353154957613], [-80.288085927134, 44.3531261618167], [-80.287951530048, 44.3531125098555], [-80.2878832692439, 44.3531281508011], [-80.287738989293, 44.3532215337679], [-80.2877249039523, 44.3532644472593], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3533270111586], [-80.2871598357525, 44.3533320137857], [-80.2866384110016, 44.3533435417762]]]}, 'catalog': 'https://earth-search.aws.element84.com/v1', 'collection': ['sentinel-2-l2a'], 'bands': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl']}
# standardized: True
# number_workers: 20
# debug: True
# entire_tile: False
# nodes: 1
# node_memory: 25G
# chunk_size: {'x': 512, 'y': 512}
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.2868313289172, 44.3529866183925], [-80.2871254773415, 44.3529366809224], [-80.2874977225433, 44.3529180592246], [-80.2876405698119, 44.3529059627622], [-80.2879206306362, 44.3528989373857], [-80.2880395541161, 44.3528827993289], [-80.2880782566738, 44.352880279965], [-80.2882027280036, 44.353154957613], [-80.288085927134, 44.3531261618167], [-80.287951530048, 44.3531125098555], [-80.2878832692439, 44.3531281508011], [-80.287738989293, 44.3532215337679], [-80.2877249039523, 44.3532644472593], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3533270111586], [-80.2871598357525, 44.3533320137857], [-80.2866384110016, 44.3533435417762]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.04 minutes
#
# <one_mosaic> A total of 34 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/AOT.tif
# Asset key: blue, title: Blue - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B02.tif
# Asset key: cloud, title: Cloud Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/qi/CLD_20m.jp2
# Asset key: coastal, title: Coastal - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/granule_metadata.xml
# Asset key: green, title: Green - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B09.tif
# Asset key: product_metadata, title: None, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/product_metadata.xml
# Asset key: red, title: Red - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B04.tif
# Asset key: rededge1, title: Red Edge 1 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B05.tif
# Asset key: rededge2, title: Red Edge 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B06.tif
# Asset key: rededge3, title: Red Edge 3 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/SCL.tif
# Asset key: snow, title: Snow Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/qi/SNW_20m.jp2
# Asset key: swir16, title: SWIR 1.6μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2.2μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B12.tif
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/TCI.tif
# Asset key: wvp, title: Water Vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/WVP.tif
# Asset key: thumbnail, title: Thumbnail of preview image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/preview.jpg
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R20m/AOT.jp2
# Asset key: blue-jp2, title: Blue - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R10m/B02.jp2
# Asset key: coastal-jp2, title: Coastal - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R60m/B01.jp2
# Asset key: green-jp2, title: Green - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R10m/B03.jp2
# Asset key: nir-jp2, title: NIR 1 - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R10m/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R20m/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R60m/B09.jp2
# Asset key: red-jp2, title: Red - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R10m/B04.jp2
# Asset key: rededge1-jp2, title: Red Edge 1 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R20m/B05.jp2
# Asset key: rededge2-jp2, title: Red Edge 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R20m/B06.jp2
# Asset key: rededge3-jp2, title: Red Edge 3 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R20m/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R20m/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1.6μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R20m/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2.2μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R20m/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R10m/TCI.jp2
# Asset key: wvp-jp2, title: Water Vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/R20m/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2C_17TNK_20250821_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-81.00024171761814, 45.153828248771845], [-81.00023764893123, 44.16627582537803], [-80.01584714999262, 44.16221649073625], [-79.61713183890808, 45.14545548657298], [-81.00024171761814, 45.153828248771845]]]}
# Bounding Box: [-81.000242, 44.162216, -79.617132, 45.153828]
# Datetime: 2025-08-21 16:31:16.711000+00:00
# cloud cover: 18.512073
# Properties:
#   <created>: 2025-08-21T22:46:25.125Z
#   <platform>: sentinel-2c
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 18.512073
#   <proj:centroid>: {'lat': 44.68464, 'lon': -80.40298}
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:azimuth>: 286.14725199948623
#   <view:incidence_angle>: 8.106150437477405
#   <view:sun_azimuth>: 156.811872764238
#   <view:sun_elevation>: 55.2955297467904
#   <s2:tile_id>: S2C_OPER_MSI_L2A_TL_2CPS_20250821T210914_A005015_T17TNK_N05.11
#   <s2:degraded_msi_data_percentage>: 0.0171
#   <s2:nodata_pixel_percentage>: 14.533134
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:cloud_shadow_percentage>: 6.665886
#   <s2:vegetation_percentage>: 32.629919
#   <s2:not_vegetated_percentage>: 2.734978
#   <s2:water_percentage>: 39.121401
#   <s2:unclassified_percentage>: 0.268523
#   <s2:medium_proba_clouds_percentage>: 5.186015
#   <s2:high_proba_clouds_percentage>: 4.769121
#   <s2:thin_cirrus_percentage>: 8.556937
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.11
#   <s2:product_uri>: S2C_MSIL2A_20250821T161921_N0511_R040_T17TNK_20250821T210914.SAFE
#   <s2:generation_time>: 2025-08-21T21:09:14.000000Z
#   <s2:datatake_id>: GS2C_20250821T161921_005015_N05.11
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2C_OPER_MSI_L2A_DS_2CPS_20250821T210914_S20250821T162900_N05.11
#   <s2:reflectance_conversion_factor>: 0.976079260018279
#   <datetime>: 2025-08-21T16:31:16.711000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/8e84e299d1da0ecaeed3e21e8b4c974c
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '2025.03.06'}
#   <updated>: 2025-08-21T22:46:25.125Z
#   <proj:code>: EPSG:32617
#   <sza>: 34.7044702532096
#   <saa>: 156.811872764238
#   <vza>: 8.17286668600843
#   <vaa>: 286.221140482994
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 2kB
# Dimensions:      (y: 5, x: 8)
# Coordinates:
#   * y            (y) float64 40B -3.838e+05 -3.838e+05 ... -3.838e+05 -3.839e+05
#   * x            (x) float64 64B 1.187e+06 1.187e+06 ... 1.187e+06 1.187e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-08-21T16:31:16.711000
# Data variables:
#     blue         (y, x) float32 160B dask.array<chunksize=(5, 8), meta=np.ndarray>
#     green        (y, x) float32 160B dask.array<chunksize=(5, 8), meta=np.ndarray>
#     red          (y, x) float32 160B dask.array<chunksize=(5, 8), meta=np.ndarray>
#     rededge1     (y, x) float32 160B dask.array<chunksize=(5, 8), meta=np.ndarray>
#     rededge2     (y, x) float32 160B dask.array<chunksize=(5, 8), meta=np.ndarray>
#     rededge3     (y, x) float32 160B dask.array<chunksize=(5, 8), meta=np.ndarray>
#     nir08        (y, x) float32 160B dask.array<chunksize=(5, 8), meta=np.ndarray>
#     swir16       (y, x) float32 160B dask.array<chunksize=(5, 8), meta=np.ndarray>
#     swir22       (y, x) float32 160B dask.array<chunksize=(5, 8), meta=np.ndarray>
#     scl          (y, x) float32 160B dask.array<chunksize=(5, 8), meta=np.ndarray>
#     date         (y, x) float32 160B dask.array<chunksize=(5, 8), meta=np.ndarray>
#     score        (y, x) float32 160B dask.array<chunksize=(5, 8), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   1.51 minutes >>>>>>
# File 'E:\S2_mosaics_2025\S2_kml_region11_20m\log_7122288c-20d7-49af-8ab7-699229e4942a.out' does not exist.
# Directory 'E:\S2_mosaics_2025\S2_kml_region11_20m\dask_spill_7122288c-20d7-49af-8ab7-699229e4942a' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-80.529638877948, 44.5242213601121], [-80.5236686736853, 44.5252976281762], [-80.5234042910143, 44.5252538220711], [-80.5231938083608, 44.5249653160984], [-80.5230220292666, 44.5247919216231], [-80.5294731056627, 44.5235598453566], [-80.529638877948, 44.5242213601121]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.04 minutes
#
# <one_mosaic> A total of 33 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/AOT.tif
# Asset key: blue, title: Blue - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B02.tif
# Asset key: cloud, title: Cloud Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/qi/CLD_20m.jp2
# Asset key: coastal, title: Coastal - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/granule_metadata.xml
# Asset key: green, title: Green - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B09.tif
# Asset key: product_metadata, title: None, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/product_metadata.xml
# Asset key: red, title: Red - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B04.tif
# Asset key: rededge1, title: Red Edge 1 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B05.tif
# Asset key: rededge2, title: Red Edge 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B06.tif
# Asset key: rededge3, title: Red Edge 3 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/SCL.tif
# Asset key: snow, title: Snow Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/qi/SNW_20m.jp2
# Asset key: swir16, title: SWIR 1.6μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2.2μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B12.tif
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/TCI.tif
# Asset key: wvp, title: Water Vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/WVP.tif
# Asset key: thumbnail, title: Thumbnail of preview image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/preview.jpg
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R20m/AOT.jp2
# Asset key: blue-jp2, title: Blue - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R10m/B02.jp2
# Asset key: coastal-jp2, title: Coastal - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R60m/B01.jp2
# Asset key: green-jp2, title: Green - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R10m/B03.jp2
# Asset key: nir-jp2, title: NIR 1 - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R10m/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R20m/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R60m/B09.jp2
# Asset key: red-jp2, title: Red - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R10m/B04.jp2
# Asset key: rededge1-jp2, title: Red Edge 1 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R20m/B05.jp2
# Asset key: rededge2-jp2, title: Red Edge 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R20m/B06.jp2
# Asset key: rededge3-jp2, title: Red Edge 3 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R20m/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R20m/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1.6μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R20m/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2.2μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R20m/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R10m/TCI.jp2
# Asset key: wvp-jp2, title: Water Vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R20m/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2B_17TNK_20250816_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-81.00024171761814, 45.153828248771845], [-81.00023764893123, 44.16627582535331], [-80.00625227938608, 44.16213326272399], [-79.60721311385011, 45.145334935216574], [-81.00024171761814, 45.153828248771845]]]}
# Bounding Box: [-81.000242, 44.162133, -79.607213, 45.153828]
# Datetime: 2025-08-16 16:30:59.497000+00:00
# cloud cover: 46.567771
# Properties:
#   <created>: 2025-08-16T19:41:59.474Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 46.567771
#   <proj:centroid>: {'lat': 44.68438, 'lon': -80.39815}
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:azimuth>: 285.1145525878699
#   <view:incidence_angle>: 8.134537630664688
#   <view:sun_azimuth>: 155.345021823521
#   <view:sun_elevation>: 56.7537349780884
#   <s2:tile_id>: S2B_OPER_MSI_L2A_TL_2BPS_20250816T183457_A044110_T17TNK_N05.11
#   <s2:degraded_msi_data_percentage>: 0.0229
#   <s2:nodata_pixel_percentage>: 13.829789
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:cloud_shadow_percentage>: 0.761176
#   <s2:vegetation_percentage>: 27.420518
#   <s2:not_vegetated_percentage>: 2.461837
#   <s2:water_percentage>: 22.38107
#   <s2:unclassified_percentage>: 0.310914
#   <s2:medium_proba_clouds_percentage>: 7.442368
#   <s2:high_proba_clouds_percentage>: 26.853248
#   <s2:thin_cirrus_percentage>: 12.272155
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.11
#   <s2:product_uri>: S2B_MSIL2A_20250816T161829_N0511_R040_T17TNK_20250816T183457.SAFE
#   <s2:generation_time>: 2025-08-16T18:34:57.000000Z
#   <s2:datatake_id>: GS2B_20250816T161829_044110_N05.11
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_2BPS_20250816T183457_S20250816T162600_N05.11
#   <s2:reflectance_conversion_factor>: 0.974268282300954
#   <datetime>: 2025-08-16T16:30:59.497000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/3705f16607e58b854bfa9ab75376facd
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '2025.03.06'}
#   <updated>: 2025-08-16T19:41:59.474Z
#   <proj:code>: EPSG:32617
#   <sza>: 33.2462650219116
#   <saa>: 155.345021823521
#   <vza>: 8.21255064269149
#   <vaa>: 285.271134136974
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 20kB
# Dimensions:      (y: 15, x: 27)
# Coordinates:
#   * y            (y) float64 120B -3.692e+05 -3.692e+05 ... -3.695e+05
#   * x            (x) float64 216B 1.163e+06 1.163e+06 ... 1.163e+06 1.164e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-08-16T16:30:59.497000
# Data variables:
#     blue         (y, x) float32 2kB dask.array<chunksize=(15, 27), meta=np.ndarray>
#     green        (y, x) float32 2kB dask.array<chunksize=(15, 27), meta=np.ndarray>
#     red          (y, x) float32 2kB dask.array<chunksize=(15, 27), meta=np.ndarray>
#     rededge1     (y, x) float32 2kB dask.array<chunksize=(15, 27), meta=np.ndarray>
#     rededge2     (y, x) float32 2kB dask.array<chunksize=(15, 27), meta=np.ndarray>
#     rededge3     (y, x) float32 2kB dask.array<chunksize=(15, 27), meta=np.ndarray>
#     nir08        (y, x) float32 2kB dask.array<chunksize=(15, 27), meta=np.ndarray>
#     swir16       (y, x) float32 2kB dask.array<chunksize=(15, 27), meta=np.ndarray>
#     swir22       (y, x) float32 2kB dask.array<chunksize=(15, 27), meta=np.ndarray>
#     scl          (y, x) float32 2kB dask.array<chunksize=(15, 27), meta=np.ndarray>
#     date         (y, x) float32 2kB dask.array<chunksize=(15, 27), meta=np.ndarray>
#     score        (y, x) float32 2kB dask.array<chunksize=(15, 27), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   1.21 minutes >>>>>>
# File 'E:\S2_mosaics_2025\S2_kml_region11_20m\log_33d5f34e-5f77-4f39-a4a8-8077a0551677.out' does not exist.
# Directory 'E:\S2_mosaics_2025\S2_kml_region11_20m\dask_spill_33d5f34e-5f77-4f39-a4a8-8077a0551677' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-80.3772169808165, 44.3239559238229], [-80.3778062318809, 44.3239281559541], [-80.3783858830901, 44.3257096706257], [-80.3764241776696, 44.3259233842728], [-80.376232840644, 44.3258912372486], [-80.3761778827904, 44.3258276760676], [-80.3757712939805, 44.325759362561], [-80.3752059343744, 44.3257911355417], [-80.3747978938721, 44.3239478686715], [-80.3765005174368, 44.3236001331235], [-80.3766048311268, 44.3237444227003], [-80.3766908273936, 44.3238675253118], [-80.3769060715396, 44.323903689341], [-80.3772169808165, 44.3239559238229]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.04 minutes
#
# <one_mosaic> A total of 34 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250813_0_L2A/AOT.tif
# Asset key: blue, title: Blue - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250813_0_L2A/B02.tif
# Asset key: cloud, title: Cloud Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/0/qi/CLD_20m.jp2
# Asset key: coastal, title: Coastal - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250813_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250813_0_L2A/granule_metadata.xml
# Asset key: green, title: Green - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250813_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250813_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250813_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250813_0_L2A/B09.tif
# Asset key: product_metadata, title: None, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/0/product_metadata.xml
# Asset key: red, title: Red - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250813_0_L2A/B04.tif
# Asset key: rededge1, title: Red Edge 1 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250813_0_L2A/B05.tif
# Asset key: rededge2, title: Red Edge 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250813_0_L2A/B06.tif
# Asset key: rededge3, title: Red Edge 3 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250813_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250813_0_L2A/SCL.tif
# Asset key: snow, title: Snow Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/0/qi/SNW_20m.jp2
# Asset key: swir16, title: SWIR 1.6μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250813_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2.2μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250813_0_L2A/B12.tif
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250813_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250813_0_L2A/TCI.tif
# Asset key: wvp, title: Water Vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250813_0_L2A/WVP.tif
# Asset key: thumbnail, title: Thumbnail of preview image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250813_0_L2A/preview.jpg
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/0/R20m/AOT.jp2
# Asset key: blue-jp2, title: Blue - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/0/R10m/B02.jp2
# Asset key: coastal-jp2, title: Coastal - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/0/R60m/B01.jp2
# Asset key: green-jp2, title: Green - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/0/R10m/B03.jp2
# Asset key: nir-jp2, title: NIR 1 - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/0/R10m/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/0/R20m/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/0/R60m/B09.jp2
# Asset key: red-jp2, title: Red - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/0/R10m/B04.jp2
# Asset key: rededge1-jp2, title: Red Edge 1 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/0/R20m/B05.jp2
# Asset key: rededge2-jp2, title: Red Edge 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/0/R20m/B06.jp2
# Asset key: rededge3-jp2, title: Red Edge 3 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/0/R20m/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/0/R20m/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1.6μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/0/R20m/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2.2μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/0/R20m/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/0/R10m/TCI.jp2
# Asset key: wvp-jp2, title: Water Vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/0/R20m/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2B_17TNK_20250813_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-80.95555405141977, 45.15381960076859], [-81.00024116330452, 45.02224826772927], [-81.00023764531663, 44.16537549832127], [-79.62711829312833, 44.15712570786563], [-79.60360176290054, 45.14529082911873], [-80.95555405141977, 45.15381960076859]]]}
# Bounding Box: [-81.000241, 44.157126, -79.603602, 45.15382]
# Datetime: 2025-08-13 16:21:03.271000+00:00
# cloud cover: 28.539544
# Properties:
#   <created>: 2025-08-13T21:31:47.250Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 28.539544
#   <proj:centroid>: {'lat': 44.6559, 'lon': -80.30637}
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:azimuth>: 107.04186648416454
#   <view:incidence_angle>: 6.9191177227506016
#   <view:sun_azimuth>: 150.363340054865
#   <view:sun_elevation>: 56.7835304926348
#   <s2:tile_id>: S2B_OPER_MSI_L2A_TL_2BPS_20250813T201211_A044067_T17TNK_N05.11
#   <s2:degraded_msi_data_percentage>: 0.0408
#   <s2:nodata_pixel_percentage>: 0.200394
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:cloud_shadow_percentage>: 3.792804
#   <s2:vegetation_percentage>: 24.206711
#   <s2:not_vegetated_percentage>: 2.838167
#   <s2:water_percentage>: 39.45013
#   <s2:unclassified_percentage>: 1.094097
#   <s2:medium_proba_clouds_percentage>: 8.985894
#   <s2:high_proba_clouds_percentage>: 14.679
#   <s2:thin_cirrus_percentage>: 4.87465
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.11
#   <s2:product_uri>: S2B_MSIL2A_20250813T160829_N0511_R140_T17TNK_20250813T201211.SAFE
#   <s2:generation_time>: 2025-08-13T20:12:11.000000Z
#   <s2:datatake_id>: GS2B_20250813T160829_044067_N05.11
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_2BPS_20250813T201211_S20250813T160906_N05.11
#   <s2:reflectance_conversion_factor>: 0.973270610774753
#   <datetime>: 2025-08-13T16:21:03.271000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250813_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/12ad34b7a59c31ccf4e3c385859262e2
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '2025.03.06'}
#   <updated>: 2025-08-13T21:31:47.250Z
#   <proj:code>: EPSG:32617
#   <sza>: 33.2164695073652
#   <saa>: 150.363340054865
#   <vza>: 7.00014719977181
#   <vaa>: 107.312969235058
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 12kB
# Dimensions:      (y: 14, x: 17)
# Coordinates:
#   * y            (y) float64 112B -3.885e+05 -3.885e+05 ... -3.887e+05
#   * x            (x) float64 136B 1.18e+06 1.18e+06 ... 1.18e+06 1.18e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-08-13T16:21:03.271000
# Data variables:
#     blue         (y, x) float32 952B dask.array<chunksize=(14, 17), meta=np.ndarray>
#     green        (y, x) float32 952B dask.array<chunksize=(14, 17), meta=np.ndarray>
#     red          (y, x) float32 952B dask.array<chunksize=(14, 17), meta=np.ndarray>
#     rededge1     (y, x) float32 952B dask.array<chunksize=(14, 17), meta=np.ndarray>
#     rededge2     (y, x) float32 952B dask.array<chunksize=(14, 17), meta=np.ndarray>
#     rededge3     (y, x) float32 952B dask.array<chunksize=(14, 17), meta=np.ndarray>
#     nir08        (y, x) float32 952B dask.array<chunksize=(14, 17), meta=np.ndarray>
#     swir16       (y, x) float32 952B dask.array<chunksize=(14, 17), meta=np.ndarray>
#     swir22       (y, x) float32 952B dask.array<chunksize=(14, 17), meta=np.ndarray>
#     scl          (y, x) float32 952B dask.array<chunksize=(14, 17), meta=np.ndarray>
#     date         (y, x) float32 952B dask.array<chunksize=(14, 17), meta=np.ndarray>
#     score        (y, x) float32 952B dask.array<chunksize=(14, 17), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   1.32 minutes >>>>>>
# File 'E:\S2_mosaics_2025\S2_kml_region11_20m\log_3d676911-4a82-49b2-9a84-6ff1e05ffb88.out' does not exist.
# Directory 'E:\S2_mosaics_2025\S2_kml_region11_20m\dask_spill_3d676911-4a82-49b2-9a84-6ff1e05ffb88' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-80.4414758461818, 44.4468399119331], [-80.4399721805282, 44.4471867620164], [-80.4395657798354, 44.4447820571645], [-80.44099741403, 44.4444232095963], [-80.4414758461818, 44.4468399119331]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.04 minutes
#
# <one_mosaic> A total of 33 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/AOT.tif
# Asset key: blue, title: Blue - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B02.tif
# Asset key: cloud, title: Cloud Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/qi/CLD_20m.jp2
# Asset key: coastal, title: Coastal - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/granule_metadata.xml
# Asset key: green, title: Green - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B09.tif
# Asset key: product_metadata, title: None, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/product_metadata.xml
# Asset key: red, title: Red - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B04.tif
# Asset key: rededge1, title: Red Edge 1 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B05.tif
# Asset key: rededge2, title: Red Edge 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B06.tif
# Asset key: rededge3, title: Red Edge 3 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/SCL.tif
# Asset key: snow, title: Snow Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/qi/SNW_20m.jp2
# Asset key: swir16, title: SWIR 1.6μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2.2μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/B12.tif
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/TCI.tif
# Asset key: wvp, title: Water Vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/WVP.tif
# Asset key: thumbnail, title: Thumbnail of preview image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A/preview.jpg
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R20m/AOT.jp2
# Asset key: blue-jp2, title: Blue - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R10m/B02.jp2
# Asset key: coastal-jp2, title: Coastal - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R60m/B01.jp2
# Asset key: green-jp2, title: Green - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R10m/B03.jp2
# Asset key: nir-jp2, title: NIR 1 - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R10m/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R20m/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R60m/B09.jp2
# Asset key: red-jp2, title: Red - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R10m/B04.jp2
# Asset key: rededge1-jp2, title: Red Edge 1 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R20m/B05.jp2
# Asset key: rededge2-jp2, title: Red Edge 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R20m/B06.jp2
# Asset key: rededge3-jp2, title: Red Edge 3 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R20m/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R20m/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1.6μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R20m/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2.2μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R20m/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R10m/TCI.jp2
# Asset key: wvp-jp2, title: Water Vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/16/0/R20m/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2B_17TNK_20250816_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-81.00024171761814, 45.153828248771845], [-81.00023764893123, 44.16627582535331], [-80.00625227938608, 44.16213326272399], [-79.60721311385011, 45.145334935216574], [-81.00024171761814, 45.153828248771845]]]}
# Bounding Box: [-81.000242, 44.162133, -79.607213, 45.153828]
# Datetime: 2025-08-16 16:30:59.497000+00:00
# cloud cover: 46.567771
# Properties:
#   <created>: 2025-08-16T19:41:59.474Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 46.567771
#   <proj:centroid>: {'lat': 44.68438, 'lon': -80.39815}
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:azimuth>: 285.1145525878699
#   <view:incidence_angle>: 8.134537630664688
#   <view:sun_azimuth>: 155.345021823521
#   <view:sun_elevation>: 56.7537349780884
#   <s2:tile_id>: S2B_OPER_MSI_L2A_TL_2BPS_20250816T183457_A044110_T17TNK_N05.11
#   <s2:degraded_msi_data_percentage>: 0.0229
#   <s2:nodata_pixel_percentage>: 13.829789
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:cloud_shadow_percentage>: 0.761176
#   <s2:vegetation_percentage>: 27.420518
#   <s2:not_vegetated_percentage>: 2.461837
#   <s2:water_percentage>: 22.38107
#   <s2:unclassified_percentage>: 0.310914
#   <s2:medium_proba_clouds_percentage>: 7.442368
#   <s2:high_proba_clouds_percentage>: 26.853248
#   <s2:thin_cirrus_percentage>: 12.272155
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.11
#   <s2:product_uri>: S2B_MSIL2A_20250816T161829_N0511_R040_T17TNK_20250816T183457.SAFE
#   <s2:generation_time>: 2025-08-16T18:34:57.000000Z
#   <s2:datatake_id>: GS2B_20250816T161829_044110_N05.11
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_2BPS_20250816T183457_S20250816T162600_N05.11
#   <s2:reflectance_conversion_factor>: 0.974268282300954
#   <datetime>: 2025-08-16T16:30:59.497000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2B_17TNK_20250816_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/3705f16607e58b854bfa9ab75376facd
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '2025.03.06'}
#   <updated>: 2025-08-16T19:41:59.474Z
#   <proj:code>: EPSG:32617
#   <sza>: 33.2462650219116
#   <saa>: 155.345021823521
#   <vza>: 8.21255064269149
#   <vaa>: 285.271134136974
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 9kB
# Dimensions:      (y: 17, x: 11)
# Coordinates:
#   * y            (y) float64 136B -3.763e+05 -3.763e+05 ... -3.766e+05
#   * x            (x) float64 88B 1.172e+06 1.172e+06 ... 1.172e+06 1.172e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-08-16T16:30:59.497000
# Data variables:
#     blue         (y, x) float32 748B dask.array<chunksize=(17, 11), meta=np.ndarray>
#     green        (y, x) float32 748B dask.array<chunksize=(17, 11), meta=np.ndarray>
#     red          (y, x) float32 748B dask.array<chunksize=(17, 11), meta=np.ndarray>
#     rededge1     (y, x) float32 748B dask.array<chunksize=(17, 11), meta=np.ndarray>
#     rededge2     (y, x) float32 748B dask.array<chunksize=(17, 11), meta=np.ndarray>
#     rededge3     (y, x) float32 748B dask.array<chunksize=(17, 11), meta=np.ndarray>
#     nir08        (y, x) float32 748B dask.array<chunksize=(17, 11), meta=np.ndarray>
#     swir16       (y, x) float32 748B dask.array<chunksize=(17, 11), meta=np.ndarray>
#     swir22       (y, x) float32 748B dask.array<chunksize=(17, 11), meta=np.ndarray>
#     scl          (y, x) float32 748B dask.array<chunksize=(17, 11), meta=np.ndarray>
#     date         (y, x) float32 748B dask.array<chunksize=(17, 11), meta=np.ndarray>
#     score        (y, x) float32 748B dask.array<chunksize=(17, 11), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   1.18 minutes >>>>>>
# File 'E:\S2_mosaics_2025\S2_kml_region11_20m\log_4cb2789a-26bf-421a-ba92-4b6378e28cf2.out' does not exist.
# Directory 'E:\S2_mosaics_2025\S2_kml_region11_20m\dask_spill_4cb2789a-26bf-421a-ba92-4b6378e28cf2' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-80.4421816733383, 44.4466135137253], [-80.4416845003799, 44.4468203876096], [-80.4411932481774, 44.444365318568], [-80.4415073722911, 44.4442547096037], [-80.4421816733383, 44.4466135137253]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.03 minutes
#
# <one_mosaic> A total of 33 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/9/S2B_17TNK_20250905_0_L2A/AOT.tif
# Asset key: blue, title: Blue - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/9/S2B_17TNK_20250905_0_L2A/B02.tif
# Asset key: cloud, title: Cloud Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/9/5/0/qi/CLD_20m.jp2
# Asset key: coastal, title: Coastal - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/9/S2B_17TNK_20250905_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/9/S2B_17TNK_20250905_0_L2A/granule_metadata.xml
# Asset key: green, title: Green - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/9/S2B_17TNK_20250905_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/9/S2B_17TNK_20250905_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/9/S2B_17TNK_20250905_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/9/S2B_17TNK_20250905_0_L2A/B09.tif
# Asset key: product_metadata, title: None, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/9/5/0/product_metadata.xml
# Asset key: red, title: Red - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/9/S2B_17TNK_20250905_0_L2A/B04.tif
# Asset key: rededge1, title: Red Edge 1 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/9/S2B_17TNK_20250905_0_L2A/B05.tif
# Asset key: rededge2, title: Red Edge 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/9/S2B_17TNK_20250905_0_L2A/B06.tif
# Asset key: rededge3, title: Red Edge 3 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/9/S2B_17TNK_20250905_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/9/S2B_17TNK_20250905_0_L2A/SCL.tif
# Asset key: snow, title: Snow Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/9/5/0/qi/SNW_20m.jp2
# Asset key: swir16, title: SWIR 1.6μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/9/S2B_17TNK_20250905_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2.2μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/9/S2B_17TNK_20250905_0_L2A/B12.tif
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/9/S2B_17TNK_20250905_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/9/S2B_17TNK_20250905_0_L2A/TCI.tif
# Asset key: wvp, title: Water Vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/9/S2B_17TNK_20250905_0_L2A/WVP.tif
# Asset key: thumbnail, title: Thumbnail of preview image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/9/S2B_17TNK_20250905_0_L2A/preview.jpg
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/9/5/0/R20m/AOT.jp2
# Asset key: blue-jp2, title: Blue - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/9/5/0/R10m/B02.jp2
# Asset key: coastal-jp2, title: Coastal - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/9/5/0/R60m/B01.jp2
# Asset key: green-jp2, title: Green - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/9/5/0/R10m/B03.jp2
# Asset key: nir-jp2, title: NIR 1 - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/9/5/0/R10m/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/9/5/0/R20m/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/9/5/0/R60m/B09.jp2
# Asset key: red-jp2, title: Red - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/9/5/0/R10m/B04.jp2
# Asset key: rededge1-jp2, title: Red Edge 1 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/9/5/0/R20m/B05.jp2
# Asset key: rededge2-jp2, title: Red Edge 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/9/5/0/R20m/B06.jp2
# Asset key: rededge3-jp2, title: Red Edge 3 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/9/5/0/R20m/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/9/5/0/R20m/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1.6μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/9/5/0/R20m/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2.2μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/9/5/0/R20m/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/9/5/0/R10m/TCI.jp2
# Asset key: wvp-jp2, title: Water Vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/9/5/0/R20m/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2B_17TNK_20250905_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-81.00024171761814, 45.153828248771845], [-81.00023764531663, 44.16537549832127], [-80.00126930620276, 44.161009791631905], [-79.60492336966202, 45.14530698340291], [-81.00024171761814, 45.153828248771845]]]}
# Bounding Box: [-81.000242, 44.16101, -79.604923, 45.153828]
# Datetime: 2025-09-05 16:30:56.172000+00:00
# cloud cover: 64.13641
# Properties:
#   <created>: 2025-09-05T21:41:28.232Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 64.13641
#   <proj:centroid>: {'lat': 44.68362, 'lon': -80.3964}
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:azimuth>: 285.1011218702665
#   <view:incidence_angle>: 8.115438883682828
#   <view:sun_azimuth>: 160.752616358344
#   <view:sun_elevation>: 50.4162892988021
#   <s2:tile_id>: S2B_OPER_MSI_L2A_TL_2BPS_20250905T202408_A044396_T17TNK_N05.11
#   <s2:degraded_msi_data_percentage>: 0.0482
#   <s2:nodata_pixel_percentage>: 13.446316
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:cloud_shadow_percentage>: 4.720756
#   <s2:vegetation_percentage>: 7.612704
#   <s2:not_vegetated_percentage>: 1.288612
#   <s2:water_percentage>: 21.103755
#   <s2:unclassified_percentage>: 1.134499
#   <s2:medium_proba_clouds_percentage>: 14.955515
#   <s2:high_proba_clouds_percentage>: 48.369804
#   <s2:thin_cirrus_percentage>: 0.811094
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.11
#   <s2:product_uri>: S2B_MSIL2A_20250905T161829_N0511_R040_T17TNK_20250905T202408.SAFE
#   <s2:generation_time>: 2025-09-05T20:24:08.000000Z
#   <s2:datatake_id>: GS2B_20250905T161829_044396_N05.11
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_2BPS_20250905T202408_S20250905T162300_N05.11
#   <s2:reflectance_conversion_factor>: 0.982532507379172
#   <datetime>: 2025-09-05T16:30:56.172000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2025/9/S2B_17TNK_20250905_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/da17de2323136b4e2f855422d5fe16bf
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '2025.03.06'}
#   <updated>: 2025-09-05T21:42:13.363Z
#   <proj:code>: EPSG:32617
#   <sza>: 39.5837107011979
#   <saa>: 160.752616358344
#   <vza>: 8.1819120982888
#   <vaa>: 285.292216952254
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 6kB
# Dimensions:      (y: 15, x: 8)
# Coordinates:
#   * y            (y) float64 120B -3.763e+05 -3.764e+05 ... -3.766e+05
#   * x            (x) float64 64B 1.172e+06 1.172e+06 ... 1.172e+06 1.172e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-09-05T16:30:56.172000
# Data variables:
#     blue         (y, x) float32 480B dask.array<chunksize=(15, 8), meta=np.ndarray>
#     green        (y, x) float32 480B dask.array<chunksize=(15, 8), meta=np.ndarray>
#     red          (y, x) float32 480B dask.array<chunksize=(15, 8), meta=np.ndarray>
#     rededge1     (y, x) float32 480B dask.array<chunksize=(15, 8), meta=np.ndarray>
#     rededge2     (y, x) float32 480B dask.array<chunksize=(15, 8), meta=np.ndarray>
#     rededge3     (y, x) float32 480B dask.array<chunksize=(15, 8), meta=np.ndarray>
#     nir08        (y, x) float32 480B dask.array<chunksize=(15, 8), meta=np.ndarray>
#     swir16       (y, x) float32 480B dask.array<chunksize=(15, 8), meta=np.ndarray>
#     swir22       (y, x) float32 480B dask.array<chunksize=(15, 8), meta=np.ndarray>
#     scl          (y, x) float32 480B dask.array<chunksize=(15, 8), meta=np.ndarray>
#     date         (y, x) float32 480B dask.array<chunksize=(15, 8), meta=np.ndarray>
#     score        (y, x) float32 480B dask.array<chunksize=(15, 8), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   1.23 minutes >>>>>>
# File 'E:\S2_mosaics_2025\S2_kml_region11_20m\log_a0b45b0e-b796-4084-8e44-ee8db83d8bdc.out' does not exist.
# Directory 'E:\S2_mosaics_2025\S2_kml_region11_20m\dask_spill_a0b45b0e-b796-4084-8e44-ee8db83d8bdc' and its contents have been deleted.
# {'sensor': 'S2_SR', 'unit': 2, 'year': 2025, 'nbYears': -1, 'prod_names': ['mosaic'], 'resolution': 20, 'out_folder': 'E:/S2_mosaics_2025/S2_kml_region11_20m', 'out_datatype': 'int16', 'projection': 'EPSG:3979', 'IncludeAngles': False, 'start_dates': ['2025-06-15'], 'end_dates': ['2025-09-15'], 'regions': {'region1': {'type': 'Polygon', 'coordinates': [[[-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.2868313289172, 44.3529866183925], [-80.2871254773415, 44.3529366809224], [-80.2874977225433, 44.3529180592246], [-80.2876405698119, 44.3529059627622], [-80.2879206306362, 44.3528989373857], [-80.2880395541161, 44.3528827993289], [-80.2880782566738, 44.352880279965], [-80.2882027280036, 44.353154957613], [-80.288085927134, 44.3531261618167], [-80.287951530048, 44.3531125098555], [-80.2878832692439, 44.3531281508011], [-80.287738989293, 44.3532215337679], [-80.2877249039523, 44.3532644472593], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3533270111586], [-80.2871598357525, 44.3533320137857], [-80.2866384110016, 44.3533435417762]]]}, 'region2': {'type': 'Polygon', 'coordinates': [[[-80.529638877948, 44.5242213601121], [-80.5236686736853, 44.5252976281762], [-80.5234042910143, 44.5252538220711], [-80.5231938083608, 44.5249653160984], [-80.5230220292666, 44.5247919216231], [-80.5294731056627, 44.5235598453566], [-80.529638877948, 44.5242213601121]]]}, 'region3': {'type': 'Polygon', 'coordinates': [[[-80.3772169808165, 44.3239559238229], [-80.3778062318809, 44.3239281559541], [-80.3783858830901, 44.3257096706257], [-80.3764241776696, 44.3259233842728], [-80.376232840644, 44.3258912372486], [-80.3761778827904, 44.3258276760676], [-80.3757712939805, 44.325759362561], [-80.3752059343744, 44.3257911355417], [-80.3747978938721, 44.3239478686715], [-80.3765005174368, 44.3236001331235], [-80.3766048311268, 44.3237444227003], [-80.3766908273936, 44.3238675253118], [-80.3769060715396, 44.323903689341], [-80.3772169808165, 44.3239559238229]]]}, 'region4': {'type': 'Polygon', 'coordinates': [[[-80.4414758461818, 44.4468399119331], [-80.4399721805282, 44.4471867620164], [-80.4395657798354, 44.4447820571645], [-80.44099741403, 44.4444232095963], [-80.4414758461818, 44.4468399119331]]]}, 'region5': {'type': 'Polygon', 'coordinates': [[[-80.4421816733383, 44.4466135137253], [-80.4416845003799, 44.4468203876096], [-80.4411932481774, 44.444365318568], [-80.4415073722911, 44.4442547096037], [-80.4421816733383, 44.4466135137253]]]}}, 'SsrData': {'NAME': 'S2_SR', 'SSR_CODE': 21, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], '10M_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'SIX_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'NoA_BANDS': ['red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'LEAF_BANDS': ['green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'GEE_NAME': 'COPERNICUS/S2_SR_HARMONIZED', 'CLOUD': 'CLOUDY_PIXEL_PERCENTAGE', 'SZA': 'view:sun_elevation', 'SAA': 'view:sun_azimuth', 'VZA': 'view:sun_elevation', 'VAA': 'view:sun_azimuth', 'BLU': 'blue', 'GRN': 'green', 'RED': 'red', 'NIR': 'nir08', 'SW1': 'swir16', 'SW2': 'swir22'}, 'out_location': 'drive', 'months': [], 'tile_names': [], 'cloud_cover': 80, 'export_style': 'separate', 'monthly': False, 'current_time': 0, 'scene_ID': '', 'current_region': 'region5', 'Criteria': {'timeframe': '2025-06-15/2025-09-15', 'filters': {'eo:cloud_cover': {'lt': 80}}, 'region': {'type': 'Polygon', 'coordinates': [[[-80.4421816733383, 44.4466135137253], [-80.4416845003799, 44.4468203876096], [-80.4411932481774, 44.444365318568], [-80.4415073722911, 44.4442547096037], [-80.4421816733383, 44.4466135137253]]]}, 'catalog': 'https://earth-search.aws.element84.com/v1', 'collection': ['sentinel-2-l2a'], 'bands': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16 ...
