# %%
import os
import sys

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

# %%
ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

CompParams = {
  "number_workers":10,   #For S2 data, only use 10 rather than 20  
  "debug"       : True,
  "entire_tile" : False,     #
  "nodes"       : 1,
  "node_memory" : "50G",
  'chunk_size': {'x': 4096, 'y': 4096}
}

  
ProdParams = {
    'sensor': 'HLS_SR',       # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR', 'HLSS30_SR' or 'MOD_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2025,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    'months': [5,6,7,8,9,10],            # A list of integers represening one or multiple monthes     
    'tile_names': ['tile41_412', 'tile41_421','tile41_422'],  # A list of (sub-)tile names (defined using CCRS' tile griding system) 
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution': 30,            # Exporting spatial resolution    
    'out_folder': 'E:/HLS_mosaics_2025/HLS_mosaic_tile41_2025_30m',  # the folder name for exporting
    'out_datatype': 'int16',     # 'int8' or 'int16'
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    #'start_dates': ['2025-06-15'],
    #'end_dates': ['2025-09-15'],
    #'regions': {'ottawa': ottawa_region}  #, {'vancouver': vancouver_region}    
}

# %%
main(ProdParams, CompParams)
# Out:
# <form_spatial_regions> Raw polygon = {'type': 'Polygon', 'coordinates': [[[-130.5366, 54.4272], [-127.1208, 50.8966], [-121.2106, 52.7067], [-124.1998, 56.439], [-130.5366, 54.4272]]]}
# <form_spatial_regions> Raw polygon = {'type': 'Polygon', 'coordinates': [[[-132.4816, 48.7834], [-129.3357, 45.3897], [-124.2603, 47.3104], [-127.1208, 50.8966], [-132.4816, 48.7834]]]}
# <form_spatial_regions> Raw polygon = {'type': 'Polygon', 'coordinates': [[[-127.1208, 50.8966], [-124.2603, 47.3104], [-118.7501, 48.9443], [-121.2106, 52.7067], [-127.1208, 50.8966]]]}
# <MosaicProduction> User defined input parameters:
# sensor: HLS_SR
# unit: 2
# year: 2025
# nbYears: -1
# months: [5, 6, 7, 8, 9, 10]
# tile_names: ['tile41_412', 'tile41_421', 'tile41_422']
# prod_names: ['mosaic']
# resolution: 30
# out_folder: E:/HLS_mosaics_2025/HLS_mosaic_tile41_2025_30m
# out_datatype: int16
# projection: EPSG:3979
# IncludeAngles: False
# SsrData: {'NAME': 'HLS_SR', 'SSR_CODE': 102, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07'], 'SIX_BANDS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07'], 'NoA_BANDS': ['B04', 'B05', 'B06', 'B07'], 'LEAF_BANDS': ['B03', 'B04', 'B05', 'B06', 'B07'], 'ANGLE_BANDS': ['VZA', 'VAA', 'SZA', 'SAA'], 'CLOUD': 'CLOUD_COVERAGE', 'BLU': 'B02', 'GRN': 'B03', 'RED': 'B04', 'NIR': 'B05', 'SW1': 'B06', 'SW2': 'B07'}
# out_location: drive
# cloud_cover: 80
# export_style: separate
# CloudScore: False
# monthly: True
# start_dates: ['2025-05-01', '2025-06-01', '2025-07-01', '2025-08-01', '2025-09-01', '2025-10-01']
# end_dates: ['2025-05-31', '2025-06-30', '2025-07-31', '2025-08-31', '2025-09-30', '2025-10-31']
# current_time: 0
# scene_ID:
# regions: {'tile41_412': {'type': 'Polygon', 'coordinates': [[[-130.73659999999998, 54.6272], [-127.3208, 50.6966], [-121.0106, 52.506699999999995], [-123.9998, 56.639], [-130.73659999999998, 54.6272]]]}, 'tile41_421': {'type': 'Polygon', 'coordinates': [[[-132.68159999999997, 48.9834], [-129.5357, 45.189699999999995], [-124.0603, 47.1104], [-126.9208, 51.0966], [-132.68159999999997, 48.9834]]]}, 'tile41_422': {'type': 'Polygon', 'coordinates': [[[-127.3208, 51.0966], [-124.4603, 47.1104], [-118.5501, 48.744299999999996], [-121.0106, 52.9067], [-127.3208, 51.0966]]]}}
# current_region: tile41_412
# Criteria: {'timeframe': '2025-05-01/2025-05-31', 'filters': {'eo:cloud_cover': {'lt': 80}}, 'region': {'type': 'Polygon', 'coordinates': [[[-130.73659999999998, 54.6272], [-127.3208, 50.6966], [-121.0106, 52.506699999999995], [-123.9998, 56.639], [-130.73659999999998, 54.6272]]]}, 'collection': ['HLSS30_2.0', 'HLSL30_2.0'], 'bands': {'S2': ['B02', 'B03', 'B04', 'B08', 'B11', 'B12', 'Fmask'], 'LS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'Fmask'], 'angle': ['SZA', 'SAA', 'VZA', 'VAA']}, 'catalog': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD'}
# standardized: True
# number_workers: 10
# debug: True
# entire_tile: False
# nodes: 1
# node_memory: 50G
# chunk_size: {'x': 4096, 'y': 4096}
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-130.73659999999998, 54.6272], [-127.3208, 50.6966], [-121.0106, 52.506699999999995], [-123.9998, 56.639], [-130.73659999999998, 54.6272]]]}
#
# <one_mosaic> A total of 343 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T10VDH.2025122T191909.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.jpg
# Asset key: B12, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B12.tif
# Asset key: B02, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B02.tif
# Asset key: B09, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B09.tif
# Asset key: B10, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B10.tif
# Asset key: B04, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B04.tif
# Asset key: VZA, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.VZA.tif
# Asset key: Fmask, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.Fmask.tif
# Asset key: B11, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B11.tif
# Asset key: B03, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B03.tif
# Asset key: B06, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B06.tif
# Asset key: B05, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B05.tif
# Asset key: B8A, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B8A.tif
# Asset key: B01, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B01.tif
# Asset key: B07, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B07.tif
# Asset key: SAA, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.SAA.tif
# Asset key: B08, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B08.tif
# Asset key: VAA, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.VAA.tif
# Asset key: SZA, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.SZA.tif
# Asset key: s3_B12, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B12.tif
# Asset key: s3_B02, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B02.tif
# Asset key: s3_B09, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B09.tif
# Asset key: s3_B10, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B10.tif
# Asset key: s3_B04, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B04.tif
# Asset key: s3_VZA, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.VZA.tif
# Asset key: s3_Fmask, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.Fmask.tif
# Asset key: s3_B11, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B11.tif
# Asset key: s3_B03, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B03.tif
# Asset key: s3_B06, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B06.tif
# Asset key: s3_B05, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B05.tif
# Asset key: s3_B8A, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B8A.tif
# Asset key: s3_B01, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B01.tif
# Asset key: s3_B07, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B07.tif
# Asset key: s3_SAA, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.SAA.tif
# Asset key: s3_B08, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.B08.tif
# Asset key: s3_VAA, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.VAA.tif
# Asset key: s3_SZA, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10VDH.2025122T191909.v2.0/HLS.S30.T10VDH.2025122T191909.v2.0.SZA.tif
# Asset key: metadata, title: CMR XML metadata for G3520384890-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3520384890-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: HLS.S30.T10VDH.2025122T191909.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-124.4627324, 55.848628], [-122.8440833, 55.8572224], [-122.840006, 56.8437093], [-123.9651205, 56.8395431], [-124.4627324, 55.848628]]]}
# Bounding Box: [-124.4627324, 55.848628, -122.840006, 56.8437093]
# Datetime: 2025-05-02 19:29:03.222000+00:00
# cloud cover: 2
# Properties:
#   <datetime>: 2025-05-02T19:29:03.222Z
#   <eo:cloud_cover>: 2
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2025-05-02T19:29:03.222Z
#   <end_datetime>: 2025-05-02T19:29:03.222Z
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 11GB
# Dimensions:      (y: 16694, x: 16447)
# Coordinates:
#   * y            (y) float64 134kB 1.24e+06 1.24e+06 ... 7.395e+05 7.394e+05
#   * x            (x) float64 132kB -2.173e+06 -2.173e+06 ... -1.68e+06 -1.68e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-05-02T19:29:03.222000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     sensor       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 42
#
# <<<<<< The unique granule tiles =  ['T10UDC', 'T10VDH', 'T10UDG', 'T10UEF', 'T10UEG', 'T10UEC', 'T10UCC', 'T09UYT', 'T09UXT', 'T10UCG', 'T10UCE', 'T09UYV', 'T10UCF', 'T09UXU', 'T10UCB', 'T09UYS', 'T10UDE', 'T10UDD', 'T10UCD', 'T09UYU', 'T09UXV', 'T09UXS', 'T10UDF', 'T10UFD', 'T10VCH', 'T09UXB', 'T09UVU', 'T09UUA', 'T09VXC', 'T09UWA', 'T09UWT', 'T09UVB', 'T10UFE', 'T10UEE', 'T10UED', 'T09UXA', 'T09UWS', 'T09UVA', 'T09UWV', 'T09UWB', 'T09UWU', 'T09UVV']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 267.57 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.02 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation = 113.30 minutes >>>>>>
# File 'E:\HLS_mosaics_2025\HLS_mosaic_tile41_2025_30m\log_c1c83b7f-6f06-4cf6-a08e-c1cfffa54f21.out' does not exist.
# Directory 'E:\HLS_mosaics_2025\HLS_mosaic_tile41_2025_30m\dask_spill_c1c83b7f-6f06-4cf6-a08e-c1cfffa54f21' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-130.73659999999998, 54.6272], [-127.3208, 50.6966], [-121.0106, 52.506699999999995], [-123.9998, 56.639], [-130.73659999999998, 54.6272]]]}
#
# <one_mosaic> A total of 525 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T09UXU.2025152T191909.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.jpg
# Asset key: SAA, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.SAA.tif
# Asset key: B04, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B04.tif
# Asset key: Fmask, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.Fmask.tif
# Asset key: B09, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B09.tif
# Asset key: B10, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B10.tif
# Asset key: B08, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B08.tif
# Asset key: B07, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B07.tif
# Asset key: B11, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B11.tif
# Asset key: B06, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B06.tif
# Asset key: B8A, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B8A.tif
# Asset key: VAA, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.VAA.tif
# Asset key: B01, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B01.tif
# Asset key: B02, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B02.tif
# Asset key: VZA, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.VZA.tif
# Asset key: SZA, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.SZA.tif
# Asset key: B05, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B05.tif
# Asset key: B03, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B03.tif
# Asset key: B12, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B12.tif
# Asset key: s3_SAA, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.SAA.tif
# Asset key: s3_B04, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B04.tif
# Asset key: s3_Fmask, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.Fmask.tif
# Asset key: s3_B09, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B09.tif
# Asset key: s3_B10, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B10.tif
# Asset key: s3_B08, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B08.tif
# Asset key: s3_B07, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B07.tif
# Asset key: s3_B11, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B11.tif
# Asset key: s3_B06, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B06.tif
# Asset key: s3_B8A, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B8A.tif
# Asset key: s3_VAA, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.VAA.tif
# Asset key: s3_B01, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B01.tif
# Asset key: s3_B02, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B02.tif
# Asset key: s3_VZA, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.VZA.tif
# Asset key: s3_SZA, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.SZA.tif
# Asset key: s3_B05, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B05.tif
# Asset key: s3_B03, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B03.tif
# Asset key: s3_B12, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T09UXU.2025152T191909.v2.0/HLS.S30.T09UXU.2025152T191909.v2.0.B12.tif
# Asset key: metadata, title: CMR XML metadata for G3558939947-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3558939947-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: HLS.S30.T09UXU.2025152T191909.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-125.9283215, 52.222566], [-125.8943215, 52.7078721], [-126.1011308, 52.2269406], [-125.9283215, 52.222566]]]}
# Bounding Box: [-126.1011308, 52.222566, -125.8943215, 52.7078721]
# Datetime: 2025-06-01 19:30:11.903000+00:00
# cloud cover: 41
# Properties:
#   <datetime>: 2025-06-01T19:30:11.903Z
#   <eo:cloud_cover>: 41
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2025-06-01T19:30:11.903Z
#   <end_datetime>: 2025-06-01T19:30:11.903Z
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 11GB
# Dimensions:      (y: 16694, x: 16447)
# Coordinates:
#   * y            (y) float64 134kB 1.24e+06 1.24e+06 ... 7.395e+05 7.394e+05
#   * x            (x) float64 132kB -2.173e+06 -2.173e+06 ... -1.68e+06 -1.68e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-06-01T19:30:11.903000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     sensor       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 42
#
# <<<<<< The unique granule tiles =  ['T09UXU', 'T10UCF', 'T10UCG', 'T09UWV', 'T09UWA', 'T09UXT', 'T09UXB', 'T10UDD', 'T10UDC', 'T09UXS', 'T10UDE', 'T09UYT', 'T09UXA', 'T09UYV', 'T10UCE', 'T09UXV', 'T09UWU', 'T10UDG', 'T10VDH', 'T10UED', 'T10UCC', 'T09UVA', 'T09UVV', 'T10UDF', 'T10UCD', 'T10UCB', 'T09UYS', 'T09UVU', 'T09UWS', 'T10UEF', 'T09UYU', 'T10UEE', 'T09UVB', 'T09UWT', 'T10VCH', 'T09UWB', 'T10UEC', 'T10UFE', 'T10UEG', 'T09UUA', 'T09VXC', 'T10UFD']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 273.09 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.02 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation = 151.55 minutes >>>>>>
# File 'E:\HLS_mosaics_2025\HLS_mosaic_tile41_2025_30m\log_8569dabe-e830-426c-b6c7-54d87ff12f49.out' does not exist.
# Directory 'E:\HLS_mosaics_2025\HLS_mosaic_tile41_2025_30m\dask_spill_8569dabe-e830-426c-b6c7-54d87ff12f49' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-130.73659999999998, 54.6272], [-127.3208, 50.6966], [-121.0106, 52.506699999999995], [-123.9998, 56.639], [-130.73659999999998, 54.6272]]]}
#
# <one_mosaic> A total of 648 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T10UEG.2025182T191909.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.jpg
# Asset key: SZA, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.SZA.tif
# Asset key: B09, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B09.tif
# Asset key: B07, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B07.tif
# Asset key: B08, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B08.tif
# Asset key: B10, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B10.tif
# Asset key: VZA, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.VZA.tif
# Asset key: B03, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B03.tif
# Asset key: B04, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B04.tif
# Asset key: B02, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B02.tif
# Asset key: B06, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B06.tif
# Asset key: Fmask, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.Fmask.tif
# Asset key: B12, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B12.tif
# Asset key: B11, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B11.tif
# Asset key: B8A, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B8A.tif
# Asset key: B05, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B05.tif
# Asset key: SAA, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.SAA.tif
# Asset key: B01, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B01.tif
# Asset key: VAA, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.VAA.tif
# Asset key: s3_SZA, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.SZA.tif
# Asset key: s3_B09, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B09.tif
# Asset key: s3_B07, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B07.tif
# Asset key: s3_B08, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B08.tif
# Asset key: s3_B10, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B10.tif
# Asset key: s3_VZA, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.VZA.tif
# Asset key: s3_B03, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B03.tif
# Asset key: s3_B04, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B04.tif
# Asset key: s3_B02, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B02.tif
# Asset key: s3_B06, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B06.tif
# Asset key: s3_Fmask, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.Fmask.tif
# Asset key: s3_B12, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B12.tif
# Asset key: s3_B11, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B11.tif
# Asset key: s3_B8A, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B8A.tif
# Asset key: s3_B05, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B05.tif
# Asset key: s3_SAA, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.SAA.tif
# Asset key: s3_B01, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.B01.tif
# Asset key: s3_VAA, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEG.2025182T191909.v2.0/HLS.S30.T10UEG.2025182T191909.v2.0.VAA.tif
# Asset key: metadata, title: CMR XML metadata for G3589695246-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3589695246-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: HLS.S30.T10UEG.2025182T191909.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-121.2860145, 54.9470178], [-121.2427243, 55.9332025], [-123.0003202, 55.9457344], [-123.0003123, 54.9590989], [-121.2860145, 54.9470178]]]}
# Bounding Box: [-123.0003202, 54.9470178, -121.2427243, 55.9457344]
# Datetime: 2025-07-01 19:29:14.394000+00:00
# cloud cover: 63
# Properties:
#   <datetime>: 2025-07-01T19:29:14.394Z
#   <eo:cloud_cover>: 63
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2025-07-01T19:29:14.394Z
#   <end_datetime>: 2025-07-01T19:29:14.394Z
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 11GB
# Dimensions:      (y: 16694, x: 16447)
# Coordinates:
#   * y            (y) float64 134kB 1.24e+06 1.24e+06 ... 7.395e+05 7.394e+05
#   * x            (x) float64 132kB -2.173e+06 -2.173e+06 ... -1.68e+06 -1.68e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-07-01T19:29:14.394000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     sensor       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 42
#
# <<<<<< The unique granule tiles =  ['T10UDC', 'T09UXT', 'T09UWV', 'T10UCF', 'T10UCE', 'T09UYV', 'T09UWU', 'T09UWA', 'T10UDD', 'T10UDE', 'T10UCD', 'T10UCC', 'T09UYT', 'T10UCB', 'T09UXV', 'T10UCG', 'T09UYS', 'T09UXS', 'T09UVA', 'T10UDF', 'T09UYU', 'T09UXU', 'T09UVU', 'T09UWT', 'T10UEF', 'T09UXA', 'T09UVV', 'T10UEG', 'T10UEC', 'T10UDG', 'T09UXB', 'T09UWB', 'T10UED', 'T09UVB', 'T10UEE', 'T10UFD', 'T09UUA', 'T10VDH', 'T09UWS', 'T10VCH', 'T09VXC', 'T10UFE']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 297.79 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.02 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# ...
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.02 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation = 182.98 minutes >>>>>>
# File 'E:\HLS_mosaics_2025\HLS_mosaic_tile41_2025_30m\log_e9174192-d033-4c7b-9d04-264f6494c06b.out' does not exist.
# Directory 'E:\HLS_mosaics_2025\HLS_mosaic_tile41_2025_30m\dask_spill_e9174192-d033-4c7b-9d04-264f6494c06b' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-130.73659999999998, 54.6272], [-127.3208, 50.6966], [-121.0106, 52.506699999999995], [-123.9998, 56.639], [-130.73659999999998, 54.6272]]]}
#
# <one_mosaic> A total of 597 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T10UEF.2025244T190931.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.jpg
# Asset key: B09, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B09.tif
# Asset key: B12, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B12.tif
# Asset key: B11, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B11.tif
# Asset key: B08, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B08.tif
# Asset key: B03, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B03.tif
# Asset key: B06, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B06.tif
# Asset key: B10, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B10.tif
# Asset key: B07, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B07.tif
# Asset key: B8A, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B8A.tif
# Asset key: B05, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B05.tif
# Asset key: B01, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B01.tif
# Asset key: B02, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B02.tif
# Asset key: Fmask, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.Fmask.tif
# Asset key: SZA, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.SZA.tif
# Asset key: SAA, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.SAA.tif
# Asset key: B04, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B04.tif
# Asset key: VZA, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.VZA.tif
# Asset key: VAA, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.VAA.tif
# Asset key: s3_B09, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B09.tif
# Asset key: s3_B12, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B12.tif
# Asset key: s3_B11, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B11.tif
# Asset key: s3_B08, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B08.tif
# Asset key: s3_B03, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B03.tif
# Asset key: s3_B06, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B06.tif
# Asset key: s3_B10, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B10.tif
# Asset key: s3_B07, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B07.tif
# Asset key: s3_B8A, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B8A.tif
# Asset key: s3_B05, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B05.tif
# Asset key: s3_B01, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B01.tif
# Asset key: s3_B02, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B02.tif
# Asset key: s3_Fmask, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.Fmask.tif
# Asset key: s3_SZA, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.SZA.tif
# Asset key: s3_SAA, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.SAA.tif
# Asset key: s3_B04, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.B04.tif
# Asset key: s3_VZA, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.VZA.tif
# Asset key: s3_VAA, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UEF.2025244T190931.v2.0/HLS.S30.T10UEF.2025244T190931.v2.0.VAA.tif
# Asset key: metadata, title: CMR XML metadata for G3685275256-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3685275256-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: HLS.S30.T10UEF.2025244T190931.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-121.3232119, 54.0485147], [-121.2822658, 55.0348657], [-122.3354843, 55.0451725], [-122.7958855, 54.0611092], [-122.7958908, 54.0600306], [-121.3232119, 54.0485147]]]}
# Bounding Box: [-122.7958908, 54.0485147, -121.2822658, 55.0451725]
# Datetime: 2025-09-01 19:19:46.436000+00:00
# cloud cover: 64
# Properties:
#   <datetime>: 2025-09-01T19:19:46.436Z
#   <eo:cloud_cover>: 64
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2025-09-01T19:19:46.436Z
#   <end_datetime>: 2025-09-01T19:19:46.436Z
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 11GB
# Dimensions:      (y: 16694, x: 16447)
# Coordinates:
#   * y            (y) float64 134kB 1.24e+06 1.24e+06 ... 7.395e+05 7.394e+05
#   * x            (x) float64 132kB -2.173e+06 -2.173e+06 ... -1.68e+06 -1.68e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-09-01T19:19:46.436000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     sensor       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 42
#
# <<<<<< The unique granule tiles =  ['T10UDD', 'T10UDC', 'T10VDH', 'T10UEF', 'T10UDE', 'T09UXU', 'T10UED', 'T10UCE', 'T10UDG', 'T10UCF', 'T09UYV', 'T09UXT', 'T10UCG', 'T10UCD', 'T09UYU', 'T10UEE', 'T10UEG', 'T10UDF', 'T09UWA', 'T10UCC', 'T10UFD', 'T09UXA', 'T09UWV', 'T09UYT', 'T10UCB', 'T10UEC', 'T09UVA', 'T09UXB', 'T09UXS', 'T10UFE', 'T10VCH', 'T09UXV', 'T09UYS', 'T09UVB', 'T09VXC', 'T09UWU', 'T09UWB', 'T09UVV', 'T09UWT', 'T09UUA', 'T09UVU', 'T09UWS']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 282.60 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
