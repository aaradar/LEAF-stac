# %%
import os
import sys

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

# %%
ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

CompParams = {
  "number_workers":10,     
  "debug"       : True,
  "entire_tile" : False, 
  "nodes"       : 1,
  "node_memory" : "50G",
  'chunk_size': {'x': 4096, 'y': 4096}
}

  
ProdParams = {
    'sensor': 'HLS_SR',       # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR' or 'HLSS30_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2025,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    'months': [5,6,7,8,9,10],    # A list of integers represening one or multiple monthes     
    'tile_names': ['tile46_411','tile46_412','tile46_421','tile46_422'],  # A list of (sub-)tile names
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution': 30,            # Exporting spatial resolution    
    'out_folder': 'E:/HLS_mosaics_2025/HLS_mosaic_tile46_2025_30m',  # the folder name for exporting
    'out_datatype': 'int16',     # 'int8' or 'int16'
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    #'start_dates': ['2025-06-15'],
    #'end_dates': ['2025-09-15'],
    #'regions': {'ottawa': ottawa_region}  #, {'vancouver': vancouver_region}    
}

# %%
main(ProdParams, CompParams)
# Out:
# <form_spatial_regions> Raw polygon = {'type': 'Polygon', 'coordinates': [[[-62.8968, 55.5882], [-66.0957, 51.9431], [-60.4286, 49.9916], [-56.8731, 53.4275], [-62.8968, 55.5882]]]}
# <form_spatial_regions> Raw polygon = {'type': 'Polygon', 'coordinates': [[[-56.8731, 53.4275], [-60.4286, 49.9916], [-55.3111, 47.7608], [-51.5381, 50.9785], [-56.8731, 53.4275]]]}
# <form_spatial_regions> Raw polygon = {'type': 'Polygon', 'coordinates': [[[-66.0957, 51.9431], [-68.7488, 48.2563], [-63.4293, 46.4895], [-60.4286, 49.9916], [-66.0957, 51.9431]]]}
# <form_spatial_regions> Raw polygon = {'type': 'Polygon', 'coordinates': [[[-60.4286, 49.9916], [-63.4293, 46.4895], [-58.5508, 44.4557], [-55.3111, 47.7608], [-60.4286, 49.9916]]]}
# <MosaicProduction> User defined input parameters:
# sensor: HLS_SR
# unit: 2
# year: 2025
# nbYears: -1
# months: [5, 6, 7, 8, 9, 10]
# tile_names: ['tile46_411', 'tile46_412', 'tile46_421', 'tile46_422']
# prod_names: ['mosaic']
# resolution: 30
# out_folder: E:/HLS_mosaics_2025/HLS_mosaic_tile46_2025_30m
# out_datatype: int16
# projection: EPSG:3979
# IncludeAngles: False
# SsrData: {'NAME': 'HLS_SR', 'SSR_CODE': 102, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07'], 'SIX_BANDS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07'], 'NoA_BANDS': ['B04', 'B05', 'B06', 'B07'], 'LEAF_BANDS': ['B03', 'B04', 'B05', 'B06', 'B07'], 'ANGLE_BANDS': ['VZA', 'VAA', 'SZA', 'SAA'], 'CLOUD': 'CLOUD_COVERAGE', 'BLU': 'B02', 'GRN': 'B03', 'RED': 'B04', 'NIR': 'B05', 'SW1': 'B06', 'SW2': 'B07'}
# out_location: drive
# cloud_cover: 80
# export_style: separate
# CloudScore: False
# monthly: True
# start_dates: ['2025-05-01', '2025-06-01', '2025-07-01', '2025-08-01', '2025-09-01', '2025-10-01']
# end_dates: ['2025-05-31', '2025-06-30', '2025-07-31', '2025-08-31', '2025-09-30', '2025-10-31']
# current_time: 0
# scene_ID:
# regions: {'tile46_411': {'type': 'Polygon', 'coordinates': [[[-63.0968, 55.7882], [-66.2957, 51.7431], [-60.2286, 49.791599999999995], [-56.6731, 53.627500000000005], [-63.0968, 55.7882]]]}, 'tile46_412': {'type': 'Polygon', 'coordinates': [[[-57.073100000000004, 53.627500000000005], [-60.628600000000006, 49.791599999999995], [-55.1111, 47.5608], [-51.3381, 51.1785], [-57.073100000000004, 53.627500000000005]]]}, 'tile46_421': {'type': 'Polygon', 'coordinates': [[[-66.2957, 52.143100000000004], [-68.9488, 48.0563], [-63.229299999999995, 46.2895], [-60.2286, 50.1916], [-66.2957, 52.143100000000004]]]}, 'tile46_422': {'type': 'Polygon', 'coordinates': [[[-60.628600000000006, 50.1916], [-63.6293, 46.2895], [-58.3508, 44.2557], [-55.1111, 47.960800000000006], [-60.628600000000006, 50.1916]]]}}
# current_region: tile46_411
# Criteria: {'timeframe': '2025-05-01/2025-05-31', 'filters': {'eo:cloud_cover': {'lt': 80}}, 'region': {'type': 'Polygon', 'coordinates': [[[-63.0968, 55.7882], [-66.2957, 51.7431], [-60.2286, 49.791599999999995], [-56.6731, 53.627500000000005], [-63.0968, 55.7882]]]}, 'collection': ['HLSS30_2.0', 'HLSL30_2.0'], 'bands': {'S2': ['B02', 'B03', 'B04', 'B08', 'B11', 'B12', 'Fmask'], 'LS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'Fmask'], 'angle': ['SZA', 'SAA', 'VZA', 'VAA']}, 'catalog': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD'}
# standardized: True
# number_workers: 10
# debug: True
# entire_tile: False
# nodes: 1
# node_memory: 50G
# chunk_size: {'x': 4096, 'y': 4096}
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-63.0968, 55.7882], [-66.2957, 51.7431], [-60.2286, 49.791599999999995], [-56.6731, 53.627500000000005], [-63.0968, 55.7882]]]}
# <search_STAC_Catalog> Number of items found in collection HLSS30_2.0: 410
# <search_STAC_Catalog> Number of items found in collection HLSL30_2.0: 230
#
# <one_mosaic> A total of 640 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T20UPG.2025122T151711.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.jpg
# Asset key: VZA, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.VZA.tif
# Asset key: B06, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B06.tif
# Asset key: B8A, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B8A.tif
# Asset key: B10, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B10.tif
# Asset key: B03, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B03.tif
# Asset key: B04, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B04.tif
# Asset key: SZA, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.SZA.tif
# Asset key: B11, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B11.tif
# Asset key: VAA, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.VAA.tif
# Asset key: Fmask, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.Fmask.tif
# Asset key: B02, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B02.tif
# Asset key: B05, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B05.tif
# Asset key: B12, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B12.tif
# Asset key: B09, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B09.tif
# Asset key: B08, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B08.tif
# Asset key: B07, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B07.tif
# Asset key: SAA, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.SAA.tif
# Asset key: B01, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B01.tif
# Asset key: s3_VZA, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.VZA.tif
# Asset key: s3_B06, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B06.tif
# Asset key: s3_B8A, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B8A.tif
# Asset key: s3_B10, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B10.tif
# Asset key: s3_B03, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B03.tif
# Asset key: s3_B04, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B04.tif
# Asset key: s3_SZA, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.SZA.tif
# Asset key: s3_B11, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B11.tif
# Asset key: s3_VAA, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.VAA.tif
# Asset key: s3_Fmask, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.Fmask.tif
# Asset key: s3_B02, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B02.tif
# Asset key: s3_B05, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B05.tif
# Asset key: s3_B12, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B12.tif
# Asset key: s3_B09, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B09.tif
# Asset key: s3_B08, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B08.tif
# Asset key: s3_B07, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B07.tif
# Asset key: s3_SAA, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.SAA.tif
# Asset key: s3_B01, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T20UPG.2025122T151711.v2.0/HLS.S30.T20UPG.2025122T151711.v2.0.B01.tif
# Asset key: metadata, title: CMR XML metadata for G3520413880-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3520413880-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: HLS.S30.T20UPG.2025122T151711.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-59.7265733, 54.9150072], [-59.6440317, 55.8999986], [-61.3992031, 55.9353354], [-61.4386426, 54.949074], [-59.7265733, 54.9150072]]]}
# Bounding Box: [-61.4386426, 54.9150072, -59.6440317, 55.9353354]
# Datetime: 2025-05-02 15:17:51.634000+00:00
# cloud cover: 0
# Properties:
#   <datetime>: 2025-05-02T15:17:51.634Z
#   <eo:cloud_cover>: 0
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2025-05-02T15:17:51.634Z
#   <end_datetime>: 2025-05-02T15:17:51.634Z
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 11GB
# Dimensions:      (y: 16709, x: 16503)
# Coordinates:
#   * y            (y) float64 134kB 1.24e+06 1.24e+06 ... 7.392e+05 7.392e+05
#   * x            (x) float64 132kB 1.879e+06 1.879e+06 ... 2.374e+06 2.374e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-05-02T15:17:51.634000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     sensor       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 47
#
# <<<<<< The unique granule tiles =  ['T21UUA', 'T20UNF', 'T20UPD', 'T20UPE', 'T20UNE', 'T20UMC', 'T20UNG', 'T21UVU', 'T20UNC', 'T20UMD', 'T20UPF', 'T20UPC', 'T20ULC', 'T20UMB', 'T21UUV', 'T20UQE', 'T20UND', 'T21UUT', 'T20UQC', 'T20ULB', 'T20UPG', 'T21UUU', 'T20UQD', 'T20UNA', 'T21UVV', 'T20UNB', 'T20UMF', 'T20UME', 'T20ULE', 'T19UGV', 'T19UGU', 'T19UGT', 'T21UVA', 'T21UWV', 'T20ULF', 'T20ULD', 'T19UGS', 'T20UPB', 'T21UUS', 'T20UMG', 'T20UQB', 'T21UUR', 'T20UPA', 'T20UQA', 'T21UVT', 'T19UFU', 'T19UFT']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 264.58 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
# ERROR:asyncio:Exception in callback BaseIOStream.write.<locals>.<lambda>() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\iostream.py:536
# handle: <Handle BaseIOStream.write.<locals>.<lambda>() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\iostream.py:536>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\iostream.py", line 536, in <lambda>
#     future.add_done_callback(lambda f: f.exception())
#                                        ~~~~~~~~~~~^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 106, in _needs_document_lock_wrapper
#     await p
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\views\ws.py", line 284, in send_message
#     await message.send(self)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\protocol\message.py", line 310, in send
#     await conn.write_message(self.header_json, locked=False)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\views\ws.py", line 300, in write_message
#     await super().write_message(message, binary)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\websocket.py", line 1113, in wrapper
#     await fut
# asyncio.exceptions.CancelledError
# <<<<<< The total elapsed time for mosaic generation = 150.88 minutes >>>>>>
# File 'E:\HLS_mosaics_2025\HLS_mosaic_tile46_2025_30m\log_6be4f024-c003-4f0e-8968-3e3630a9b3e2.out' does not exist.
# Directory 'E:\HLS_mosaics_2025\HLS_mosaic_tile46_2025_30m\dask_spill_6be4f024-c003-4f0e-8968-3e3630a9b3e2' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-63.0968, 55.7882], [-66.2957, 51.7431], [-60.2286, 49.791599999999995], [-56.6731, 53.627500000000005], [-63.0968, 55.7882]]]}
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\json\decoder.py:361: RuntimeWarning: coroutine 'WSHandler.send_message' was never awaited
#   obj, end = self.scan_once(s, idx)
# <search_STAC_Catalog> Number of items found in collection HLSS30_2.0: 293
# <search_STAC_Catalog> Number of items found in collection HLSL30_2.0: 237
#
# <one_mosaic> A total of 530 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T21UUR.2025152T151711.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.jpg
# Asset key: B04, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B04.tif
# Asset key: VAA, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.VAA.tif
# Asset key: B11, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B11.tif
# Asset key: B12, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B12.tif
# Asset key: B10, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B10.tif
# Asset key: B8A, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B8A.tif
# Asset key: Fmask, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.Fmask.tif
# Asset key: B06, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B06.tif
# Asset key: B09, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B09.tif
# Asset key: B07, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B07.tif
# Asset key: SZA, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.SZA.tif
# Asset key: VZA, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.VZA.tif
# Asset key: B01, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B01.tif
# Asset key: SAA, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.SAA.tif
# Asset key: B08, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B08.tif
# Asset key: B02, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B02.tif
# Asset key: B03, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B03.tif
# Asset key: B05, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B05.tif
# Asset key: s3_B04, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B04.tif
# Asset key: s3_VAA, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.VAA.tif
# Asset key: s3_B11, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B11.tif
# Asset key: s3_B12, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B12.tif
# Asset key: s3_B10, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B10.tif
# Asset key: s3_B8A, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B8A.tif
# Asset key: s3_Fmask, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.Fmask.tif
# Asset key: s3_B06, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B06.tif
# Asset key: s3_B09, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B09.tif
# Asset key: s3_B07, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B07.tif
# Asset key: s3_SZA, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.SZA.tif
# Asset key: s3_VZA, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.VZA.tif
# Asset key: s3_B01, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B01.tif
# Asset key: s3_SAA, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.SAA.tif
# Asset key: s3_B08, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B08.tif
# Asset key: s3_B02, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B02.tif
# Asset key: s3_B03, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B03.tif
# Asset key: s3_B05, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UUR.2025152T151711.v2.0/HLS.S30.T21UUR.2025152T151711.v2.0.B05.tif
# Asset key: metadata, title: CMR XML metadata for G3558906692-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3558906692-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: HLS.S30.T21UUR.2025152T151711.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-59.7937894, 50.0502756], [-59.7906913, 50.0546682], [-59.5592414, 50.5241602], [-59.8213325, 50.5181], [-59.7937894, 50.0502756]]]}
# Bounding Box: [-59.8213325, 50.0502756, -59.5592414, 50.5241602]
# Datetime: 2025-06-01 15:19:07.298000+00:00
# cloud cover: 54
# Properties:
#   <datetime>: 2025-06-01T15:19:07.298Z
#   <eo:cloud_cover>: 54
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2025-06-01T15:19:07.298Z
#   <end_datetime>: 2025-06-01T15:19:07.298Z
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 11GB
# Dimensions:      (y: 16709, x: 16503)
# Coordinates:
#   * y            (y) float64 134kB 1.24e+06 1.24e+06 ... 7.392e+05 7.392e+05
#   * x            (x) float64 132kB 1.879e+06 1.879e+06 ... 2.374e+06 2.374e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-06-01T15:19:07.298000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     sensor       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 47
#
# <<<<<< The unique granule tiles =  ['T20UNB', 'T20UNA', 'T20UPC', 'T21UUR', 'T20UMB', 'T20UPA', 'T20UQA', 'T21UUA', 'T20UPD', 'T20ULD', 'T19UGU', 'T20UMC', 'T21UUU', 'T20UQD', 'T21UUS', 'T20UQB', 'T20ULC', 'T21UVA', 'T20UNC', 'T20UPB', 'T20UNG', 'T20UNE', 'T20UND', 'T21UVV', 'T20UPE', 'T19UGT', 'T19UGV', 'T20UPG', 'T21UUV', 'T21UUT', 'T20UQC', 'T20ULB', 'T21UVU', 'T20ULE', 'T20UMD', 'T20UQE', 'T20UMG', 'T20ULF', 'T20UMF', 'T21UVT', 'T20UNF', 'T21UWV', 'T20UME', 'T20UPF', 'T19UGS', 'T19UFT', 'T19UFU']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 255.43 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.05 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation = 129.13 minutes >>>>>>
# File 'E:\HLS_mosaics_2025\HLS_mosaic_tile46_2025_30m\log_16ed97da-0710-4c5d-9ec7-2bde2efd55f8.out' does not exist.
# Directory 'E:\HLS_mosaics_2025\HLS_mosaic_tile46_2025_30m\dask_spill_16ed97da-0710-4c5d-9ec7-2bde2efd55f8' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-63.0968, 55.7882], [-66.2957, 51.7431], [-60.2286, 49.791599999999995], [-56.6731, 53.627500000000005], [-63.0968, 55.7882]]]}
# <search_STAC_Catalog> Number of items found in collection HLSS30_2.0: 364
# <search_STAC_Catalog> Number of items found in collection HLSL30_2.0: 244
#
# <one_mosaic> A total of 608 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T21UVA.2025182T151711.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.jpg
# Asset key: Fmask, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.Fmask.tif
# Asset key: VAA, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.VAA.tif
# Asset key: B8A, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B8A.tif
# Asset key: B08, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B08.tif
# Asset key: B01, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B01.tif
# Asset key: VZA, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.VZA.tif
# Asset key: B02, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B02.tif
# Asset key: B11, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B11.tif
# Asset key: B05, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B05.tif
# Asset key: B03, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B03.tif
# Asset key: B09, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B09.tif
# Asset key: SAA, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.SAA.tif
# Asset key: B06, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B06.tif
# Asset key: B12, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B12.tif
# Asset key: B10, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B10.tif
# Asset key: B04, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B04.tif
# Asset key: SZA, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.SZA.tif
# Asset key: B07, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B07.tif
# Asset key: s3_Fmask, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.Fmask.tif
# Asset key: s3_VAA, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.VAA.tif
# Asset key: s3_B8A, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B8A.tif
# Asset key: s3_B08, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B08.tif
# Asset key: s3_B01, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B01.tif
# Asset key: s3_VZA, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.VZA.tif
# Asset key: s3_B02, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B02.tif
# Asset key: s3_B11, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B11.tif
# Asset key: s3_B05, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B05.tif
# Asset key: s3_B03, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B03.tif
# Asset key: s3_B09, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B09.tif
# Asset key: s3_SAA, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.SAA.tif
# Asset key: s3_B06, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B06.tif
# Asset key: s3_B12, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B12.tif
# Asset key: s3_B10, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B10.tif
# Asset key: s3_B04, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B04.tif
# Asset key: s3_SZA, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.SZA.tif
# Asset key: s3_B07, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T21UVA.2025182T151711.v2.0/HLS.S30.T21UVA.2025182T151711.v2.0.B07.tif
# Asset key: metadata, title: CMR XML metadata for G3589537568-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3589537568-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: HLS.S30.T21UVA.2025182T151711.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-58.5280799, 54.0504964], [-57.6648603, 54.0583664], [-57.081072, 55.046959], [-58.5653984, 55.0369205], [-58.5280799, 54.0504964]]]}
# Bounding Box: [-58.5653984, 54.0504964, -57.081072, 55.046959]
# Datetime: 2025-07-01 15:17:57.400000+00:00
# cloud cover: 2
# Properties:
#   <datetime>: 2025-07-01T15:17:57.400Z
#   <eo:cloud_cover>: 2
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2025-07-01T15:17:57.400Z
#   <end_datetime>: 2025-07-01T15:17:57.400Z
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 11GB
# Dimensions:      (y: 16709, x: 16503)
# Coordinates:
#   * y            (y) float64 134kB 1.24e+06 1.24e+06 ... 7.392e+05 7.392e+05
#   * x            (x) float64 132kB 1.879e+06 1.879e+06 ... 2.374e+06 2.374e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-07-01T15:17:57.400000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     sensor       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 47
#
# <<<<<< The unique granule tiles =  ['T20UNA', 'T20UPD', 'T20UPC', 'T21UUA', 'T21UVU', 'T21UVV', 'T20UPA', 'T20UQC', 'T21UUV', 'T20UQE', 'T21UVT', 'T20UMC', 'T20UNF', 'T20UMB', 'T21UWV', 'T21UUT', 'T20UPB', 'T21UUR', 'T20UPE', 'T21UVA', 'T21UUU', 'T20UQD', 'T21UUS', 'T20UQA', 'T20UNE', 'T20UQB', 'T20UMD', 'T20ULB', 'T20UNG', 'T20UME', 'T20ULE', 'T19UGV', 'T20ULD', 'T19UGU', 'T20UMF', 'T20UNC', 'T20UNB', 'T20UPG', 'T20UND', 'T20UPF', 'T20ULC', 'T20UMG', 'T19UGS', 'T19UGT', 'T20ULF', 'T19UFU', 'T19UFT']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
