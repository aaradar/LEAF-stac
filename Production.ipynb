# %%
import os
import sys

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

# %%
ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

CompParams = {
  "debug"       : True,
  "entire_tile" : False,     #
  "nodes"       : 1,
  "node_memory" : "120G",
  "number_workers" : 10
}

  
ProdParams = {
    'sensor': 'HLSS30_SR',       # A sensor type string (e.g., 'S2_SR' or 'HLSS30_SR' or 'MOD_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2024,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    'months': [8],            # A list of integers represening one or multiple monthes     
    'tile_names': ['tile55_922'], # A list of (sub-)tile names (defined using CCRS' tile griding system) 
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution': 30,            # Exporting spatial resolution    
    'out_folder': 'C:/Work_Data/HLSS30_mosaic_ott_vanc_2024_10m_new_mask',  # the folder name for exporting
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    #'start_dates': ['2024-06-15'],
    #'end_dates': ['2024-09-15'],
    'regions': {'ottawa': ottawa_region, 'vancouver': vancouver_region}
}

# %%
main(ProdParams, CompParams)
# Out:
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-76.12, 45.184], [-75.383, 45.171], [-75.39, 45.564], [-76.105, 45.568], [-76.12, 45.184]]]}
#
# <period_mosaic> A total of 7 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T18TVR.2024220T154941.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.jpg
# Asset key: Fmask, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.Fmask.tif
# Asset key: B10, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B10.tif
# Asset key: B12, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B12.tif
# Asset key: B01, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B01.tif
# Asset key: B06, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B06.tif
# Asset key: SAA, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.SAA.tif
# Asset key: SZA, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.SZA.tif
# Asset key: VAA, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.VAA.tif
# Asset key: B02, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B02.tif
# Asset key: B09, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B09.tif
# Asset key: B8A, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B8A.tif
# Asset key: B05, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B05.tif
# Asset key: B04, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B04.tif
# Asset key: B08, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B08.tif
# Asset key: VZA, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.VZA.tif
# Asset key: B07, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B07.tif
# Asset key: B03, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B03.tif
# Asset key: B11, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B11.tif
# Asset key: s3_Fmask, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.Fmask.tif
# Asset key: s3_B10, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B10.tif
# Asset key: s3_B12, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B12.tif
# Asset key: s3_B01, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B01.tif
# Asset key: s3_B06, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B06.tif
# Asset key: s3_SAA, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.SAA.tif
# Asset key: s3_SZA, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.SZA.tif
# Asset key: s3_VAA, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.VAA.tif
# Asset key: s3_B02, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B02.tif
# Asset key: s3_B09, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B09.tif
# Asset key: s3_B8A, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B8A.tif
# Asset key: s3_B05, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B05.tif
# Asset key: s3_B04, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B04.tif
# Asset key: s3_B08, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B08.tif
# Asset key: s3_VZA, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.VZA.tif
# Asset key: s3_B07, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B07.tif
# Asset key: s3_B03, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B03.tif
# Asset key: s3_B11, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2024220T154941.v2.0/HLS.S30.T18TVR.2024220T154941.v2.0.B11.tif
# Asset key: metadata, title: CMR XML metadata for G3188844157-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3188844157-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# ID: HLS.S30.T18TVR.2024220T154941.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-75.9494331, 45.0613134], [-74.8760255, 45.0651927], [-74.8738328, 46.0535047], [-75.6087144, 46.0519534], [-75.9494331, 45.0613134]]]}
# Bounding Box: [-75.9494331, 45.0613134, -74.8738328, 46.0535047]
# Datetime: 2024-08-07 16:00:39.880000+00:00
# cloud cover: 2
# Properties:
#   <datetime>: 2024-08-07T16:00:39.880Z
#   <eo:cloud_cover>: 2
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2024-08-07T16:00:39.880Z
#   <end_datetime>: 2024-08-07T16:00:39.880Z
#
# <period_mosaic> based mosaic image =  <xarray.Dataset> Size: 212MB
# Dimensions:      (y: 1943, x: 2274)
# Coordinates:
#   * y            (y) float64 16kB -1.471e+05 -1.472e+05 ... -2.054e+05
#   * x            (x) float64 18kB 1.475e+06 1.475e+06 ... 1.543e+06 1.543e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2024-08-07T16:00:39.880000
# Data variables:
#     blue         (y, x) float32 18MB dask.array<chunksize=(1943, 2000), meta=np.ndarray>
#     green        (y, x) float32 18MB dask.array<chunksize=(1943, 2000), meta=np.ndarray>
#     red          (y, x) float32 18MB dask.array<chunksize=(1943, 2000), meta=np.ndarray>
#     rededge1     (y, x) float32 18MB dask.array<chunksize=(1943, 2000), meta=np.ndarray>
#     rededge2     (y, x) float32 18MB dask.array<chunksize=(1943, 2000), meta=np.ndarray>
#     rededge3     (y, x) float32 18MB dask.array<chunksize=(1943, 2000), meta=np.ndarray>
#     nir08        (y, x) float32 18MB dask.array<chunksize=(1943, 2000), meta=np.ndarray>
#     swir16       (y, x) float32 18MB dask.array<chunksize=(1943, 2000), meta=np.ndarray>
#     swir22       (y, x) float32 18MB dask.array<chunksize=(1943, 2000), meta=np.ndarray>
#     Fmask        (y, x) float32 18MB dask.array<chunksize=(1943, 2000), meta=np.ndarray>
#     date         (y, x) float32 18MB dask.array<chunksize=(1943, 2000), meta=np.ndarray>
#     score        (y, x) float32 18MB dask.array<chunksize=(1943, 2000), meta=np.ndarray>
#
# <period_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['T18TVR']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# ---------------------------------------------------------------------------
# CPLE_HttpResponseError                    Traceback (most recent call last)
# File rasterio\\_base.pyx:310, in rasterio._base.DatasetBase.__init__()
#
# File rasterio\\_base.pyx:221, in rasterio._base.open_dataset()
#
# File rasterio\\_err.pyx:359, in rasterio._err.exc_wrap_pointer()
#
# CPLE_HttpResponseError: HTTP response code: 401 - Failure writing output to destination, passed 27 returned 0
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 main(ProdParams, CompParams)
#
# File ~\STAC_python\Production.py:123, in main(inProdParams, inCompParams)
#     120   leaf.LEAF_production(prod_params, comp_params)
#     122 else:
# --> 123   eoMz.MosaicProduction(prod_params, comp_params)
#
# File ~\STAC_python\source\eoMosaic.py:1588, in MosaicProduction(ProdParams, CompParams)
#    1580   #out_params = compact_params(mosaic, SsrData, ClassImg)
#    1581
#    1582   # Export the 64-bits image to either GD or GCS
#    (...)   1585 else:
#    1586   # Produce and export vegetation parameetr maps for a time period and a region
#    1587   print('\n<MosaicProduction> Generate and export separate mosaic images......')
# -> 1588   one_mosaic(usedParams, CompParams)
#
# File ~\STAC_python\source\eoMosaic.py:1362, in one_mosaic(ProdParams, CompParams, Output)
#    1359   client.cancel(future)
#    1361 # We do the compute to get a dask array instead of a future
# -> 1362 base_img = base_img.chunk({"x": 2000, "y": 2000}).compute()
#    1364 #==========================================================================================================
#    1365 # Mask out the pixels with negative date value
#    1366 #==========================================================================================================
#    1367 mosaic = base_img.where(base_img[eoIM.pix_date] > 0)
#
# File ~\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\dask\base.py:373, in DaskMethodsMixin.compute(self, **kwargs)
#     349 def compute(self, **kwargs):
#     350     """Compute this dask collection
#     351
#     352     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)    371     dask.compute
#     372     """
# --> 373     (result,) = compute(self, traverse=False, **kwargs)
#     374     return result
#
# File ~\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\dask\base.py:681, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     678     expr = expr.optimize()
#     679     keys = list(flatten(expr.__dask_keys__()))
# --> 681     results = schedule(expr, keys, **kwargs)
#     683 return repack(results)
#
# File ~\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\odc\loader\_builder.py:436, in _dask_loader_tyx()
#     434 with rdr.restore_env(env, load_state):
#     435     for ti, ti_srcs in enumerate(srcs):
# --> 436         _fill_nd_slice(
#     437             ti_srcs, gbox, cfg, chunk[ti], ydim=ydim, selection=selection
#     438         )
#     439     return chunk
#
# File ~\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\odc\loader\_builder.py:513, in _fill_nd_slice()
#     510     return dst
#     512 src, *rest = srcs
# --> 513 yx_roi, pix = src.read(cfg, dst_gbox, dst=dst, selection=selection)
#     514 assert len(yx_roi) == 2
#     515 assert pix.ndim == dst.ndim
#
# File ~\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\odc\loader\_rio.py:115, in read()
#     107 def read(
#     108     self,
#     109     cfg: RasterLoadParams,
#    (...)    113     selection: Optional[ReaderSubsetSelection] = None,
#     114 ) -> tuple[tuple[slice, slice], np.ndarray]:
# --> 115     return rio_read(self._src, cfg, dst_geobox, dst=dst, selection=selection)
#
# File ~\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\odc\loader\_rio.py:526, in rio_read()
#     520     if cfg.fail_on_error:
#     521         log.error(
#     522             "Aborting load due to failure while reading: %s:%d",
#     523             src.uri,
#     524             src.band,
#     525         )
# --> 526         raise e
#     527 except rasterio.errors.RasterioError as e:
#     528     if cfg.fail_on_error:
#
# File ~\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\odc\loader\_rio.py:512, in rio_read()
#     508     return roi, out.transpose([1, 2, 0])
#     510 try:
#     511     return fixup_out(
# --> 512         _rio_read(src, cfg, dst_geobox, prep_dst(dst), selection=selection)
#     513     )
#     514 except (
#     515     rasterio.errors.RasterioIOError,
#     516     rasterio.errors.RasterBlockError,
#     517     rasterio.errors.WarpOperationError,
#     518     rasterio.errors.WindowEvaluationError,
#     519 ) as e:
#     520     if cfg.fail_on_error:
#
# File ~\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\odc\loader\_rio.py:560, in _rio_read()
#     549 def _rio_read(
#     550     src: RasterSource,
#     551     cfg: RasterLoadParams,
#    (...)    556     # if resampling is `nearest` then ignore sub-pixel translation when deciding
#     557     # whether we can just paste source into destination
#     558     ttol = 0.9 if cfg.nearest else 0.05
# --> 560     with rasterio.open(src.uri, "r", sharing=False) as rdr:
#     561         assert isinstance(rdr, rasterio.DatasetReader)
#     562         ovr_idx: Optional[int] = None
#
# File ~\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\rasterio\env.py:463, in wrapper()
#     460     session = DummySession()
#     462 with env_ctor(session=session):
# --> 463     return f(*args, **kwds)
#
# File ~\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\rasterio\__init__.py:356, in open()
#     353     path = _parse_path(raw_dataset_path)
#     355 if mode == "r":
# --> 356     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     357 elif mode == "r+":
#     358     dataset = get_writer_for_path(path, driver=driver)(
#     359         path, mode, driver=driver, sharing=sharing, **kwargs
#     360     )
#
# File rasterio\\_base.pyx:312, in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: HTTP response code: 401 - Failure writing output to destination, passed 27 returned 0
